# %% [markdown]
# # Importing Dependencies

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('Dependencies Imported')
# Out:
# Dependencies Imported

# %%
data = pd.read_csv("Coursera.csv")
data.head(5)
# Out:
#    course_id                                        Course_Name  \
# 0      32281  Write A Feature Length Screenplay For Film Or ...
# 1       5114  Business Strategy: Business Model Canvas Analy...
# 2      28977                      Silicon Thin Film Solar Cells
# 3       9253                               Finance for Managers
# 4       9969       Retrieve Data using Single-Table SQL Queries
#
#                       Tenant Difficulty_Level  Course Rating  \
# 0  Michigan State University         Beginner            4.8
# 1   Coursera Project Network         Beginner            4.8
# 2        �cole Polytechnique         Advanced            4.1
# 3       IESE Business School     Intermediate            4.8
# 4   Coursera Project Network         Beginner            4.6
#
#                                           Course_URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                   Course_Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               Skills  members
# 0  Drama  Comedy  peering  screenwriting  film  D...   200630
# 1  Finance  business plan  persona (user experien...   793665
# 2  chemistry  physics  Solar Energy  film  lambda...   114262
# 3  accounts receivable  dupont analysis  analysis...   673572
# 4  Data Analysis  select (sql)  database manageme...   151266

# %% [markdown]
# # Basic Data Analysis

# %%
data.shape #3522 courses and 7 columns with different attributes
# Out:
# (3522, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   course_id           3522 non-null   int64
#  1   Course_Name         3522 non-null   object
#  2   Tenant              3522 non-null   object
#  3   Difficulty_Level    3522 non-null   object
#  4   Course Rating       3522 non-null   float64
#  5   Course_URL          3522 non-null   object
#  6   Course_Description  3522 non-null   object
#  7   Skills              3522 non-null   object
#  8   members             3522 non-null   int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 247.8+ KB

# %%
data.isnull().sum() #no value is missing
# Out:
# course_id             0
# Course_Name           0
# Tenant                0
# Difficulty_Level      0
# Course Rating         0
# Course_URL            0
# Course_Description    0
# Skills                0
# members               0
# dtype: int64

# %%
data['Difficulty_Level'].value_counts()
# Out:
# Beginner          1444
# Advanced          1005
# Intermediate       837
# Conversant         186
# Not Calibrated      50
# Name: Difficulty_Level, dtype: int64

# %%
data['Course Rating'].value_counts()
# Out:
# 4.7    740
# 4.6    623
# 4.8    598
# 4.5    389
# 4.4    242
# 4.9    180
# 4.3    165
# 4.2    121
# 5.0     90
# 4.1     85
# 0.0     82
# 4.0     51
# 3.8     24
# 3.9     20
# 3.7     18
# 3.6     18
# 3.5     17
# 3.4     13
# 3.0     12
# 3.2      9
# 3.3      6
# 2.9      6
# 2.6      2
# 1.0      2
# 2.8      2
# 2.4      2
# 1.9      1
# 2.5      1
# 2.0      1
# 2.3      1
# 3.1      1
# Name: Course Rating, dtype: int64

# %%
# data[data['Course Rating'] == 'Not Calibrated'] = 0

# %%
data['Tenant'].value_counts()
# Out:
# Coursera Project Network                      562
# University of Illinois at Urbana-Champaign    138
# Johns Hopkins University                      110
# University of Colorado Boulder                101
# University of Michigan                        101
#                                              ...
# CertNexus                                       1
# Brightline Initiative                           1
# University of Nebraska                          1
# ConsenSys Academy                               1
# VMware                                          1
# Name: Tenant, Length: 184, dtype: int64

# %%
data['Course_Name']
# Out:
# 0       Write A Feature Length Screenplay For Film Or ...
# 1       Business Strategy: Business Model Canvas Analy...
# 2                           Silicon Thin Film Solar Cells
# 3                                    Finance for Managers
# 4            Retrieve Data using Single-Table SQL Queries
#                               ...
# 3517    Capstone: Retrieving, Processing, and Visualiz...
# 3518                     Patrick Henry: Forgotten Founder
# 3519    Business intelligence and data analytics: Gene...
# 3520                                  Rigid Body Dynamics
# 3521    Architecting with Google Kubernetes Engine: Pr...
# Name: Course_Name, Length: 3522, dtype: object

# %% [markdown]
# # Required Columns for System

# %% [markdown]
# #### Important columns to be used in recommendation system :
#
# - Course Name : Names of the courses
# - Course Description : Similar courses may have similar course description
# - Skills : Users may want to see courses based on same skills
# - Difficulty Level : Similar courses as per difficulty level
#
# #### Columns not used for the recommendation system :
#
# - Course Ratings : Numerical Column; Ratings can sometimes become a biased factor and distribution is not even
# - University : Same university might offer multiple courses in different domains which the user might not want to see
# - Course URL : No significance in the recommendation system

# %%
data = data[['Course_Name','Difficulty_Level','Course_Description','Skills', 'Course Rating']]

# %%
data.head(5)
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write A Feature Length Screenplay For Film Or ...         Beginner
# 1  Business Strategy: Business Model Canvas Analy...         Beginner
# 2                      Silicon Thin Film Solar Cells         Advanced
# 3                               Finance for Managers     Intermediate
# 4       Retrieve Data using Single-Table SQL Queries         Beginner
#
#                                   Course_Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               Skills  Course Rating
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona (user experien...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select (sql)  database manageme...            4.6

# %% [markdown]
# # Data Pre-Processing
#
# An important part of the process is to pre-process the data into usable format for the recommendation system

# %%
# Removing spaces between the words (Lambda funtions can be used as well)

data['Course_Name'] = data['Course_Name'].str.replace(' ',',')
data['Course_Name'] = data['Course_Name'].str.replace(',,',',')
data['Course_Name'] = data['Course_Name'].str.replace(':','')
data['Course_Description'] = data['Course_Description'].str.replace(' ',',')
data['Course_Description'] = data['Course_Description'].str.replace(',,',',')
data['Course_Description'] = data['Course_Description'].str.replace('_','')
data['Course_Description'] = data['Course_Description'].str.replace(':','')
data['Course_Description'] = data['Course_Description'].str.replace('(','')
data['Course_Description'] = data['Course_Description'].str.replace(')','')

#removing paranthesis from skills columns 
data['Skills'] = data['Skills'].str.replace('(','')
data['Skills'] = data['Skills'].str.replace(')','')

# %%
data.head(5)
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...         Beginner
# 1  Business,Strategy,Business,Model,Canvas,Analys...         Beginner
# 2                      Silicon,Thin,Film,Solar,Cells         Advanced
# 3                               Finance,for,Managers     Intermediate
# 4       Retrieve,Data,using,Single-Table,SQL,Queries         Beginner
#
#                                   Course_Description  \
# 0  Write,a,Full,Length,Feature,Film,Script,In,thi...
# 1  By,the,end,of,this,guided,project,you,will,be,...
# 2  This,course,consists,of,a,general,presentation...
# 3  When,it,comes,to,numbers,there,is,always,more,...
# 4  In,this,course,you�ll,learn,how,to,effectively...
#
#                                               Skills  Course Rating
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona user experienc...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select sql  database management...            4.6

# %% [markdown]
# # Tags Column
#
# The tags column is the combination of the following columns : **Course Name** + **Difficulty Level** + **Course Description** + **Skills**

# %%
data['tags'] = data['Course_Name'] + data['Difficulty_Level'] + data['Course_Description'] + data['Skills'] + data['Course Rating'].astype('str')

# %%
data.head(5)
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...         Beginner
# 1  Business,Strategy,Business,Model,Canvas,Analys...         Beginner
# 2                      Silicon,Thin,Film,Solar,Cells         Advanced
# 3                               Finance,for,Managers     Intermediate
# 4       Retrieve,Data,using,Single-Table,SQL,Queries         Beginner
#
#                                   Course_Description  \
# 0  Write,a,Full,Length,Feature,Film,Script,In,thi...
# 1  By,the,end,of,this,guided,project,you,will,be,...
# 2  This,course,consists,of,a,general,presentation...
# 3  When,it,comes,to,numbers,there,is,always,more,...
# 4  In,this,course,you�ll,learn,how,to,effectively...
#
#                                               Skills  Course Rating  \
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona user experienc...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select sql  database management...            4.6
#
#                                                 tags
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...
# 1  Business,Strategy,Business,Model,Canvas,Analys...
# 2  Silicon,Thin,Film,Solar,CellsAdvancedThis,cour...
# 3  Finance,for,ManagersIntermediateWhen,it,comes,...
# 4  Retrieve,Data,using,Single-Table,SQL,QueriesBe...

# %%
data['tags'].iloc[1]
# Out:
# 'Business,Strategy,Business,Model,Canvas,Analysis,with,MiroBeginnerBy,the,end,of,this,guided,project,you,will,be,fluent,in,identifying,and,creating,Business,Model,Canvas,solutions,based,on,previous,high-level,analyses,and,research,data.,This,will,enable,you,to,identify,and,map,the,elements,required,for,new,products,and,services.,Furthermore,it,is,essential,for,generating,positive,results,for,your,business,venture.,This,guided,project,is,designed,to,engage,and,harness,your,visionary,and,exploratory,abilities.,You,will,use,proven,models,in,strategy,and,product,development,with,the,Miro,platform,to,explore,and,analyse,your,business,propositions.,,We,will,practice,critically,examining,results,from,previous,analysis,and,research,results,in,deriving,the,values,for,each,of,the,business,model,sections.Finance  business plan  persona user experience  business model canvas  Planning  Business  project  Product Development  presentation  Strategy business business-strategy4.8'

# %% [markdown]
# # Dataframe to be used

# %%
new_df = data[['Course_Name','tags', 'Course Rating', 'Difficulty_Level']]

# %%
new_df.head(5)
# Out:
#                                          Course_Name  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...
# 1  Business,Strategy,Business,Model,Canvas,Analys...
# 2                      Silicon,Thin,Film,Solar,Cells
# 3                               Finance,for,Managers
# 4       Retrieve,Data,using,Single-Table,SQL,Queries
#
#                                                 tags  Course Rating  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...            4.8
# 1  Business,Strategy,Business,Model,Canvas,Analys...            4.8
# 2  Silicon,Thin,Film,Solar,CellsAdvancedThis,cour...            4.1
# 3  Finance,for,ManagersIntermediateWhen,it,comes,...            4.8
# 4  Retrieve,Data,using,Single-Table,SQL,QueriesBe...            4.6
#
#   Difficulty_Level
# 0         Beginner
# 1         Beginner
# 2         Advanced
# 3     Intermediate
# 4         Beginner

# %%
new_df['tags'] = data['tags'].str.replace(',',' ')
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df['Course_Name'] = data['Course_Name'].str.replace(',',' ')
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.rename(columns = {'Course_Name':'course_name'}, inplace = True)
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower()) #lower casing the tags column
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.head(5)
# Out:
#                                          course_name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy Business Model Canvas Analys...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                                                 tags  Course Rating  \
# 0  write a feature length screenplay for film or ...            4.8
# 1  business strategy business model canvas analys...            4.8
# 2  silicon thin film solar cellsadvancedthis cour...            4.1
# 3  finance for managersintermediatewhen it comes ...            4.8
# 4  retrieve data using single-table sql queriesbe...            4.6
#
#   Difficulty_Level
# 0         Beginner
# 1         Beginner
# 2         Advanced
# 3     Intermediate
# 4         Beginner

# %%
new_df.shape #3522 courses with tags and 2 columns (course_name and tags)
# Out:
# (3522, 4)

# %% [markdown]
# # Text Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %% [markdown]
# # Stemming Process

# %%
import nltk #for stemming process

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
#defining the stemming function
def stem(text):
    y=[]
    
    for i in text.split():
        y.append(ps.stem(i))
    
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem) #applying stemming on the tags column
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Similarity Measure

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %% [markdown]
# # Recommendation Function

# %%
l1 = list()

# %%
l2 = list()

# %%
def recommend(course):
    course_index = new_df[new_df['course_name'] == course].index[0]
    distances = similarity[course_index]
    course_list = sorted(list(enumerate(distances)),reverse=True, key=lambda x:x[1])[1:7]

    for i in course_list:
        new_df['Recommendation'] = new_df.iloc[i[0]].course_name
        l1.append(new_df.iloc[i[0]].course_name)
        
#         print(new_df.iloc[i[0]].course_name)
    return l1

# %%
for i in range(new_df.shape[0]):
# Out:
#   File "<ipython-input-38-09a4f6885617>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
# recommend('Business Strategy Business Model Canvas Analysis with Miro')

# %% [markdown]
# **So these are the 6 courses which are recommended based on our search in the recommendation function**

# %%
for i in range(new_df.shape[0]):
    my_dict = {"Course_Name":[],"Recommendation_Course":[]}

    my_dict["Course_Name"].append(new_df.loc[i, 'course_name'])
    my_dict["Recommendation_Course"].append(recommend(new_df.loc[i, 'course_name']))
    print(my_dict)

#     c = {new_df.loc[i, 'course_name'] : recommend(new_df.loc[i, 'course_name'])}
#     n = pd.DataFrame({'Course_Name':new_df.loc[i, 'course_name']},{'Recommendation_Course' : recommend(new_df.loc[i, 'course_name'])})
#     n = print(f"Course Name: {new_df.loc[i, 'course_name']} '\n' {recommend(new_df.loc[i, 'course_name'])}")
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# {'Course_Name': ['Write A Feature Length Screenplay For Film Or Television'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)']]}
# {'Course_Name': ['Business Strategy Business Model Canvas Analysis with Miro'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately']]}
# {'Course_Name': ['Silicon Thin Film Solar Cells'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy']]}
# {'Course_Name': ['Finance for Managers'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1']]}
# {'Course_Name': ['Retrieve Data using Single-Table SQL Queries'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses']]}
# {'Course_Name': ['Building Test Automation Framework using Selenium and TestNG'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool']]}
# {'Course_Name': ['Doing Business in China Capstone'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone']]}
# {'Course_Name': ['Programming Languages Part A'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala']]}
# {'Course_Name': ['The Roles and Responsibilities of Nonprofit Boards of Directors within the Governance Process'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management']]}
# {'Course_Name': ['Business Russian Communication. Part 3'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet']]}
# {'Course_Name': ['Agile Projects Developing Tasks with Taiga'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro']]}
# {'Course_Name': ['Esports Management Capstone Project'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management']]}
# {'Course_Name': ['Hacking and Patching'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems']]}
# {'Course_Name': ['Business Statistics and Analysis Capstone'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Management ...
# {'Course_Name': ['Grab Data Fast with Vertical and Horizontal LOOKUP'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate M ...
# {'Course_Name': ['Global Health An Interdisciplinary Overview'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Manageme ...
# {'Course_Name': ['Python Programming Essentials'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Management Profits Har ...
# {'Course_Name': ['Creating Dashboards and Storytelling with Tableau'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Ma ...
# ...
# {'Course_Name': ['Introduction to Acoustics (Part 2)'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Management Profit ...
# {'Course_Name': ['Qualitative Research Methods'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Management Profits Harn ...
# {'Course_Name': ['The Rooseveltian Century'], 'Recommendation_Course': [['Script Writing Write a Pilot Episode for a TV or Web Series (Project-Centered Course)', 'Write Your First Novel', 'Transmedia Writing', 'Songwriting Writing the Lyrics', 'Songwriting Writing the Lyrics', 'How to Write a Resume (Project-Centered Course)', 'Product Development Customer Persona Development with Miro', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Journey Mapping with Miro', 'Innovating with the Business Model Canvas', 'Analyzing Macro-Environmental Factors Using Creately', 'Analyzing Market Attractiveness Using Creately', 'Physics of silicon solar cells', 'Introduction to solar cells', 'Organic Solar Cells - Theory and Practice', 'Solar Energy Systems Overview', 'Solar Energy Basics', 'Photovoltaic solar energy', 'Fundamentals of financial and management accounting', 'Introduction to Finance The Basics', 'The Language and Tools of Financial Analysis', 'Operations Management Analysis and Improvement Methods', 'Corporate finance Know your numbers 2', 'Management and financial accounting Know your numbers 1', 'Creating Database Tables with SQL', 'Manipulating Data with SQL', 'Create Relational Database Tables Using SQLiteStudio', 'Retrieve Data with Multiple-Table SQL Queries', 'Advanced SQL Retrieval Queries in SQLiteStudio', 'Relational Database Support for Data Warehouses', 'Building Test Automation Framework - Selenium C# & NUnit', 'Data-Driven Testing (via spreadsheet) with Selenium & TestNG', 'Advanced TestNG Framework and Integration with Selenium', 'Introduction to Software Testing', 'Introduction to TestNG and Integration with Selenium', 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool', 'Business Strategy Business Model Canvas Analysis with Miro', 'Action-Driven Business Plan From the �Classroom� to the World', 'English for Effective Business Speaking', 'Managerial Economics and Business Analysis Capstone', 'Essentials of Entrepreneurship Thinking & Action', 'International Business Capstone', 'Programming Languages Part C', 'Programming Languages Part B', 'Functional Programming Principles in Scala', 'Introduction to Programming in Swift 5', 'Introduction to Programming and Animation with Alice', 'Functional Program Design in Scala', 'The Factors that Influence the Effectiveness of Boards and the Governance Process', 'Introduction to the Nonprofit Sector Nonprofit Organizations Nonprofit Leadership and Governance', 'Capstone - Managing Board Change for Higher Levels of Leadership and Governance Effectiveness', 'Time to Reorganize! Understand Organizations Act and Build a Meaningful World.', 'Managerial Accounting Tools for Facilitating and Guiding Business Decisions', 'International Organizations Management', 'Business Russian Communication. Part 2', 'Business Russian Communication. Part 1', 'Russian for beginners 3. ??????? ???? A1', 'Russian for beginners 2. ??????? ???? A1', 'Russian for beginners 1. ??????? ???? A1', 'Russian Alphabet', 'Agile Projects Develop Product Wireframe Prototypes in Miro', 'Agile Projects Defining Epics and Mapping Value with Taiga', 'Agile Projects Creating User Stories with Value in Taiga', 'IT Project Management', 'Product and Service Development Empathy Mapping with Miro', 'Product Development Customer Persona Development with Miro', 'Business Strategy in Practice (Project-centered Course)', 'Strategic Management - Capstone Project', 'Strategic Organization Design', 'Strategy Formulation', 'Procurement Basics', 'Fundamentals of Management', 'Web Application Security Testing with Burp Suite', 'Network Security & Database Vulnerabilities', 'Network Security & Database Vulnerabilities', 'Web Application Security Testing with OWASP ZAP', 'Advanced System Security Topics', 'Design and Analyze Secure Networked Systems', 'Statistics with R Capstone', 'Data Analysis and Reporting in SAS Visual Analytics', 'Increasing Real Estate Management Profits Harnessi ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
new = pd.DataFrame.from_dict(my_dict)

# %%
new
# Out:
#                                          Course_Name  \
# 0  Architecting with Google Kubernetes Engine Pro...
#
#                                Recommendation_Course
# 0  [Script Writing Write a Pilot Episode for a TV...

# %%
g = pd.Series(g)
g
# Out:
# 0        Product Development Customer Persona Developme...
# 1        Product and Service Development Empathy Mappin...
# 2        Product Development Customer Journey Mapping w...
# 3                Innovating with the Business Model Canvas
# 4        Analyzing Macro-Environmental Factors Using Cr...
#                                ...
# 42283    Architecting with Google Kubernetes Engine Fou...
# 42284        Getting Started with Google Kubernetes Engine
# 42285    Essential Google Cloud Infrastructure Core Ser...
# 42286    Essential Google Cloud Infrastructure Core Ser...
# 42287    Essential Google Cloud Infrastructure Core Ser...
# Length: 42288, dtype: object

# %%
new_df['Recommendation'] = g
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.sort_values('Course Rating', ascending = False)
# Out:
#                                             course_name  \
# 1154                      Build CRUD REST API in Django
# 593              Acing the Product Management Interview
# 2160   Conduct a Cost-Benefit Analysis in Google Sheets
# 3190  Computational Thinking for K-12 Educators Sequ...
# 2498  Edit Your Photos for Social Media Marketing us...
# ...                                                 ...
# 278                      Microservices with Spring Boot
# 2467  Predict Performance Using MA Forecasting in Go...
# 2469    How To Land the Job You Want (Capstone Project)
# 2470                            C++ Classes and Objects
# 544   Create an FPS Weapon in Unity (Part 2 - Firing...
#
#                                                    tags  Course Rating  \
# 1154  build crud rest api in djangointermediatein th...            5.0
# 593   ace the product manag interviewadvancedsponsor...            5.0
# 2160  conduct a cost-benefit analysi in googl sheets...            5.0
# 3190  comput think for k-12 educ sequenc and loopsad...            5.0
# 2498  edit your photo for social media market use pi...            5.0
# ...                                                 ...            ...
# 278   microservic with spring bootadvancedbi the end...            0.0
# 2467  predict perform use ma forecast in googl sheet...            0.0
# 2469  how to land the job you want (capston project)...            0.0
# 2470  c++ class and objectsconversantin thi project ...            0.0
# 544   creat an fp weapon in uniti (part 2 - fire eff...            0.0
#
#      Difficulty_Level                                     Recommendation
# 1154     Intermediate                      Introduction to Breast Cancer
# 593          Advanced                      Interactive Computer Graphics
# 2160         Beginner  Survey Data Collection and Analytics Project (...
# 3190         Advanced  Memoir and Personal Essay Managing Your Relati...
# 2498         Beginner  Materials Science 10 Things Every Engineer Sho...
# ...               ...                                                ...
# 278          Advanced                         iOS App Development Basics
# 2467         Beginner         Image Classification with CNNs using Keras
# 2469         Advanced  Traffic Sign Classification Using Deep Learnin...
# 2470       Conversant  Predicting House Prices with Regression using ...
# 544          Advanced        The People Power and Pride of Public Health
#
# [3522 rows x 5 columns]

# %%
import pickle

# %%
# pickle.dump(similarity,open('similarity.pkl','wb'))
# pickle.dump(new_df.to_dict(),open('course_list.pkl','wb')) #contains the dataframe in dict 
# pickle.dump(new_df,open('courses.pkl','wb'))

# %%
new_df.drop(columns = 'tags', inplace = True)
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
new_df.head()
# Out:
#                                          course_name  Course Rating  \
# 0  Write A Feature Length Screenplay For Film Or ...            4.8
# 1  Business Strategy Business Model Canvas Analys...            4.8
# 2                      Silicon Thin Film Solar Cells            4.1
# 3                               Finance for Managers            4.8
# 4       Retrieve Data using Single-Table SQL Queries            4.6
#
#   Difficulty_Level                                     Recommendation
# 0         Beginner  Script Writing Write a Pilot Episode for a TV ...
# 1         Beginner                             Write Your First Novel
# 2         Advanced                                 Transmedia Writing
# 3     Intermediate                     Songwriting Writing the Lyrics
# 4         Beginner                     Songwriting Writing the Lyrics

# %%
#pycaret setup
from pycaret.nlp import *
# clf = setup(data, target = 'Course_Name', session_id=562, silent = True)

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
# %time su_1 = setup(data = data, target = 'tags', session_id=21, custom_stopwords = stop_words)
# Out:
# <style  type="text/css" >
# </style><table id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5c" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow0_col1" class="data row0 col1" >21</td>
#             </tr>
#             <tr>
#                                 <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow1_col0" class="data row1 col0" >Documents</td>
#                         <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow1_col1" class="data row1 col1" >3522</td>
#             </tr>
#             <tr>
#                                 <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow2_col0" class="data row2 col0" >Vocab Size</td>
#                         <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow2_col1" class="data row2 col1" >13451</td>
#             </tr>
#             <tr>
#                                 <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow3_col0" class="data row3 col0" >Custom Stopwords</td>
#                         <td id="T_cc26e246_9a3c_11ec_865d_5c3a45ab6a5crow3_col1" class="data row3 col1" >True</td>
#             </tr>
#     </tbody></table>
# Wall time: 35.9 s

# %%
# %time m1 = create_model(model='lda', multi_core=True)
# Out:
# Wall time: 8.42 s

# %%
# %time lda_data = assign_model(m1)
# Out:
# IntProgress(value=0, description='Processing: ', max=3527)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      20:54:40
# Status     . . . . . . . . . . . . . . . . . .  Extracting Topics from Model
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
lda_data.head()
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...         Beginner
# 1  Business,Strategy,Business,Model,Canvas,Analys...         Beginner
# 2                      Silicon,Thin,Film,Solar,Cells         Advanced
# 3                               Finance,for,Managers     Intermediate
# 4       Retrieve,Data,using,Single-Table,SQL,Queries         Beginner
#
#                                   Course_Description  \
# 0  Write,a,Full,Length,Feature,Film,Script,In,thi...
# 1  By,the,end,of,this,guided,project,you,will,be,...
# 2  This,course,consists,of,a,general,presentation...
# 3  When,it,comes,to,numbers,there,is,always,more,...
# 4  In,this,course,you�ll,learn,how,to,effectively...
#
#                                               Skills  Course Rating  \
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona user experienc...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select sql  database management...            4.6
#
#                                                 tags   Topic_0   Topic_1  \
# 0  write feature length screenplay film full leng...  0.125215  0.001361
# 1  business strategy analysis mirobeginnerby end ...  0.959294  0.003691
# 2  film solar course consist general base silicon...  0.002133  0.840457
# 3  finance come number always meet eye operationa...  0.638714  0.352280
# 4  retrieve datum use single table sql course lea...  0.030134  0.001974
#
#     Topic_2   Topic_3 Dominant_Topic  Perc_Dominant_Topic
# 0  0.756583  0.116842        Topic 2                 0.76
# 1  0.003595  0.033420        Topic 0                 0.96
# 2  0.155332  0.002079        Topic 1                 0.84
# 3  0.004525  0.004481        Topic 0                 0.64
# 4  0.056641  0.911251        Topic 3                 0.91

# %%
plot_model()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="668d4ebf-f23b-4928-979a-7b50129f7961" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("668d4ebf-f23b-4928-979a-7b50129f7961")) {                    Plotly.newPlot(                        "668d4ebf-f23b-4928-979a-7b50129f7961",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","x":["course","learn","use","project","business","datum","design","science","management","analysis","model","create","development","also","system","computer","basic","learning","work","process","understand","strategy","skill","machine","programming","include","student","able","provide","application","language","software","develop","make","concept","base","health","help","tool","take","leadership","need","apply","experience","knowledge","build","information","data","new","well","explore","technology","web","end","different","learner","complete","program","part","specialization","practice","problem","marketing","security","method","research","introduce","world","technique","teach","write","key","product","way","first","focus","introduction","cover","communication","change","give","time","network","plan","human","people","finance","level","material","set","many","value","market","week","service","important","global","study","social","topic"],"y":[10136,4730,4234,2909,2901,2840,2379,2194,2153,1923,1656,1603,1579,1557,1522,1443,1326,1325,1310,1284,1283,1274,1263,1236,1228,1196,1189,1150,1149,1140,1124,1121,1119,1103,1091,1084,1063,1031,1031,1016,1002,996,994,982,969,969,955,922,902,897,871,870,855,855,837,831,830,814,804,798,783,741,739,726,722,716,711,702,689,684,683,676,674,673,660,655,648,641,641,623,621,619,617,604,595,593,591,585,583,573,570,564,558,551,546,545,539,538,536,530],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111 ...

# %%
lda2 = create_model('lda', num_topics = 6, multi_core = True)

# %%
print(lda2)
# Out:
# LdaModel(num_terms=13451, num_topics=6, decay=0.5, chunksize=100)

# %%
lda_results = assign_model(lda2)
lda_results.head()
# Out:
# IntProgress(value=0, description='Processing: ', max=3527)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      20:54:40
# Status     . . . . . . . . . . . . . . . . . .  Extracting Topics from Model
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# <==== Code starts here ====>

courses_list = load_model('course_list')
similarity = load_model('similarity')
courses = load_model('courses')
def recommend(course):
    index = courses_list[courses_list['course_name'] == course].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_course_names = []
    for i in distances[1:7]:
        course_name = courses_list.iloc[i[0]].course_name
        recommended_course_names.append(course_name)

    return recommended_course_names
# Out:
# Model Sucessfully Loaded
# Model Sucessfully Loaded
# Model Sucessfully Loaded

# %%
# course_list = courses_list['course_name'].values

# %%
courses_list
# Out:
# {'course_name': {0: 'Write A Feature Length Screenplay For Film Or Television',
#   1: 'Business Strategy Business Model Canvas Analysis with Miro',
#   2: 'Silicon Thin Film Solar Cells',
#   3: 'Finance for Managers',
#   4: 'Retrieve Data using Single-Table SQL Queries',
#   5: 'Building Test Automation Framework using Selenium and TestNG',
#   6: 'Doing Business in China Capstone',
#   7: 'Programming Languages Part A',
#   8: 'The Roles and Responsibilities of Nonprofit Boards of Directors within the Governance Process',
#   9: 'Business Russian Communication. Part 3',
#   10: 'Agile Projects Developing Tasks with Taiga',
#   11: 'Esports Management Capstone Project',
#   12: 'Hacking and Patching',
#   13: 'Business Statistics and Analysis Capstone',
#   14: 'Grab Data Fast with Vertical and Horizontal LOOKUP',
#   15: 'Global Health An Interdisciplinary Overview',
#   16: 'Python Programming Essentials',
#   17: 'Creating Dashboards and Storytelling with Tableau',
#   18: 'Parallel programming',
#   19: 'Recommendation Systems with TensorFlow on GCP',
#   20: 'The Changing Arctic',
#   21: 'COVID-19 - A clinical update',
#   22: 'How to Create Text Effects in GIMP',
#   23: 'Preparing for the Google Cloud Professional Data Engineer Exam',
#   24: 'Multiple Regression Analysis in Public Health',
#   25: 'General Pathophysiology',
#   26: 'Population Health Alternative Payment Models',
#   27: 'AWS Elastic Beanstalk Build & Deploy a Node.js RESTful API',
#   28: 'Philosophy Science and Religion Philosophy and Religion',
#   29: 'Poverty & Population How Demographics Shape Policy',
#   30: 'Electrodynamics Analysis of Electric Fields',
#   31: 'The Music of American English Pronunciation',
#   32: 'Fundamentals of Management',
#   33: 'Advanced Speaking and Listening Project',
#   34: 'Hybrid Cloud Service Mesh with Anthos',
#   35: 'Dealing With Missing Data',
#   36: 'COBOL Programming with VSCode',
#   37: 'Cryptography and Hashing Overview',
#   38: 'Postman - Intro to APIs (without coding)',
#   39: 'Protecting Business Innovations via Patent',
#   40: 'Real-time OCR and Text Detection with Tensorflow OpenCV and Tesseract',
#   41: 'Global Strategy I How The Global Economy Works',
#   42: 'Disability Inclusion in Education Building Systems of Support',
#   43: 'Introduction to Cybersecurity Tools & Cyber Attacks',
#   44: 'Introduction to Cybersecurity Tools & Cyber Attacks',
#   45: 'Fundamentals of Funding with Goldman Sachs 10 000 Women',
#   46: 'Foundations of Objective-C App Development',
#   47: 'Programming Mobile Applications for Android Handheld Systems Part 2',
#   48: 'Analyzing Market Attractiveness Using Creately',
#   49: 'Personal Leadership Development Planning and Leading High Performing Teams',
#   50: 'Integrating Scripts for Scene Interactions',
#   51: 'Voices of Social Change',
#   52: 'Managing Asthma Allergies Diabetes and Seizures in School',
#   53: 'Global Challenges in Business Capstone',
#   54: 'Severe to Profound Intellectual Disability Circles of Care and Education',
#   55: 'Teaching Children with Visual Impairment Creating Empowering Classrooms',
#   56: 'Intercultural Communication and Conflict Resolution',
#   57: 'Prediction and Control with Function Approximation',
#   58: 'Advanced Neurobiology I',
#   59: 'Foundations of Teaching for Learning Introduction',
#   60: 'Change Leadership Developing Force Field Analysis in Miro',
#   61: 'Lesson | Telephone Language',
#   62: 'Python Tricks and Hacks for Productivity',
#   63: 'Privacy in the USA',
#   64: 'Japanese for beginners 2',
#   65: 'Introduction to Recommender Systems Non-Personalized and Content-Based',
#   66: 'Global Disease Masterclass Global Disease Distribution',
#   67: 'Age of Cathedrals',
#   68: 'Smart Contracts',
#   69: 'Create an FPS Weapon in Unity (Part 1 - Revolver)',
#   70: 'Homeland Security and Cybersecurity Future',
#   71: 'Healthcare Consumerism and Implication for Care Delivery',
#   72: 'Magna Carta and its Legacies Freedom and protest',
#   73: 'Converter Circuits',
#   74: 'Predictive Modeling and Analytics',
#   75: 'Animals and Institutions',
#   76: 'ART of the MOOC Public Art and Pedagogy',
#   77: 'Genetics and Society A Course for Educators',
#   78: 'Russian History from Lenin to Putin',
#   79: 'Packet Switching Networks and Algorithms',
#   80: 'Transgender Medicine for General Medical Providers',
#   81: 'Epigenetic Control of Gene Expression',
#   82: 'Successful Interviewing',
#   83: 'The hidden value � Lean in manufacturing and services',
#   84: 'Mastering SQL Joins',
#   85: 'Create a Database with the Modeling Tool in MySQL Workbench',
#   86: 'Project Planning and Machine Learning',
#   87: 'Build Random Forests in R with Azure ML Studio',
#   88: 'Introduction to CAD CAM and Practical CNC Machining',
#   89: 'Problem Solving Using Computational Thinking',
#   90: 'Surveillance Systems Analysis Dissemination and Special Systems',
#   91: 'Control physics with C# in Unity',
#   92: 'Create Relational Database Tables Using SQLiteStudio',
#   93: 'Spacecraft Dynamics Capstone Mars Mission',
#   94: 'Guided Imagery',
#   95: 'Making Architecture',
#   96: 'Building Resilient Streaming Analytics Systems on GCP',
#   97: 'Types of Conflict',
#   98: 'Product Design Designing a modern table lamp using SketchUp',
#   99: 'Beyond the Sustainable Development Goals (SDGs) Addressing Sustainability and Development',
#   100: 'The New Nordic Diet - from Gastronomy to Health',
#   101: 'Voice Disorders What Patients and Professionals Need to Know',
#   102: 'Teaching Tips for Tricky English Grammar',
#   103: 'Learn to Teach Java  Boolean Expressions If Statements and Iteration',
#   104: 'Business Writing',
#   105: 'Cyber Threats and Attack Vectors',
#   106: 'Build a Table Layout App in Android Studio',
#   107: 'Introduction to Genomic Technologies',
#   108: 'Designing for Sustainment Keeping Improvement Work on Track (Patient Safety IV)',
#   109: 'Big data and Language 2',
#   110: 'Understanding the Australian economy An introduction to macroeconomic and financial policies',
#   111: 'Bayesian Statistics Mixture Models',
#   112: 'Networking and Security in iOS Applications',
#   113: 'Improving Math Engagement with Prodigy',
#   114: 'Molecular Evolution (Bioinformatics IV)',
#   115: 'Exception Handling in Python',
#   116: 'FinTech Foundations and Overview',
#   117: 'Information & Digital Literacy for University Success',
#   118: 'Improving Classroom Management with Class Dojo',
#   119: 'Managing Big Data with MySQL',
#   120: 'Risk Return & Valuation',
#   121: 'Managing Employee Performance',
#   122: 'Channel Management and Retailing',
#   123: 'Entrepreneurship II Preparing for Launch',
#   124: 'World Design for Video Games',
#   125: 'Mathematics for Machine Learning Linear Algebra',
#   126: 'Free Speech on Campus Teach-Out',
#   127: 'Real-Time Embedded Systems Concepts and Practices',
#   128: 'Create a Virtual Classroom using Google Slides',
#   129: 'Security and Privacy for Big Data - Part 1',
#   130: 'Disinformation Misinformation and Fake News Teach-Out',
#   131: 'Teaching Intermediate Grammar Project',
#   132: 'Introduction to Acoustics (Part 2)',
#   133: 'Qualitative Research Methods',
#   134: 'The Rooseveltian Century',
#   135: 'Analysis for Business Systems',
#   136: 'Implementing SOLID Principles in C# with .NET Core',
#   137: 'History of Rock Part Two',
#   138: 'Device-based Models with TensorFlow Lite',
#   139: 'Wireshark for Basic Network Security Analysis',
#   140: 'Advanced Practice Provider/Physician Assistant Opioid Use Disorder Medication Assisted Treatment Waiver Training (24hr)',
#   141: 'Setting Expectations & Assessing Performance Issues',
#   142: 'Tracking Student Growth using Google Slides',
#   143: "The Teacher's Social and Emotional Learning",
#   144: 'Beyond Silicon Valley Growing Entrepreneurship in Transitioning Economies',
#   145: 'The fundamentals of hotel distribution',
#   146: 'Marketing in a Digital World',
#   147: 'Bugs 101 Insect-Human Interactions',
#   148: 'Analyze Website Visitors with Google Analytics Segments',
#   149: 'Scandinavian Film and Television',
#   150: 'Modern American Poetry',
#   151: 'Textual Elements of Design Fonts Typography and Spacing',
#   152: 'Marketing Analytics Capstone Project',
#   153: 'Tell the Data Story with Survey Graphics in Google Slides',
#   154: 'Musicianship Tensions Harmonic Function and Modal Interchange',
#   155: 'User Experience Responsive Hero in XD for Beginners',
#   156: 'Internet History Technology and Security',
#   157: 'Securing Digital Democracy',
#   158: 'Guided Imagery',
#   159: 'Teach English Now! Capstone Project 1',
#   160: 'Teach English Now! Capstone Project 1',
#   161: 'Our Energy Future',
#   162: 'Penetration Testing Incident Response and Forensics',
#   163: 'Building Resilient Streaming Analytics Systems on GCP',
#   164: 'Web Application Development with JavaScript and MongoDB',
#   165: 'Teaching Impacts of Technology Global Society',
#   166: 'Subsistence Marketplaces',
#   167: 'Introduction to Game Design',
#   168: 'Business Process Management in Healthcare Organizations',
#   169: 'Career Planning A Pathway to Employment',
#   170: 'Marketing Strategy for Entrepreneurs',
#   171: 'Sleep Neurobiology Medicine and Society',
#   172: 'Building Containerized Applications on AWS',
#   173: 'Engagement & Nurture Marketing Strategies',
#   174: 'When Disaster Meets Conflict',
#   175: 'Introduction to Git and GitHub',
#   176: 'Palo Alto Networks Cybersecurity Essentials II',
#   177: 'Introduction to the Internet of Things and Embedded Systems',
#   178: 'Using Python to Interact with the Operating System',
#   179: 'Portfolio Optimization using Markowitz Model',
#   180: 'Securing and Integrating Components of your Application',
#   181: 'Construction Finance',
#   182: 'The Finite Element Method for Problems in Physics',
#   183: 'Russian company law. Formation of legal entities.',
#   184: 'Forensic Accounting and Fraud Examination',
#   185: 'Data Analytics Foundations for Accountancy I',
#   186: 'Complex Retrieval Queries in MySQL Workbench',
#   187: 'Standardisation & Technology',
#   188: 'Precalculus Mathematical Modeling',
#   189: 'Account Management & Sales Force Design',
#   190: 'Business Implications of AI A Nano-course',
#   191: 'Taxation of Business Entities II Pass-Through Entities',
#   192: 'Cancer Prevention Web-Based Activity',
#   193: 'Engineering Design Process with Autodesk Fusion 360',
#   194: 'Genomics for Law',
#   195: 'Master Class for Corporate Entrepreneurs',
#   196: 'AWS Elastic BeanstalkDeploy a Python(Flask) Web Application',
#   197: 'Fundamentals of Business Finance with Goldman Sachs 10 000 Women',
#   198: 'Data Science in Stratified Healthcare and Precision Medicine',
#   199: 'International Cyber Conflicts',
#   200: 'App Design and Development for iOS',
#   201: 'Introduction to the Arctic Climate',
#   202: 'Introduction to Programming with MATLAB',
#   203: 'Pharmaceutical and Medical Device Innovations',
#   204: 'Software Product Management Capstone',
#   205: 'Data-driven Astronomy',
#   206: 'Basics of Inclusive Design for Online Education',
#   207: 'Making Successful Decisions through the Strategy Law & Ethics Model',
#   208: 'Achieving Advanced Insights with BigQuery',
#   209: 'Exploring Beethoven�s Piano Sonatas',
#   210: 'Text Retrieval and Search Engines',
#   211: 'Build a Twitter Clone Backend',
#   212: 'Introduction to Ableton Live',
#   213: 'Introduction to Ableton Live',
#   214: 'Environmental Management & Ethics',
#   215: 'Create a Buy Signal using RSI in R with the Quantmod Package',
#   216: 'Seeing Through Photographs',
#   217: 'Ebola Essential Knowledge for Health Professionals',
#   218: 'Excel Skills for Business Intermediate II',
#   219: 'Understanding China 1700-2000 A Data Analytic Approach Part 1',
#   220: 'Statistical Data Visualization with Seaborn',
#   221: 'Professional Responsibility and Ethics for Accountants',
#   222: 'Technical Writing',
#   223: 'Hosting a Static Website (HTML/CSS/Javascript) in AWS S3',
#   224: 'Project Management The Basics for Success',
#   225: "API Design and Fundamentals of Google Cloud's Apigee API Platform",
#   226: 'Data Analysis Using Pyspark',
#   227: 'Introduction to Environmental Law and Policy',
#   228: 'FPGA computing systems Background knowledge and introductory materials',
#   229: 'Researcher Management and Leadership Training',
#   230: 'Introduction to TestNG and Integration with Selenium',
#   231: 'Food & Beverage Management',
#   232: 'Reproducible Research',
#   233: 'Reproducible Research',
#   234: 'Cyber Attack Countermeasures',
#   235: 'Matrix Methods',
#   236: 'Penetration Testing Incident Response and Forensics',
#   237: "Easing Physical Symptoms It's Not Just Hospice Anymore",
#   238: 'Hierarchical Clustering Customer Segmentation',
#   239: 'Applied Plotting Charting & Data Representation in Python',
#   240: 'Deploy Models with TensorFlow Serving and Flask',
#   241: 'Sport Sponsorship. Let them Play',
#   242: 'Strategies for Teaching Perfect Tenses and Modals',
#   243: 'Building Cloud Services with the Java Spring Framework',
#   244: 'Social Media Management',
#   245: 'Successful Career Development',
#   246: 'Design Patterns',
#   247: 'Psychology of Popularity',
#   248: 'Collaborative Foresight How to Game the Future',
#   249: 'Create UI in Unity Part 3 - Settings Menu',
#   250: 'Autodesk Certified Professional Inventor for Mechanical Design Exam Prep',
#   251: 'Urban Nature Connecting Cities Nature and Innovation',
#   252: 'Content Strategy for Professionals Expanding Your Content�s Reach',
#   253: 'Advanced Search Engine Optimization Strategies',
#   254: 'Experimental Design Basics',
#   255: 'The Art of Music Production',
#   256: 'The Art of Music Production',
#   257: 'Leading Positive Change through Appreciative Inquiry',
#   258: 'Sales Training Techniques for a Human-Centric Sales Process',
#   259: 'Doing Clinical Research Biostatistics with the Wolfram Language',
#   260: 'Quantitative Research',
#   261: 'Create Informative Presentations with Google Slides',
#   262: 'Introduction to Biomedical Engineering',
#   263: 'Introduction to Accounting Data Analytics and Visualization',
#   264: 'Manufacturing Process with Autodesk Fusion 360',
#   265: 'Introduction to Game Development',
#   266: 'Getting started in cryo-EM',
#   267: 'Java for Android',
#   268: 'Public Economics',
#   269: 'Introduction to Algae',
#   270: 'A Journey through Western Christianity from Persecuted Faith to Global Religion (200 - 1650)',
#   271: 'Game-Theoretic Solution Concept with Spread Sheets',
#   272: 'Survival Analysis in R for Public Health',
#   273: 'Collegiate Esports and Career Planning',
#   274: 'Learn to Program Crafting Quality Code',
#   275: 'Materials Data Sciences and Informatics',
#   276: 'Nutrition and Lifestyle in Pregnancy',
#   277: 'Sustainable Agricultural Land Management',
#   278: 'Microservices with Spring Boot',
#   279: 'Lecture Series for Preventing and Controlling COVID-19',
#   280: 'The Dynamic Earth A Course for Educators',
#   281: 'Requirements Specifications Goals and Conflict Analysis',
#   282: 'Marketing Design with Easil',
#   283: 'Hands-on Text Mining and Analytics',
#   284: 'Statistical Mechanics Algorithms and Computations',
#   285: 'Introduction to Data Analysis Using Excel',
#   286: 'The Place of Music in 21st Century Education',
#   287: 'Developing AI Applications on Azure',
#   288: 'Hiring and Onboarding Employees with ClickUp',
#   289: 'African cities  An Introduction to Urban Planning',
#   290: 'iOS Project Transreality Game',
#   291: 'Designing Your Personal Weight Loss Plan',
#   292: 'Advanced Writing',
#   293: 'Doping  Sports Organizations and Sciences',
#   294: 'Introduction to Python',
#   295: 'Challenges of Agribusiness Management',
#   296: 'Cost and Economics in Pricing Strategy',
#   297: 'Economic Growth and Distributive Justice Part I -The Role of the State',
#   298: 'Encryption And Decryption Using C++',
#   299: 'Real-Time Mission-Critical Systems Design',
#   300: 'Android App Components - Services Local IPC and Content Providers',
#   301: 'VR and 360 Video Production',
#   302: 'RPA Lifecycle Development and Testing',
#   303: 'Methods of Surface Analysis',
#   304: 'Startups in open innovation',
#   305: 'Python Data Structures',
#   306: 'Blockchain Cryptoassets and Decentralized Finance',
#   307: 'Data Processing Using Python',
#   308: 'International Law in Action the Arbitration of International Disputes',
#   309: 'Applied Text Mining in Python',
#   310: 'Engaging ELLs and Their Families in the School and Community',
#   311: 'Serve Scikit-Learn Models for Deployment with BentoML',
#   312: 'Making Sense of the News News Literacy Lessons for Digital Citizens',
#   313: 'Astro 101 Black Holes',
#   314: 'Patenting in Biotechnology',
#   315: 'Evaluating Designs with Users',
#   316: 'Capstone Project � Analyzing a Real Transaction',
#   317: 'Create Charts and Dashboard using Google Sheets',
#   318: 'Use Commands and Create a Remote Git Repository',
#   319: 'Advanced Modeling for Discrete Optimization',
#   320: 'Command Line in Linux',
#   321: 'Principles of Secure Coding',
#   322: 'Introduction to Public Health Engineering in Humanitarian Contexts',
#   323: 'The Development of Mobile Health Monitoring Systems',
#   324: '3D Printing Software',
#   325: 'Building Web Applications in Django',
#   326: 'Building Custom Regional Reports with Google Analytics',
#   327: 'Developing a Google SRE Culture',
#   328: 'Conflict Resolution Skills',
#   329: 'Building a Data Science Team',
#   330: 'S�ren Kierkegaard - Subjectivity Irony and the Crisis of Modernity',
#   331: 'Design Thinking and Global Startup',
#   332: 'Design and Analyze Secure Networked Systems',
#   333: 'Mechanics Motion Forces Energy and Gravity from Particles to Planets',
#   334: 'Predictive Analytics and Data Mining',
#   335: 'Anatomy of the Chest Abdomen and Pelvis',
#   336: 'Database Design and Diagramming in Dia',
#   337: 'A Complete Reinforcement Learning System (Capstone)',
#   338: 'Private Equity and Venture Capital',
#   339: 'Memoir and Personal Essay Managing Your Relationship with the Reader',
#   340: 'Fundamentals of Immunology T Cells and Signaling',
#   341: 'Game Theory with Python',
#   342: 'Data Science at Scale - Capstone Project',
#   343: 'Social Media Advertising',
#   344: 'Photography Capstone Project',
#   345: 'The Wonders and Challenges of Bible Education',
#   346: 'Functions Methods and Interfaces in Go',
#   347: 'Search Advertising',
#   348: 'On Strategy  What Managers Can Learn from Philosophy - PART 1',
#   349: 'Introduction to Big Data',
#   350: "H�tel �De l'�toile� - a hotel in crisis?",
#   351: 'Leading People and Teams Capstone',
#   352: 'Corporate Finance I Measuring and Promoting Value Creation',
#   353: 'TCP/IP and Advanced Topics',
#   354: 'Natural Language Processing with Probabilistic Models',
#   355: 'Renewable Energy and Green Building Entrepreneurship',
#   356: 'Surveillance Systems The Building Blocks',
#   357: 'Anticipating Your Next Battle in Business and Beyond',
#   358: 'Getting Started With Application Development',
#   359: 'Global Arctic',
#   360: 'Sampling People Networks and Records',
#   361: 'Mindware Critical Thinking for the Information Age',
#   362: 'Precision Medicine',
#   363: 'Data Science Math Skills',
#   364: 'Digital Marketing Capstone',
#   365: 'Understanding Plants - Part II Fundamentals of Plant Biology',
#   366: 'Linux Tools for Developers',
#   367: 'Women in Leadership Inspiring Positive Change',
#   368: 'Hadoop Platform and Application Framework',
#   369: 'Career 911 Your Future Job in Medicine and Healthcare',
#   370: 'Business Application of Machine Learning and Artificial Intelligence in Healthcare',
#   371: 'Journeys to Education Teach-Out',
#   372: 'The Product Lifecycle A Guide from start to finish',
#   373: 'Startup Valuation Methods',
#   374: 'Innovation & Entrepreneurship - From Design Thinking to Funding',
#   375: 'TensorFlow for CNNs Transfer Learning',
#   376: 'Introduction to Probability and Data with R',
#   377: 'Calculating Descriptive Statistics in R',
#   378: 'Leadership Through Design Innovation',
#   379: 'Planning Auditing and Maintaining Enterprise Systems',
#   380: 'Creating Models using Smartpls',
#   381: 'Big History Connecting Knowledge',
#   382: 'Algorithms for DNA Sequencing',
#   383: 'Bioinformatics Introduction and Methods ????? ?????',
#   384: 'Introduction to Machine Learning',
#   385: 'Autodesk Certified Professional Civil 3D for Infrastructure Design Exam Prep',
#   386: 'Understanding International Relations Theory',
#   387: 'Bioinformatic Methods I',
#   388: 'Getting Started With Game Development Using PyGame',
#   389: 'Introduction to Social Media Marketing',
#   390: 'Understanding China 1700-2000 A Data Analytic Approach Part 2',
#   391: 'Advanced Data Structures in Java',
#   392: 'Introduction to Javascript The Basics',
#   393: 'Value Creation The Carlson-Polizzotto Method',
#   394: 'SEL for Students A Path to Social Emotional Well-Being',
#   395: 'Production Machine Learning Systems',
#   396: 'Introduction to Cost Accounting',
#   397: 'Converting Challenges into Opportunities',
#   398: 'Emerging Trends & Technologies in the Virtual K-12 Classroom',
#   399: 'Neurolinguistics',
#   400: 'Basic Modeling for Discrete Optimization',
#   401: 'Computational Vision',
#   402: 'Troubleshooting and Debugging Techniques',
#   403: 'Classify Radio Signals from Space using Keras',
#   404: 'Industrial Biotechnology',
#   405: 'Data Visualization and Communication with Tableau',
#   406: 'Relational database systems',
#   407: 'Getting Started with Power BI Desktop',
#   408: 'Sequences Time Series and Prediction',
#   409: 'Digital Thread Implementation',
#   410: 'IBM Data Topology',
#   411: 'Build a Deep Learning Based Image Classifier with R',
#   412: 'Machine Learning Clustering & Retrieval',
#   413: 'Global Health Security Solidarity and Sustainability through the International Health Regulations',
#   414: 'Preparing for the Google Cloud Professional Cloud Architect Exam',
#   415: 'Patient Safety and Quality Improvement Developing a Systems View (Patient Safety I)',
#   416: 'Material Processing',
#   417: 'Recommender Systems Capstone',
#   418: 'Positive Psychiatry and Mental Health',
#   419: 'Finance for Non-Financial Managers',
#   420: 'Convolutional Neural Networks in TensorFlow',
#   421: 'Soul Beliefs Causes and Consequences - Unit 2 Belief Systems',
#   422: 'Agile Projects Creating User Stories with Value in Taiga',
#   423: 'Social Pedagogy across Europe',
#   424: 'Security and Privacy for Big Data - Part 2',
#   425: 'Corporate Sustainability. Understanding and Seizing the Strategic Opportunity',
#   426: 'Hearing Loss in Children',
#   427: 'Scaling Operations Linking Strategy and Execution',
#   428: 'Introduction to Human Behavioral Genetics',
#   429: 'Gathering and Developing the News',
#   430: 'Healthcare Data Models',
#   431: "Biohacking Your Brain's Health",
#   432: 'Cybersecurity and the X-Factor',
#   433: 'Nanotechnology and Nanosensors Part1',
#   434: 'Capstone MOOC for "Android App Development"',
#   435: "Meeting Investors' Goals",
#   436: 'Digital Media and Marketing Principles',
#   437: 'Digital Signal Processing 4 Applications',
#   438: 'Introduction to solar cells',
#   439: 'Mind Control Managing Your Mental Health During COVID-19',
#   440: 'Getting Started with AWS Machine Learning',
#   441: 'Essentials of Corporate Finance Capstone',
#   442: 'Software Design as an Abstraction',
#   443: 'Modern Robotics Course 3 Robot Dynamics',
#   444: 'Frozen in the Ice Exploring the Arctic',
#   445: 'Be Your Best Creative Self',
#   446: 'Weight Management Beyond Balancing Calories',
#   447: 'The Fall and Rise of Jerusalem',
#   448: 'Hardware Description Languages for FPGA Design',
#   449: 'Hyperparameter Tuning with Neural Network Intelligence',
#   450: 'Reinforcement Learning for Trading Strategies',
#   451: 'State Estimation and Localization for Self-Driving Cars',
#   452: 'Business English Capstone Project',
#   453: 'Differential Equations for Engineers',
#   454: 'AstroTech The Science and Technology behind Astronomical Discovery',
#   455: 'Learn to Teach Java ArrayLists and 2D Arrays',
#   456: 'Optimizing Your Google Cloud Platform (GCP) Costs',
#   457: 'Python Project pillow tesseract and opencv',
#   458: 'Chemistry',
#   459: 'Detecting and Mitigating Cyber Threats and Attacks',
#   460: 'Programming for Everybody (Getting Started with Python)',
#   461: 'Trading Basics',
#   462: 'Fundamentals of Fluid-Solid Interactions',
#   463: 'Solving Complex Problems Capstone',
#   464: 'Easing the burden of obesity diabetes and cardiovascular disease',
#   465: 'Ecological and Energy Transitions in Southern Countries',
#   466: 'Transforming Communities',
#   467: 'Foundations of Teaching for Learning Developing Relationships',
#   468: 'Data Management for Clinical Research',
#   469: 'The Art of Music Production',
#   470: 'The Art of Music Production',
#   471: 'Discounted Cash Flow Modeling',
#   472: 'Code Yourself! An Introduction to Programming',
#   473: 'Understanding Medical Research Your Facebook Friend is Wrong',
#   474: "Recovering the Humankind's Past and Saving the Universal Heritage",
#   475: 'The Newborn Assessment',
#   476: 'Cloud Computing Basics (Cloud 101)',
#   477: 'Images and Links in HTML',
#   478: 'EDIVET Do you have what it takes to be a veterinarian?',
#   479: 'Foundations of Public Health Practice The Public Health Approach',
#   480: 'Analyze Text Data with Yellowbrick',
#   481: 'Intellectual Change in Early China Warring States and Han',
#   482: 'Literacy Teaching and Learning Aims Approaches and Pedagogies',
#   483: 'Russian for beginners 1. ??????? ???? A1',
#   484: 'Draw Insights with Crosstabs Reports in Google Sheets',
#   485: 'Understanding Russians Contexts of Intercultural Communication',
#   486: 'Class Creation in Object Oriented Python',
#   487: 'Discrete Mathematics',
#   488: 'Teaching Impacts of Technology Fundamentals',
#   489: 'Fundamentals of Negotiation with Goldman Sachs 10 000 Women',
#   490: 'Introduction to TensorFlow',
#   491: 'Palo Alto Networks Academy Cybersecurity Foundation',
#   492: 'Building an Ecosystem model with Insight Maker',
#   493: 'History of Medical Cannabis',
#   494: 'Advanced Grammar & Punctuation Project',
#   495: 'Create Employee Management System with When I Work',
#   496: 'Practical Machine Learning',
#   497: 'Practical Machine Learning',
#   498: 'Web Application Security Testing with OWASP ZAP',
#   499: 'Teaching Character and Creating Positive Classrooms',
#   500: 'Front-End JavaScript Frameworks Angular',
#   501: 'Developing the Opportunity for Corporate Entrepreneurs',
#   502: 'TensorFlow for AI Get to Know Tensorflow',
#   503: 'Software Processes and Agile Practices',
#   504: 'Brand Management Aligning Business Brand and Behaviour',
#   505: "On Premises Installation and Fundamentals with Google Cloud's Apigee API Platform",
#   506: 'Business Intelligence Concepts Tools and Applications',
#   507: 'Cybersecurity and Mobility',
#   508: 'Create UI in Unity Part 1 - Screen Overlay Canvas',
#   509: 'Organisational behaviour Know your people',
#   510: 'Chemerinsky on Constitutional Law � Individual Rights and Liberties',
#   511: 'Create Power-Ups and Obstacles with C# in Unity',
#   512: 'Supply Chain Management A Learning Perspective',
#   513: 'Linear Circuits 1 DC Analysis',
#   514: '3D Printing Applications',
#   515: 'Intro to Scheduling with When I Work',
#   516: 'Understanding the Brain The Neurobiology of Everyday Life',
#   517: 'Image Compression and Generation using Variational Autoencoders in Python',
#   518: 'American Deaf Culture',
#   519: 'Optimize TensorFlow Models For Deployment with TensorRT',
#   520: 'Non-Communicable Diseases in Humanitarian Settings',
#   521: 'Reliable Google Cloud Infrastructure Design and Process',
#   522: 'Healthcare Organizations and the Health System',
#   523: 'Financing Infrastructure in African Cities',
#   524: 'Visual Machine Learning with Yellowbrick',
#   525: 'Create a Memory Puzzle Game in Python Using Pygame',
#   526: 'Responsive Website Basics Code with HTML CSS and JavaScript',
#   527: 'Age of Jefferson',
#   528: 'Children Acquiring Literacy Naturally',
#   529: 'Practical Time Series Analysis',
#   530: 'Mathematical Thinking in Computer Science',
#   531: 'Writing and Editing Word Choice and Word Order',
#   532: 'Tableau Public for Project Management and Beyond',
#   533: 'Automating Real-World Tasks with Python',
#   534: 'Internet of Things Communication Technologies',
#   535: 'Writing in First Person Point of View',
#   536: 'Fundamentals of Visualization with Tableau',
#   537: 'Building Modern Java Applications on AWS',
#   538: 'Building Your Career in Music Developing A Brand and Funding Your Music',
#   539: 'Power Onboarding',
#   540: 'Introduction to Cloud Identity',
#   541: 'Bayesian Statistics From Concept to Data Analysis',
#   542: 'Creating Custom Callbacks in Keras',
#   543: 'Cybersecurity and the Internet of Things',
#   544: 'Create an FPS Weapon in Unity (Part 2 - Firing Effects)',
#   545: 'Intimacy of Creativity Entering the Minds of Composers',
#   546: 'Understanding child development from synapse to society',
#   547: 'Doing Business in Europe',
#   548: 'Python Programming A Concise Introduction',
#   549: 'My Favorite Lectures @ HKUST',
#   550: 'Performing Data Definition and Manipulation in SQL',
#   551: 'Object Oriented Programming in Java',
#   552: 'Object Oriented Programming in Java',
#   553: "Children's Human Rights - An Interdisciplinary Introduction",
#   554: 'Data Management and Visualization',
#   555: 'Improving Your Statistical Questions',
#   556: 'Business Transformation with Google Cloud',
#   557: 'Inspiring and Motivating Individuals',
#   558: 'Android App Components - Intents Activities and Broadcast Receivers',
#   559: 'Averaged-Switch Modeling and Simulation',
#   560: 'Compare time series predictions of COVID-19 deaths',
#   561: 'Scheduling Selenium TestNG tests via Jenkins CI/CD tool',
#   562: 'Build a Simple App in Android Studio with Java',
#   563: 'Circadian clocks how rhythms structure life',
#   564: 'Conversational English Skills',
#   565: 'Analysis of Business Problems',
#   566: 'Inferential Statistical Analysis with Python',
#   567: 'Create Interactive Dashboards with Streamlit and Python',
#   568: 'Biochemical Principles of Energy Metabolism',
#   569: 'Global Statistics - Composite Indices for International Comparisons',
#   570: 'Blockchain Opportunities Beyond Crypto Assets',
#   571: 'Interpersonal Developmental and Evolutionary Perspectives of the Mind',
#   572: 'Accounting Analysis I The Role of Accounting as an Information System',
#   573: 'Advanced Functional Ceramics',
#   574: 'Solving Algorithms for Discrete Optimization',
#   575: 'Build A Google Firebase Web App (Part II)',
#   576: 'Getting Started with R',
#   577: 'JavaScript Strings Properties and Methods',
#   578: 'Coaching Practices',
#   579: 'Java Inheritance Composition and Aggregation',
#   580: 'Element Class and ID Selectors in CSS',
#   581: 'Aromatherapy Clinical Use of Essential Oils',
#   582: 'Aromatherapy Clinical Use of Essential Oils',
#   583: 'Avatar Psychology for Designers',
#   584: 'Effective Altruism',
#   585: 'I/O-efficient algorithms',
#   586: 'TensorFlow for AI Computer Vision Basics',
#   587: 'Diabetes � the Essential Facts',
#   588: 'Lesson | Video Conferencing Face to Face but Online',
#   589: 'Fundamentals of Operations with Goldman Sachs 10 000 Women',
#   590: 'Corporate finance Know your numbers 2',
#   591: 'Management of Fashion and Luxury Companies',
#   592: 'Geopolitics of Europe',
#   593: 'Acing the Product Management Interview',
#   594: 'Living with Dementia Impact on Individuals Caregivers Communities and Societies',
#   595: 'Annual Campaigns Building a Case for Support',
#   596: 'Sustainable Tourism � promoting environmental public health',
#   597: 'Cloud Applications',
#   598: 'Approaching Music Theory Melodic Forms and Simple Harmony',
#   599: 'Blockchain Business Models',
#   600: 'More Chinese for Beginners',
#   601: 'Conduct Sales Projections with Seasonality in Google Sheets',
#   602: 'Practical Predictive Analytics Models and Methods',
#   603: 'Predict Sales Revenue with scikit-learn',
#   604: 'Introduction to Research for Essay Writing',
#   605: 'Transmedia Storytelling Narrative worlds emerging technologies and global audiences',
#   606: 'Python Basics Create a Guessing Number Game from Scratch',
#   607: 'Data Science Ethics',
#   608: 'Autism Spectrum Disorder',
#   609: 'Single Page Web Applications with AngularJS',
#   610: 'Major Engineering Project Performance',
#   611: 'Network Security & Database Vulnerabilities',
#   612: 'Computational Neuroscience',
#   613: 'Asian Environmental Humanities Landscapes in Transition',
#   614: 'Writing in English at University',
#   615: 'Structuring Machine Learning Projects',
#   616: 'Critical Perspectives on Management',
#   617: 'RESTful API with HTTP and JavaScript',
#   618: 'Professionalism in an era of change',
#   619: 'Climate Adaptation for Human Health',
#   620: 'Physics 101 - Forces and Kinematics',
#   621: 'Print and Digital Elements of Design Branding and User Experience',
#   622: 'Construction Project Management',
#   623: 'Parallel Programming in Java',
#   624: 'Digitalisation in the Aerospace Industry',
#   625: 'Business English Networking',
#   626: 'Chosen Issues in Holocaust History',
#   627: 'Agile Meets Design Thinking',
#   628: 'Econometrics Methods and Applications',
#   629: 'Object-Oriented Data Structures in C++',
#   630: 'Create a Google Ads Search Campaign',
#   631: 'Capstone Create your own professional journalistic portfolio',
#   632: 'Foundations of marketing analytics',
#   633: 'Queering the Schoolhouse LGBTQ+ Inclusion for Educators',
#   634: 'Water Supply and Sanitation Policy in Developing Countries Part 2 Developing Effective Interventions',
#   635: 'Exploratory Data Analysis',
#   636: 'Exploratory Data Analysis',
#   637: 'Organ Donation From Death to Life',
#   638: 'Introduction to English Common Law',
#   639: 'Models & Frameworks to Support Sales Planning',
#   640: 'Construction Cost Estimating and Cost Control',
#   641: 'Stalin and Stalinism in Russian History',
#   642: 'Introduction to Systems Engineering',
#   643: 'Modern Robotics Course 4 Robot Motion Planning and Control',
#   644: 'DDoS Attacks and Defenses',
#   645: 'Motors and Motor Control Circuits',
#   646: 'Finance for Non-Financial Professionals',
#   647: 'Transfer Learning for Food Classification',
#   648: 'Social Marketing Capstone Project',
#   649: 'The Social and Technical Context of Health Informatics',
#   650: 'Write Professional Emails in English',
#   651: 'Software Architecture',
#   652: 'Ethical Social Media',
#   653: 'Coding for Designers Managers & Entrepreneurs II',
#   654: 'Fundamentals of Graphic Design',
#   655: 'Faster Together Enhancing the Recruitment of Minorities in Clinical Trials',
#   656: 'What does it mean to identify as Transgender or Gender Non-Conforming (TGNC)?',
#   657: 'Detecting COVID-19 with Chest X-Ray using PyTorch',
#   658: 'Social Business Model and Planning for Social Innovation',
#   659: 'Six Sigma Advanced Analyze Phase',
#   660: 'Information Visualization Applied Perception',
#   661: 'Country Level Economics Policies Institutions and Macroeconomic Performance',
#   662: 'Developing FPGA-accelerated cloud applications with SDAccel Theory',
#   663: 'Web Application Technologies and Django',
#   664: "Our Earth's Future",
#   665: 'Inspiring Leadership through Emotional Intelligence',
#   666: 'Humanitarian communication  Addressing key challenges',
#   667: 'Antimicrobial resistance - theory and methods',
#   668: 'How to finance your venture ?',
#   669: 'Mining Quality Prediction Using Machine & Deep Learning',
#   670: 'Business Model Innovation',
#   671: 'First Step Korean',
#   672: 'Build Your Professional ePortfolio in English',
#   673: 'Healthcare Data Quality and Governance',
#   674: 'Current Gen 3D Game Prop Production',
#   675: 'Healing with the Arts',
#   676: 'Communication Skills for University Success',
#   677: 'UX (User Experience) Capstone',
#   678: 'Biomedical Visualisation',
#   679: 'Ideal Gases',
#   680: 'Fundamentals of Immunology Innate Immunity and B-Cell Function',
#   681: 'Thoracic Oncology',
#   682: 'Intermediate Object-Oriented Programming for Unity Games',
#   683: 'Antisemitism From Its Origins to the Present',
#   684: 'Chinese for HSK 2',
#   685: 'Impact from digital transformation A Nano course',
#   686: 'Sequence Models',
#   687: 'Data Science Capstone',
#   688: 'Data Science Capstone',
#   689: 'Meaningful Predictive Modeling',
#   690: 'Current-Mode Control',
#   691: 'Developing Your Musicianship Final Project',
#   692: 'Achieving Your Optimal Performance',
#   693: 'The Music of the Rolling Stones 1962-1974',
#   694: 'Global Health and Humanitarianism',
#   695: 'Preventative Healthcare for the Newborn Baby',
#   696: 'Expanding SEL',
#   697: 'Visual Perception for Self-Driving Cars',
#   698: 'Art & Ideas Teaching with Themes',
#   699: 'Disease Screening in Public Health',
#   700: 'Copyright for Educators & Librarians',
#   701: 'Arch of Titus Rome and the Menorah',
#   702: 'Providing Social Emotional Behavioral and Special Education Services in School',
#   703: 'Infonomics II Business Information Management and Measurement',
#   704: 'Civic Engagement in American Democracy',
#   705: 'The Meat We Eat',
#   706: 'Acute and Chronic Rhinosinusitis A Comprehensive Review',
#   707: 'The Social Context of Mental Health and Illness',
#   708: 'Understanding Financial Statements Company Position',
#   709: 'Build a Firebase Android Application',
#   710: 'Plots (Graphics) in R',
#   711: 'Dog Emotion and Cognition',
#   712: 'Privacy in the Western World',
#   713: 'Skepticism',
#   714: 'Consonants of American English Pronunciation',
#   715: 'Guitar Performance Techniques',
#   716: 'Thrive in Trying Times Teach-Out',
#   717: 'Introduction to Graph Theory',
#   718: 'Compassionate Leadership Through Service Learning with Jane Goodall and Roots & Shoots',
#   719: 'Social Media Data Analytics',
#   720: 'Elastic Google Cloud Infrastructure Scaling and Automation',
#   721: 'Response Surfaces Mixtures and Model Building',
#   722: 'Local Economic Development',
#   723: 'Political Economy of Institutions and Development',
#   724: 'Philosophy and the Sciences Introduction to the Philosophy of Cognitive Sciences',
#   725: 'Grow to Greatness Smart Growth for Private Businesses Part I',
#   726: 'Evaluate Machine Learning Models with Yellowbrick',
#   727: 'Business Intelligence and Competitive Analysis',
#   728: 'Enterprise and Infrastructure Security',
#   729: 'English for Effective Business Speaking',
#   730: 'Raising Capital Credit Tech Coin Offerings and Crowdfunding',
#   731: 'Learning How To Learn for Youth',
#   732: 'What is news?',
#   733: 'Interprofessional Healthcare Informatics',
#   734: 'Create Your First Python Program',
#   735: 'Methods and Statistics in Social Science - Final Research Project',
#   736: 'Basic Elements of Design Design Principles and Software Overview',
#   737: 'EMT Foundations',
#   738: 'Cloud Computing Project',
#   739: 'Israel State and Society',
#   740: 'Python Data Representations',
#   741: 'Bases of the law of obligations (The Russian Federation) Part 1',
#   742: 'Solar Energy Basics',
#   743: 'Javascript animation for websites storytelling data visualization and games',
#   744: 'Advanced Engineering Systems in Motion Dynamics of Three Dimensional (3D) Motion',
#   745: 'Teach English Now! Foundational Principles',
#   746: 'Teach English Now! Foundational Principles',
#   747: 'Python Functions Files and Dictionaries',
#   748: 'Towards language universals through lexical semantics introduction to lexical and semantic typology',
#   749: 'Global Impact Cultural Psychology',
#   750: 'Managing an Agile Team',
#   751: 'Managing an Agile Team',
#   752: 'Computer Vision Neural Transfer Style & Green Screen Effect',
#   753: 'Sensors and Sensor Circuit Design',
#   754: 'Getting Started with SAS Visual Analytics',
#   755: 'Cyber-Physical Systems Modeling and Simulation',
#   756: 'Predict Ideal Diamonds over Good Diamonds using a Random Forest using R',
#   757: "The Bible's Prehistory Purpose and Political Future",
#   758: 'Introduction to iOS App Development with Swift 5',
#   759: 'Community Change in Public Health',
#   760: 'Six Sigma Tools for Analyze',
#   761: 'REAL BONES Adventures in Forensic Anthropology',
#   762: 'General Academic English',
#   763: 'The American South Its Stories Music and Art',
#   764: 'Create Custom Layers in Keras',
#   765: 'Brand management in digital economy',
#   766: 'Innovating in a Digital World',
#   767: 'Introduction to Communication Science',
#   768: 'Optimization of Topic Models using Grid Search Method',
#   769: 'Sports and Building Aerodynamics',
#   770: 'Organisational design Know your organisation',
#   771: 'Learn to Teach Java Writing Classes and Arrays',
#   772: 'Plots (Graphics) for Data Science',
#   773: 'The Sun and the Total Eclipse of August 2017',
#   774: 'Material Behavior',
#   775: 'Disaster Preparedness',
#   776: 'Protecting Business Innovations via Trademark',
#   777: 'Fundamentals of the Chinese character writing (Part 1)',
#   778: 'International Leadership and Organizational Behavior',
#   779: 'Introduction to Natural Language Processing in Python',
#   780: 'ADHD Everyday Strategies for Elementary Students',
#   781: 'Introduction to Statistical Analysis Hypothesis Testing',
#   782: 'Health Concepts in Chinese Medicine',
#   783: 'Teamwork Skills Communicating Effectively in Groups',
#   784: 'Academic Listening and Note-Taking',
#   785: 'Digital Manufacturing & Design',
#   786: 'Predicting Salaries with Simple Linear Regression in R',
#   787: 'Create your first test automation script - Selenium and C#',
#   788: 'How Google does Machine Learning',
#   789: 'Cybersecurity Awareness and Innovation',
#   790: 'Machine Learning Predict Numbers from Handwritten Digits using a Neural Network Keras and R',
#   791: 'Essential Epidemiologic Tools for Public Health Practice',
#   792: 'Giving Helpful Feedback',
#   793: 'International Labour Law',
#   794: 'Effectively delivering the news to your audience',
#   795: 'Writing your World Finding yourself in the academic space',
#   796: 'Digital Business Models',
#   797: 'Introduction to Advanced tomography',
#   798: 'Engaging in Persuasive and Credible Communication',
#   799: 'Creating a Customer Service Survey Using Google Forms',
#   800: 'Introduction to Philosophy',
#   801: 'Architecting with Google Kubernetes Engine Workloads',
#   802: 'Extracellular Vesicles in Health and Disease',
#   803: 'Understanding Your Google Cloud Platform (GCP) Costs',
#   804: 'Gmail The Foundation To Accessing Google Apps',
#   805: 'Create a Google Ads Video Campaign',
#   806: 'Photography Techniques Light Content and Sharing',
#   807: 'The City and You Find Your Best Place',
#   808: 'What is Palliative Care?',
#   809: 'CAM and Design Manufacturing for Mechanical Engineers with Autodesk Fusion 360',
#   810: 'Speaking to inform Discussing complex ideas with clear explanations and dynamic slides',
#   811: 'America Through Foreign Eyes',
#   812: 'Internet Giants The Law and Economics of Media Platforms',
#   813: 'Career Total Fitness Annual Retreat',
#   814: 'Introduction to Containers w/ Docker Kubernetes & OpenShift',
#   815: 'Sequence Models for Time Series and Natural Language Processing',
#   816: 'Simple Recurrent Neural Network with Keras',
#   817: 'Supply Chain Operations',
#   818: 'Chinese for HSK 3 PART I',
#   819: 'Spreadsheets for Beginners using Google Sheets',
#   820: 'Leadership and Emotional Intelligence',
#   821: 'Managing Supply Chain Disruption During COVID-19',
#   822: 'Regulated Competition in Healthcare Systems Theory & Practice',
#   823: 'Random Models Nested and Split-plot Designs',
#   824: 'Modern Robotics Course 5 Robot Manipulation and Wheeled Mobile Robots',
#   825: 'Fundamentals of Network Communication',
#   826: 'Predictive Modeling and Machine Learning with MATLAB',
#   827: 'Networking and Volunteerism for Career Success',
#   828: 'Crafting Strategies for Innovation Initiatives for Corporate Entrepreneurs',
#   829: 'Portfolio and Risk Management',
#   830: 'Auditing I Conceptual Foundations of Auditing',
#   831: 'Building a Business Presence With Facebook Marketing',
#   832: 'Finance for Everyone Decisions',
#   833: 'Rapid Prototyping of Embedded Interface Designs',
#   834: 'FinTech Risk Management',
#   835: 'Solar Energy Systems Overview',
#   836: 'Industrial IoT on Google Cloud Platform',
#   837: 'Customer Segmentation and Prospecting',
#   838: 'Multiplatform Mobile App Development with Web Technologies Ionic and Cordova',
#   839: 'Enjoyable Econometrics',
#   840: 'Build an App in Android Studio using Static Files',
#   841: 'Safety in the Utility Industry',
#   842: 'Content Advertising & Social IMC',
#   843: 'Introduction to Power Electronics',
#   844: 'Rails with Active Record and Action Pack',
#   845: 'Building Your Leadership Skills',
#   846: 'Accounting for Business Decision Making Measurement and Operational Decisions',
#   847: 'Work Smarter Not Harder Time Management for Personal & Professional Productivity',
#   848: 'Build Multilayer Perceptron Models with Keras',
#   849: 'Financial Reporting Capstone',
#   850: 'Songwriting Writing the Lyrics',
#   851: 'Healthcare Marketplace',
#   852: 'Developing An Entrepreneurial Mindset First Step Towards Success',
#   853: 'Capstone Project Business Technology Management',
#   854: 'Business English Basics',
#   855: 'Supply Chain Sourcing',
#   856: 'Recruiting Hiring and Onboarding Employees',
#   857: 'Programming with Scratch',
#   858: 'Teaching Impacts of Technology Workplace of the Future',
#   859: 'Foundations of Public Health Practice Behaviour & Behaviour Change',
#   860: 'Essential Google Cloud Infrastructure Core Services',
#   861: 'Tropical Parasitology Protozoans Worms Vectors and Human Diseases',
#   862: 'The Modern World Part One Global History from 1760 to 1910',
#   863: 'Solar Energy System Design',
#   864: 'Validity and Bias in Epidemiology',
#   865: 'Imagery Automation and Applications',
#   866: 'Measuring Causal Effects in the Social Sciences',
#   867: 'Protecting Business Innovations via Strategy',
#   868: 'Ecosystems of California',
#   869: 'Unethical Decision Making in Organizations',
#   870: 'How Computers Work',
#   871: 'HPV-Associated Oral and Throat Cancer What You Need to Know',
#   872: 'Making the Case for Robotic Process Automation',
#   873: 'Be a Leader Develop a Leader',
#   874: 'Influencer Marketing Strategy',
#   875: 'Digital Media and Marketing Strategies',
#   876: 'Intro to International Marketing',
#   877: 'Introduction to OpenCL on FPGAs',
#   878: 'Building Conversational Experiences with Dialogflow',
#   879: 'Docker Essentials & Building a Containerized Web Application',
#   880: 'Applying Investment Decision Rules for Startups',
#   881: 'Qualitative Data Collection Methods',
#   882: 'Assessment for Learning',
#   883: 'Financial Engineering and Risk Management Part I',
#   884: 'Teach English Now! Capstone Project 2',
#   885: 'Teach English Now! Capstone Project 2',
#   886: 'The Economics of Agro-Food Value Chains',
#   887: 'Machine Learning Algorithms Supervised Learning Tip to Tail',
#   888: '3D Printing Hardware',
#   889: 'Business English for Cross-cultural Communication',
#   890: 'Cloud Networking',
#   891: 'Build a Machine Learning Web App with Streamlit and Python',
#   892: 'Python Geospatial Data Analysis',
#   893: 'Lesson | Business English Skills Introducing Yourself in Business Settings',
#   894: 'Getting Started with Blazor WASM',
#   895: 'Establishing a Professional �Self� through Effective Intercultural Communication',
#   896: 'Biases and Portfolio Selection',
#   897: 'Building Smart Business Assistants with IBM Watson',
#   898: 'Introduction to Pointers and Memory Management in C/C++',
#   899: 'Using Seesaw for Student Learning',
#   900: 'Music and Social Action',
#   901: 'Enhancing Communication with Remind',
#   902: 'Security Operations and Administration',
#   903: 'Machine Learning Classification',
#   904: 'Git + GitHub for Open Source Collaboration',
#   905: 'Communicating Climate Change and Health',
#   906: 'Revolutionary Ideas Borders Elections Constitutions Prisons',
#   907: 'Multimodal Literacies Communication and Learning in the Era of Digital Media',
#   908: 'International Water Law',
#   909: 'Applying Machine Learning to your Data with GCP',
#   910: 'Image Understanding with TensorFlow on GCP',
#   911: 'Create a text adventure game with Ink',
#   912: 'Functional Programming in Scala Capstone',
#   913: 'Enterprise Architecture',
#   914: 'Delivery Problem',
# ...
#   204: 'Advanced',
#   205: 'Advanced',
#   206: 'Advanced',
#   207: 'Advanced',
#   208: 'Advanced',
#   209: 'Not Calibrated',
#   210: 'Beginner',
#   211: 'Beginner',
#   212: 'Advanced',
#   213: 'Advanced',
#   214: 'Intermediate',
#   215: 'Beginner',
#   216: 'Intermediate',
#   217: 'Intermediate',
#   218: 'Beginner',
#   219: 'Beginner',
#   220: 'Beginner',
#   221: 'Advanced',
#   222: 'Advanced',
#   223: 'Advanced',
#   224: 'Conversant',
#   225: 'Beginner',
#   226: 'Beginner',
#   227: 'Beginner',
#   228: 'Intermediate',
#   229: 'Beginner',
#   230: 'Beginner',
#   231: 'Beginner',
#   232: 'Beginner',
#   233: 'Beginner',
#   234: 'Advanced',
#   235: 'Intermediate',
#   236: 'Beginner',
#   237: 'Intermediate',
#   238: 'Advanced',
#   239: 'Advanced',
#   240: 'Beginner',
#   241: 'Intermediate',
#   242: 'Intermediate',
#   243: 'Advanced',
#   244: 'Intermediate',
#   245: 'Intermediate',
#   246: 'Advanced',
#   247: 'Beginner',
#   248: 'Beginner',
#   249: 'Beginner',
#   250: 'Intermediate',
#   251: 'Beginner',
#   252: 'Advanced',
#   253: 'Beginner',
#   254: 'Intermediate',
#   255: 'Advanced',
#   256: 'Advanced',
#   257: 'Beginner',
#   258: 'Advanced',
#   259: 'Advanced',
#   260: 'Advanced',
#   261: 'Beginner',
#   262: 'Advanced',
#   263: 'Advanced',
#   264: 'Advanced',
#   265: 'Beginner',
#   266: 'Not Calibrated',
#   267: 'Intermediate',
#   268: 'Advanced',
#   269: 'Beginner',
#   270: 'Intermediate',
#   271: 'Beginner',
#   272: 'Advanced',
#   273: 'Beginner',
#   274: 'Advanced',
#   275: 'Beginner',
#   276: 'Beginner',
#   277: 'Intermediate',
#   278: 'Advanced',
#   279: 'Beginner',
#   280: 'Intermediate',
#   281: 'Advanced',
#   282: 'Beginner',
#   283: 'Advanced',
#   284: 'Advanced',
#   285: 'Beginner',
#   286: 'Beginner',
#   287: 'Beginner',
#   288: 'Beginner',
#   289: 'Advanced',
#   290: 'Advanced',
#   291: 'Intermediate',
#   292: 'Intermediate',
#   293: 'Beginner',
#   294: 'Beginner',
#   295: 'Beginner',
#   296: 'Beginner',
#   297: 'Beginner',
#   298: 'Beginner',
#   299: 'Advanced',
#   300: 'Advanced',
#   301: 'Beginner',
#   302: 'Advanced',
#   303: 'Intermediate',
#   304: 'Advanced',
#   305: 'Conversant',
#   306: 'Beginner',
#   307: 'Advanced',
#   308: 'Advanced',
#   309: 'Advanced',
#   310: 'Advanced',
#   311: 'Intermediate',
#   312: 'Intermediate',
#   313: 'Beginner',
#   314: 'Advanced',
#   315: 'Beginner',
#   316: 'Advanced',
#   317: 'Beginner',
#   318: 'Beginner',
#   319: 'Advanced',
#   320: 'Beginner',
#   321: 'Intermediate',
#   322: 'Beginner',
#   323: 'Advanced',
#   324: 'Advanced',
#   325: 'Conversant',
#   326: 'Beginner',
#   327: 'Advanced',
#   328: 'Advanced',
#   329: 'Intermediate',
#   330: 'Intermediate',
#   331: 'Beginner',
#   332: 'Advanced',
#   333: 'Intermediate',
#   334: 'Advanced',
#   335: 'Beginner',
#   336: 'Beginner',
#   337: 'Intermediate',
#   338: 'Beginner',
#   339: 'Advanced',
#   340: 'Advanced',
#   341: 'Beginner',
#   342: 'Advanced',
#   343: 'Advanced',
#   344: 'Intermediate',
#   345: 'Advanced',
#   346: 'Beginner',
#   347: 'Beginner',
#   348: 'Advanced',
#   349: 'Conversant',
#   350: 'Advanced',
#   351: 'Beginner',
#   352: 'Advanced',
#   353: 'Advanced',
#   354: 'Beginner',
#   355: 'Intermediate',
#   356: 'Beginner',
#   357: 'Advanced',
#   358: 'Beginner',
#   359: 'Beginner',
#   360: 'Advanced',
#   361: 'Beginner',
#   362: 'Advanced',
#   363: 'Conversant',
#   364: 'Advanced',
#   365: 'Advanced',
#   366: 'Advanced',
#   367: 'Conversant',
#   368: 'Conversant',
#   369: 'Beginner',
#   370: 'Intermediate',
#   371: 'Beginner',
#   372: 'Beginner',
#   373: 'Intermediate',
#   374: 'Advanced',
#   375: 'Beginner',
#   376: 'Advanced',
#   377: 'Beginner',
#   378: 'Advanced',
#   379: 'Beginner',
#   380: 'Beginner',
#   381: 'Beginner',
#   382: 'Advanced',
#   383: 'Intermediate',
#   384: 'Beginner',
#   385: 'Intermediate',
#   386: 'Advanced',
#   387: 'Beginner',
#   388: 'Beginner',
#   389: 'Beginner',
#   390: 'Beginner',
#   391: 'Intermediate',
#   392: 'Beginner',
#   393: 'Beginner',
#   394: 'Intermediate',
#   395: 'Beginner',
#   396: 'Beginner',
#   397: 'Beginner',
#   398: 'Intermediate',
#   399: 'Beginner',
#   400: 'Intermediate',
#   401: 'Intermediate',
#   402: 'Conversant',
#   403: 'Beginner',
#   404: 'Intermediate',
#   405: 'Beginner',
#   406: 'Advanced',
#   407: 'Conversant',
#   408: 'Beginner',
#   409: 'Beginner',
#   410: 'Advanced',
#   411: 'Beginner',
#   412: 'Beginner',
#   413: 'Advanced',
#   414: 'Intermediate',
#   415: 'Beginner',
#   416: 'Intermediate',
#   417: 'Advanced',
#   418: 'Intermediate',
#   419: 'Beginner',
#   420: 'Beginner',
#   421: 'Advanced',
#   422: 'Beginner',
#   423: 'Advanced',
#   424: 'Intermediate',
#   425: 'Intermediate',
#   426: 'Intermediate',
#   427: 'Intermediate',
#   428: 'Beginner',
#   429: 'Advanced',
#   430: 'Advanced',
#   431: 'Beginner',
#   432: 'Intermediate',
#   433: 'Intermediate',
#   434: 'Advanced',
#   435: 'Intermediate',
#   436: 'Advanced',
#   437: 'Advanced',
#   438: 'Beginner',
#   439: 'Beginner',
#   440: 'Beginner',
#   441: 'Intermediate',
#   442: 'Advanced',
#   443: 'Advanced',
#   444: 'Intermediate',
#   445: 'Beginner',
#   446: 'Beginner',
#   447: 'Beginner',
#   448: 'Intermediate',
#   449: 'Beginner',
#   450: 'Conversant',
#   451: 'Beginner',
#   452: 'Advanced',
#   453: 'Beginner',
#   454: 'Beginner',
#   455: 'Advanced',
#   456: 'Advanced',
#   457: 'Conversant',
#   458: 'Not Calibrated',
#   459: 'Intermediate',
#   460: 'Conversant',
#   461: 'Intermediate',
#   462: 'Advanced',
#   463: 'Beginner',
#   464: 'Intermediate',
#   465: 'Intermediate',
#   466: 'Beginner',
#   467: 'Intermediate',
#   468: 'Intermediate',
#   469: 'Advanced',
#   470: 'Advanced',
#   471: 'Intermediate',
#   472: 'Conversant',
#   473: 'Beginner',
#   474: 'Intermediate',
#   475: 'Intermediate',
#   476: 'Intermediate',
#   477: 'Beginner',
#   478: 'Beginner',
#   479: 'Intermediate',
#   480: 'Beginner',
#   481: 'Intermediate',
#   482: 'Advanced',
#   483: 'Beginner',
#   484: 'Beginner',
#   485: 'Advanced',
#   486: 'Beginner',
#   487: 'Advanced',
#   488: 'Advanced',
#   489: 'Beginner',
#   490: 'Advanced',
#   491: 'Intermediate',
#   492: 'Beginner',
#   493: 'Beginner',
#   494: 'Advanced',
#   495: 'Beginner',
#   496: 'Beginner',
#   497: 'Beginner',
#   498: 'Beginner',
#   499: 'Beginner',
#   500: 'Advanced',
#   501: 'Beginner',
#   502: 'Advanced',
#   503: 'Beginner',
#   504: 'Intermediate',
#   505: 'Conversant',
#   506: 'Advanced',
#   507: 'Beginner',
#   508: 'Advanced',
#   509: 'Intermediate',
#   510: 'Beginner',
#   511: 'Beginner',
#   512: 'Beginner',
#   513: 'Beginner',
#   514: 'Intermediate',
#   515: 'Beginner',
#   516: 'Intermediate',
#   517: 'Beginner',
#   518: 'Beginner',
#   519: 'Advanced',
#   520: 'Beginner',
#   521: 'Beginner',
#   522: 'Advanced',
#   523: 'Beginner',
#   524: 'Beginner',
#   525: 'Beginner',
#   526: 'Intermediate',
#   527: 'Beginner',
#   528: 'Intermediate',
#   529: 'Intermediate',
#   530: 'Intermediate',
#   531: 'Beginner',
#   532: 'Intermediate',
#   533: 'Advanced',
#   534: 'Intermediate',
#   535: 'Advanced',
#   536: 'Beginner',
#   537: 'Advanced',
#   538: 'Conversant',
#   539: 'Intermediate',
#   540: 'Beginner',
#   541: 'Beginner',
#   542: 'Beginner',
#   543: 'Beginner',
#   544: 'Advanced',
#   545: 'Intermediate',
#   546: 'Intermediate',
#   547: 'Beginner',
#   548: 'Advanced',
#   549: 'Advanced',
#   550: 'Beginner',
#   551: 'Beginner',
#   552: 'Beginner',
#   553: 'Beginner',
#   554: 'Advanced',
#   555: 'Beginner',
#   556: 'Beginner',
#   557: 'Intermediate',
#   558: 'Advanced',
#   559: 'Advanced',
#   560: 'Beginner',
#   561: 'Beginner',
#   562: 'Beginner',
#   563: 'Beginner',
#   564: 'Advanced',
#   565: 'Beginner',
#   566: 'Beginner',
#   567: 'Beginner',
#   568: 'Intermediate',
#   569: 'Intermediate',
#   570: 'Advanced',
#   571: 'Advanced',
#   572: 'Intermediate',
#   573: 'Conversant',
#   574: 'Advanced',
#   575: 'Advanced',
#   576: 'Advanced',
#   577: 'Beginner',
#   578: 'Beginner',
#   579: 'Beginner',
#   580: 'Beginner',
#   581: 'Intermediate',
#   582: 'Intermediate',
#   583: 'Advanced',
#   584: 'Beginner',
#   585: 'Intermediate',
#   586: 'Advanced',
#   587: 'Beginner',
#   588: 'Not Calibrated',
#   589: 'Beginner',
#   590: 'Advanced',
#   591: 'Intermediate',
#   592: 'Beginner',
#   593: 'Advanced',
#   594: 'Intermediate',
#   595: 'Advanced',
#   596: 'Beginner',
#   597: 'Advanced',
#   598: 'Intermediate',
#   599: 'Beginner',
#   600: 'Beginner',
#   601: 'Beginner',
#   602: 'Beginner',
#   603: 'Beginner',
#   604: 'Intermediate',
#   605: 'Advanced',
#   606: 'Beginner',
#   607: 'Beginner',
#   608: 'Beginner',
#   609: 'Advanced',
#   610: 'Beginner',
#   611: 'Beginner',
#   612: 'Intermediate',
#   613: 'Intermediate',
#   614: 'Beginner',
#   615: 'Beginner',
#   616: 'Intermediate',
#   617: 'Beginner',
#   618: 'Beginner',
#   619: 'Beginner',
#   620: 'Advanced',
#   621: 'Beginner',
#   622: 'Beginner',
#   623: 'Intermediate',
#   624: 'Advanced',
#   625: 'Advanced',
#   626: 'Intermediate',
#   627: 'Beginner',
#   628: 'Conversant',
#   629: 'Beginner',
#   630: 'Beginner',
#   631: 'Advanced',
#   632: 'Intermediate',
#   633: 'Advanced',
#   634: 'Beginner',
#   635: 'Conversant',
#   636: 'Conversant',
#   637: 'Beginner',
#   638: 'Intermediate',
#   639: 'Advanced',
#   640: 'Beginner',
#   641: 'Beginner',
#   642: 'Advanced',
#   643: 'Intermediate',
#   644: 'Intermediate',
#   645: 'Advanced',
#   646: 'Conversant',
#   647: 'Beginner',
#   648: 'Advanced',
#   649: 'Intermediate',
#   650: 'Intermediate',
#   651: 'Advanced',
#   652: 'Advanced',
#   653: 'Beginner',
#   654: 'Conversant',
#   655: 'Advanced',
#   656: 'Advanced',
#   657: 'Beginner',
#   658: 'Advanced',
#   659: 'Intermediate',
#   660: 'Advanced',
#   661: 'Advanced',
#   662: 'Advanced',
#   663: 'Conversant',
#   664: 'Intermediate',
#   665: 'Conversant',
#   666: 'Advanced',
#   667: 'Intermediate',
#   668: 'Advanced',
#   669: 'Beginner',
#   670: 'Advanced',
#   671: 'Conversant',
#   672: 'Advanced',
#   673: 'Intermediate',
#   674: 'Advanced',
#   675: 'Beginner',
#   676: 'Beginner',
#   677: 'Advanced',
#   678: 'Beginner',
#   679: 'Intermediate',
#   680: 'Intermediate',
#   681: 'Beginner',
#   682: 'Advanced',
#   683: 'Advanced',
#   684: 'Beginner',
#   685: 'Conversant',
#   686: 'Conversant',
#   687: 'Advanced',
#   688: 'Advanced',
#   689: 'Advanced',
#   690: 'Advanced',
#   691: 'Advanced',
#   692: 'Advanced',
#   693: 'Not Calibrated',
#   694: 'Beginner',
#   695: 'Beginner',
#   696: 'Advanced',
#   697: 'Beginner',
#   698: 'Intermediate',
#   699: 'Intermediate',
#   700: 'Beginner',
#   701: 'Intermediate',
#   702: 'Beginner',
#   703: 'Advanced',
#   704: 'Intermediate',
#   705: 'Not Calibrated',
#   706: 'Beginner',
#   707: 'Beginner',
#   708: 'Beginner',
#   709: 'Advanced',
#   710: 'Beginner',
#   711: 'Beginner',
#   712: 'Beginner',
#   713: 'Beginner',
#   714: 'Beginner',
#   715: 'Intermediate',
#   716: 'Beginner',
#   717: 'Intermediate',
#   718: 'Intermediate',
#   719: 'Advanced',
#   720: 'Beginner',
#   721: 'Intermediate',
#   722: 'Intermediate',
#   723: 'Intermediate',
#   724: 'Beginner',
#   725: 'Intermediate',
#   726: 'Beginner',
#   727: 'Beginner',
#   728: 'Advanced',
#   729: 'Advanced',
#   730: 'Intermediate',
#   731: 'Beginner',
#   732: 'Conversant',
#   733: 'Intermediate',
#   734: 'Beginner',
#   735: 'Advanced',
#   736: 'Beginner',
#   737: 'Beginner',
#   738: 'Advanced',
#   739: 'Intermediate',
#   740: 'Advanced',
#   741: 'Advanced',
#   742: 'Intermediate',
#   743: 'Beginner',
#   744: 'Intermediate',
#   745: 'Beginner',
#   746: 'Beginner',
#   747: 'Conversant',
#   748: 'Advanced',
#   749: 'Intermediate',
#   750: 'Beginner',
#   751: 'Beginner',
#   752: 'Beginner',
#   753: 'Intermediate',
#   754: 'Beginner',
#   755: 'Advanced',
#   756: 'Beginner',
#   757: 'Beginner',
#   758: 'Beginner',
#   759: 'Intermediate',
#   760: 'Beginner',
#   761: 'Beginner',
#   762: 'Intermediate',
#   763: 'Beginner',
#   764: 'Beginner',
#   765: 'Not Calibrated',
#   766: 'Intermediate',
#   767: 'Advanced',
#   768: 'Beginner',
#   769: 'Intermediate',
#   770: 'Beginner',
#   771: 'Advanced',
#   772: 'Beginner',
#   773: 'Beginner',
#   774: 'Beginner',
#   775: 'Beginner',
#   776: 'Intermediate',
#   777: 'Beginner',
#   778: 'Beginner',
#   779: 'Beginner',
#   780: 'Beginner',
#   781: 'Intermediate',
#   782: 'Intermediate',
#   783: 'Intermediate',
#   784: 'Advanced',
#   785: 'Beginner',
#   786: 'Beginner',
#   787: 'Beginner',
#   788: 'Beginner',
#   789: 'Beginner',
#   790: 'Beginner',
#   791: 'Beginner',
#   792: 'Intermediate',
#   793: 'Beginner',
#   794: 'Advanced',
#   795: 'Advanced',
#   796: 'Advanced',
#   797: 'Intermediate',
#   798: 'Advanced',
#   799: 'Beginner',
#   800: 'Beginner',
#   801: 'Intermediate',
#   802: 'Beginner',
#   803: 'Advanced',
#   804: 'Beginner',
#   805: 'Advanced',
#   806: 'Intermediate',
#   807: 'Beginner',
#   808: 'Beginner',
#   809: 'Beginner',
#   810: 'Advanced',
#   811: 'Beginner',
#   812: 'Beginner',
#   813: 'Advanced',
#   814: 'Advanced',
#   815: 'Intermediate',
#   816: 'Advanced',
#   817: 'Beginner',
#   818: 'Advanced',
#   819: 'Beginner',
#   820: 'Beginner',
#   821: 'Intermediate',
#   822: 'Beginner',
#   823: 'Intermediate',
#   824: 'Advanced',
#   825: 'Intermediate',
#   826: 'Intermediate',
#   827: 'Advanced',
#   828: 'Advanced',
#   829: 'Beginner',
#   830: 'Intermediate',
#   831: 'Beginner',
#   832: 'Conversant',
#   833: 'Intermediate',
#   834: 'Beginner',
#   835: 'Beginner',
#   836: 'Advanced',
#   837: 'Conversant',
#   838: 'Advanced',
#   839: 'Beginner',
#   840: 'Beginner',
#   841: 'Beginner',
#   842: 'Beginner',
#   843: 'Advanced',
#   844: 'Beginner',
#   845: 'Conversant',
#   846: 'Advanced',
#   847: 'Conversant',
#   848: 'Beginner',
#   849: 'Advanced',
#   850: 'Intermediate',
#   851: 'Beginner',
#   852: 'Intermediate',
#   853: 'Intermediate',
#   854: 'Advanced',
#   855: 'Beginner',
#   856: 'Beginner',
#   857: 'Advanced',
#   858: 'Advanced',
#   859: 'Advanced',
#   860: 'Conversant',
#   861: 'Intermediate',
#   862: 'Beginner',
#   863: 'Intermediate',
#   864: 'Intermediate',
#   865: 'Intermediate',
#   866: 'Intermediate',
#   867: 'Intermediate',
#   868: 'Beginner',
#   869: 'Intermediate',
#   870: 'Beginner',
#   871: 'Beginner',
#   872: 'Advanced',
#   873: 'Advanced',
#   874: 'Advanced',
#   875: 'Advanced',
#   876: 'Beginner',
#   877: 'Beginner',
#   878: 'Intermediate',
#   879: 'Beginner',
#   880: 'Beginner',
#   881: 'Beginner',
#   882: 'Beginner',
#   883: 'Intermediate',
#   884: 'Beginner',
#   885: 'Beginner',
#   886: 'Beginner',
#   887: 'Intermediate',
#   888: 'Advanced',
#   889: 'Advanced',
#   890: 'Advanced',
#   891: 'Beginner',
#   892: 'Beginner',
#   893: 'Intermediate',
#   894: 'Beginner',
#   895: 'Advanced',
#   896: 'Beginner',
#   897: 'Beginner',
#   898: 'Beginner',
#   899: 'Beginner',
#   900: 'Intermediate',
#   901: 'Beginner',
#   902: 'Advanced',
#   903: 'Beginner',
#   904: 'Intermediate',
#   905: 'Beginner',
#   906: 'Intermediate',
#   907: 'Beginner',
#   908: 'Beginner',
#   909: 'Advanced',
#   910: 'Advanced',
#   911: 'Beginner',
#   912: 'Advanced',
#   913: 'Advanced',
#   914: 'Intermediate',
#   915: 'Beginner',
#   916: 'Beginner',
#   917: 'Advanced',
#   918: 'Beginner',
#   919: 'Intermediate',
#   920: 'Intermediate',
#   921: 'Beginner',
#   922: 'Intermediate',
#   923: 'Intermediate',
#   924: 'Advanced',
#   925: 'Advanced',
#   926: 'Advanced',
#   927: 'Beginner',
#   928: 'Advanced',
#   929: 'Intermediate',
#   930: 'Beginner',
#   931: 'Beginner',
#   932: 'Beginner',
#   933: 'Beginner',
#   934: 'Beginner',
#   935: 'Advanced',
#   936: 'Intermediate',
#   937: 'Advanced',
#   938: 'Beginner',
#   939: 'Conversant',
#   940: 'Beginner',
#   941: 'Intermediate',
#   942: 'Intermediate',
#   943: 'Intermediate',
#   944: 'Advanced',
#   945: 'Beginner',
#   946: 'Intermediate',
#   947: 'Advanced',
#   948: 'Advanced',
#   949: 'Intermediate',
#   950: 'Beginner',
#   951: 'Beginner',
#   952: 'Beginner',
#   953: 'Beginner',
#   954: 'Beginner',
#   955: 'Beginner',
#   956: 'Beginner',
#   957: 'Beginner',
#   958: 'Conversant',
#   959: 'Advanced',
#   960: 'Advanced',
#   961: 'Beginner',
#   962: 'Intermediate',
#   963: 'Beginner',
#   964: 'Intermediate',
#   965: 'Beginner',
#   966: 'Beginner',
#   967: 'Conversant',
#   968: 'Intermediate',
#   969: 'Advanced',
#   970: 'Advanced',
#   971: 'Advanced',
#   972: 'Beginner',
#   973: 'Intermediate',
#   974: 'Advanced',
#   975: 'Beginner',
#   976: 'Advanced',
#   977: 'Intermediate',
#   978: 'Intermediate',
#   979: 'Beginner',
#   980: 'Beginner',
#   981: 'Beginner',
#   982: 'Beginner',
#   983: 'Beginner',
#   984: 'Beginner',
#   985: 'Intermediate',
#   986: 'Intermediate',
#   987: 'Beginner',
#   988: 'Intermediate',
#   989: 'Intermediate',
#   990: 'Intermediate',
#   991: 'Beginner',
#   992: 'Intermediate',
#   993: 'Advanced',
#   994: 'Advanced',
#   995: 'Beginner',
#   996: 'Advanced',
#   997: 'Beginner',
#   998: 'Intermediate',
#   999: 'Beginner',
#   ...}}

# %%
similarity
# Out:
# array([[1.        , 0.03800057, 0.07908162, ..., 0.0947216 , 0.06892128,
#         0.10275975],
#        [0.03800057, 1.        , 0.01238729, ..., 0.30130767, 0.00518197,
#         0.03962144],
#        [0.07908162, 0.01238729, 1.        , ..., 0.01995129, 0.07234278,
#         0.03126409],
#        ...,
#        [0.0947216 , 0.30130767, 0.01995129, ..., 1.        , 0.00695519,
#         0.03722562],
#        [0.06892128, 0.00518197, 0.07234278, ..., 0.00695519, 1.        ,
#         0.02012109],
#        [0.10275975, 0.03962144, 0.03126409, ..., 0.03722562, 0.02012109,
#         1.        ]])

# %%
saved_lda = load_model('courses')
# Out:
# Model Sucessfully Loaded

# %%
print(saved_lda)
# Out:
#                                             course_name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy Business Model Canvas Analys...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 3517  Capstone Retrieving Processing and Visualizing...
# 3518                    Patrick Henry Forgotten Founder
# 3519  Business intelligence and data analytics Gener...
# 3520                                Rigid Body Dynamics
# 3521  Architecting with Google Kubernetes Engine Pro...
#
#                                                    tags  Course Rating  \
# 0     write a featur length screenplay for film or t...            4.8
# 1     busi strategi busi model canva analysi with mi...            4.8
# 2     silicon thin film solar cellsadvancedthi cours...            4.1
# 3     financ for managersintermediatewhen it come to...            4.8
# 4     retriev data use single-t sql queriesbeginneri...            4.6
# ...                                                 ...            ...
# 3517  capston retriev process and visual data with p...            4.6
# 3518  patrick henri forgotten founderintermediate�g ...            4.9
# 3519  busi intellig and data analyt gener insightsad...            4.6
# 3520  rigid bodi dynamicsbeginnerthi cours teach dyn...            4.6
# 3521  architect with googl kubernet engin production...            4.7
#
#      Difficulty_Level
# 0            Beginner
# 1            Beginner
# 2            Advanced
# 3        Intermediate
# 4            Beginner
# ...               ...
# 3517         Beginner
# 3518     Intermediate
# 3519         Advanced
# 3520         Beginner
# 3521     Intermediate
#
# [3522 rows x 4 columns]

# %%
courses
# Out:
#                                             course_name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy Business Model Canvas Analys...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 3517  Capstone Retrieving Processing and Visualizing...
# 3518                    Patrick Henry Forgotten Founder
# 3519  Business intelligence and data analytics Gener...
# 3520                                Rigid Body Dynamics
# 3521  Architecting with Google Kubernetes Engine Pro...
#
#                                                    tags  Course Rating  \
# 0     write a featur length screenplay for film or t...            4.8
# 1     busi strategi busi model canva analysi with mi...            4.8
# 2     silicon thin film solar cellsadvancedthi cours...            4.1
# 3     financ for managersintermediatewhen it come to...            4.8
# 4     retriev data use single-t sql queriesbeginneri...            4.6
# ...                                                 ...            ...
# 3517  capston retriev process and visual data with p...            4.6
# 3518  patrick henri forgotten founderintermediate�g ...            4.9
# 3519  busi intellig and data analyt gener insightsad...            4.6
# 3520  rigid bodi dynamicsbeginnerthi cours teach dyn...            4.6
# 3521  architect with googl kubernet engin production...            4.7
#
#      Difficulty_Level
# 0            Beginner
# 1            Beginner
# 2            Advanced
# 3        Intermediate
# 4            Beginner
# ...               ...
# 3517         Beginner
# 3518     Intermediate
# 3519         Advanced
# 3520         Beginner
# 3521     Intermediate
#
# [3522 rows x 4 columns]

# %%
import tabpy_client
from tabpy.tabpy_tools.client import Client
import pandas as pd
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np
import requests
from sklearn import preprocessing

client = tabpy_client.Client('http://localhost:9004/')

courses_list = pickle.load(open('courses.pkl','rb'))
similarity = pickle.load(open('similarity.pkl','rb'))



def recommend(_arg1, _arg2,_arg3):
    row = {'Course_Name': _arg1,
           'Course Rating': _arg2,
          'Difficulty Level':_arg3}
    #Convert it into a dataframe
    test_data = pd.DataFrame(data = row,index=[0])
    le = preprocessing.LabelEncoder()
    test_data['Course_Name']  = le.fit_transform(test_data['Course_Name'])
    index = courses_list[courses_list['Course_Name'] == course].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_course_names = []
    for i in distances[1:7]:
        course_name = courses_list.iloc[i[0]].course_name
        recommended_course_names.append(course_name)

    return recommended_course_names

course_list = courses_list['course_name'].values


#Deploying
client.deploy('recommend', recommend,'Recommended Courses',override = True)
