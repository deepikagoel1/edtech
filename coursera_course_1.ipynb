# %% [markdown]
# # Importing Dependencies

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('Dependencies Imported')
# Out:
# Dependencies Imported

# %%
data = pd.read_csv("Coursera.csv")
data.head(5)
# Out:
#    course_id                                        Course_Name  \
# 0      32281  Write A Feature Length Screenplay For Film Or ...
# 1       5114  Business Strategy: Business Model Canvas Analy...
# 2      28977                      Silicon Thin Film Solar Cells
# 3       9253                               Finance for Managers
# 4       9969       Retrieve Data using Single-Table SQL Queries
#
#                       Tenant Difficulty_Level  Course Rating  \
# 0  Michigan State University         Beginner            4.8
# 1   Coursera Project Network         Beginner            4.8
# 2        �cole Polytechnique         Advanced            4.1
# 3       IESE Business School     Intermediate            4.8
# 4   Coursera Project Network         Beginner            4.6
#
#                                           Course_URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                   Course_Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               Skills  members  user_profile  \
# 0  Drama  Comedy  peering  screenwriting  film  D...   200630       Student
# 1  Finance  business plan  persona (user experien...   793665       Student
# 2  chemistry  physics  Solar Energy  film  lambda...   114262       Student
# 3  accounts receivable  dupont analysis  analysis...   673572  Professional
# 4  Data Analysis  select (sql)  database manageme...   151266  Professional
#
#    Marks
# 0     89
# 1     92
# 2     84
# 3     86
# 4     88

# %% [markdown]
# # Basic Data Analysis

# %%
data.shape #3522 courses and 7 columns with different attributes
# Out:
# (3522, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   course_id           3522 non-null   int64
#  1   Course_Name         3522 non-null   object
#  2   Tenant              3522 non-null   object
#  3   Difficulty_Level    3522 non-null   object
#  4   Course Rating       3522 non-null   float64
#  5   Course_URL          3522 non-null   object
#  6   Course_Description  3522 non-null   object
#  7   Skills              3522 non-null   object
#  8   members             3522 non-null   int64
#  9   user_profile        3522 non-null   object
#  10  Marks               3522 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 302.8+ KB

# %%
data.isnull().sum() #no value is missing
# Out:
# course_id             0
# Course_Name           0
# Tenant                0
# Difficulty_Level      0
# Course Rating         0
# Course_URL            0
# Course_Description    0
# Skills                0
# members               0
# user_profile          0
# Marks                 0
# dtype: int64

# %%
data['Difficulty_Level'].value_counts()
# Out:
# Beginner          1444
# Advanced          1005
# Intermediate       837
# Conversant         186
# Not Calibrated      50
# Name: Difficulty_Level, dtype: int64

# %%
data['Course Rating'].value_counts()
# Out:
# 4.7    740
# 4.6    623
# 4.8    598
# 4.5    389
# 4.4    242
# 4.9    180
# 4.3    165
# 4.2    121
# 5.0     90
# 4.1     85
# 0.0     82
# 4.0     51
# 3.8     24
# 3.9     20
# 3.7     18
# 3.6     18
# 3.5     17
# 3.4     13
# 3.0     12
# 3.2      9
# 3.3      6
# 2.9      6
# 2.6      2
# 1.0      2
# 2.8      2
# 2.4      2
# 1.9      1
# 2.5      1
# 2.0      1
# 2.3      1
# 3.1      1
# Name: Course Rating, dtype: int64

# %%
# data[data['Course Rating'] == 'Not Calibrated'] = 0

# %%
data['Tenant'].value_counts()
# Out:
# Coursera Project Network                      562
# University of Illinois at Urbana-Champaign    138
# Johns Hopkins University                      110
# University of Colorado Boulder                101
# University of Michigan                        101
#                                              ...
# ConsenSys Academy                               1
# University of Glasgow                           1
# University of Nebraska                          1
# Yeshiva University                              1
# University of North Texas                       1
# Name: Tenant, Length: 184, dtype: int64

# %%
data['Course_Name']
# Out:
# 0       Write A Feature Length Screenplay For Film Or ...
# 1       Business Strategy: Business Model Canvas Analy...
# 2                           Silicon Thin Film Solar Cells
# 3                                    Finance for Managers
# 4            Retrieve Data using Single-Table SQL Queries
#                               ...
# 3517    Capstone: Retrieving, Processing, and Visualiz...
# 3518                     Patrick Henry: Forgotten Founder
# 3519    Business intelligence and data analytics: Gene...
# 3520                                  Rigid Body Dynamics
# 3521    Architecting with Google Kubernetes Engine: Pr...
# Name: Course_Name, Length: 3522, dtype: object

# %% [markdown]
# # Required Columns for System

# %% [markdown]
# #### Important columns to be used in recommendation system :
#
# - Course Name : Names of the courses
# - Course Description : Similar courses may have similar course description
# - Skills : Users may want to see courses based on same skills
# - Difficulty Level : Similar courses as per difficulty level
#
# #### Columns not used for the recommendation system :
#
# - Course Ratings : Numerical Column; Ratings can sometimes become a biased factor and distribution is not even
# - University : Same university might offer multiple courses in different domains which the user might not want to see
# - Course URL : No significance in the recommendation system

# %%
data = data[['Course_Name','Difficulty_Level','Course_Description','Skills', 'Course Rating']]

# %%
data.head(5)
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write A Feature Length Screenplay For Film Or ...         Beginner
# 1  Business Strategy: Business Model Canvas Analy...         Beginner
# 2                      Silicon Thin Film Solar Cells         Advanced
# 3                               Finance for Managers     Intermediate
# 4       Retrieve Data using Single-Table SQL Queries         Beginner
#
#                                   Course_Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               Skills  Course Rating
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona (user experien...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select (sql)  database manageme...            4.6

# %% [markdown]
# # Data Pre-Processing
#
# An important part of the process is to pre-process the data into usable format for the recommendation system

# %%
# Removing spaces between the words (Lambda funtions can be used as well)

data['Course_Name'] = data['Course_Name'].str.replace(' ',',')
data['Course_Name'] = data['Course_Name'].str.replace(',,',',')
data['Course_Name'] = data['Course_Name'].str.replace(':','')
data['Course_Description'] = data['Course_Description'].str.replace(' ',',')
data['Course_Description'] = data['Course_Description'].str.replace(',,',',')
data['Course_Description'] = data['Course_Description'].str.replace('_','')
data['Course_Description'] = data['Course_Description'].str.replace(':','')
data['Course_Description'] = data['Course_Description'].str.replace('(','')
data['Course_Description'] = data['Course_Description'].str.replace(')','')

#removing paranthesis from skills columns 
data['Skills'] = data['Skills'].str.replace('(','')
data['Skills'] = data['Skills'].str.replace(')','')

# %%
data.head(5)
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...         Beginner
# 1  Business,Strategy,Business,Model,Canvas,Analys...         Beginner
# 2                      Silicon,Thin,Film,Solar,Cells         Advanced
# 3                               Finance,for,Managers     Intermediate
# 4       Retrieve,Data,using,Single-Table,SQL,Queries         Beginner
#
#                                   Course_Description  \
# 0  Write,a,Full,Length,Feature,Film,Script,In,thi...
# 1  By,the,end,of,this,guided,project,you,will,be,...
# 2  This,course,consists,of,a,general,presentation...
# 3  When,it,comes,to,numbers,there,is,always,more,...
# 4  In,this,course,you�ll,learn,how,to,effectively...
#
#                                               Skills  Course Rating
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona user experienc...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select sql  database management...            4.6

# %% [markdown]
# # Tags Column
#
# The tags column is the combination of the following columns : **Course Name** + **Difficulty Level** + **Course Description** + **Skills**

# %%
data['tags'] = data['Course_Name'] + data['Difficulty_Level'] + data['Course_Description'] + data['Skills'] + data['Course Rating'].astype('str')

# %%
data.head(5)
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...         Beginner
# 1  Business,Strategy,Business,Model,Canvas,Analys...         Beginner
# 2                      Silicon,Thin,Film,Solar,Cells         Advanced
# 3                               Finance,for,Managers     Intermediate
# 4       Retrieve,Data,using,Single-Table,SQL,Queries         Beginner
#
#                                   Course_Description  \
# 0  Write,a,Full,Length,Feature,Film,Script,In,thi...
# 1  By,the,end,of,this,guided,project,you,will,be,...
# 2  This,course,consists,of,a,general,presentation...
# 3  When,it,comes,to,numbers,there,is,always,more,...
# 4  In,this,course,you�ll,learn,how,to,effectively...
#
#                                               Skills  Course Rating  \
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona user experienc...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select sql  database management...            4.6
#
#                                                 tags
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...
# 1  Business,Strategy,Business,Model,Canvas,Analys...
# 2  Silicon,Thin,Film,Solar,CellsAdvancedThis,cour...
# 3  Finance,for,ManagersIntermediateWhen,it,comes,...
# 4  Retrieve,Data,using,Single-Table,SQL,QueriesBe...

# %%
data['tags'].iloc[1]
# Out:
# 'Business,Strategy,Business,Model,Canvas,Analysis,with,MiroBeginnerBy,the,end,of,this,guided,project,you,will,be,fluent,in,identifying,and,creating,Business,Model,Canvas,solutions,based,on,previous,high-level,analyses,and,research,data.,This,will,enable,you,to,identify,and,map,the,elements,required,for,new,products,and,services.,Furthermore,it,is,essential,for,generating,positive,results,for,your,business,venture.,This,guided,project,is,designed,to,engage,and,harness,your,visionary,and,exploratory,abilities.,You,will,use,proven,models,in,strategy,and,product,development,with,the,Miro,platform,to,explore,and,analyse,your,business,propositions.,,We,will,practice,critically,examining,results,from,previous,analysis,and,research,results,in,deriving,the,values,for,each,of,the,business,model,sections.Finance  business plan  persona user experience  business model canvas  Planning  Business  project  Product Development  presentation  Strategy business business-strategy4.8'

# %% [markdown]
# # Dataframe to be used

# %%
new_df = data[['Course_Name','tags', 'Course Rating', 'Difficulty_Level']]

# %%
new_df.head(5)
# Out:
#                                          Course_Name  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...
# 1  Business,Strategy,Business,Model,Canvas,Analys...
# 2                      Silicon,Thin,Film,Solar,Cells
# 3                               Finance,for,Managers
# 4       Retrieve,Data,using,Single-Table,SQL,Queries
#
#                                                 tags  Course Rating  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...            4.8
# 1  Business,Strategy,Business,Model,Canvas,Analys...            4.8
# 2  Silicon,Thin,Film,Solar,CellsAdvancedThis,cour...            4.1
# 3  Finance,for,ManagersIntermediateWhen,it,comes,...            4.8
# 4  Retrieve,Data,using,Single-Table,SQL,QueriesBe...            4.6
#
#   Difficulty_Level
# 0         Beginner
# 1         Beginner
# 2         Advanced
# 3     Intermediate
# 4         Beginner

# %%
new_df['tags'] = data['tags'].str.replace(',',' ')
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df['Course_Name'] = data['Course_Name'].str.replace(',',' ')
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.rename(columns = {'Course_Name':'course_name'}, inplace = True)
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower()) #lower casing the tags column
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.head(5)
# Out:
#                                          course_name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy Business Model Canvas Analys...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                                                 tags  Course Rating  \
# 0  write a feature length screenplay for film or ...            4.8
# 1  business strategy business model canvas analys...            4.8
# 2  silicon thin film solar cellsadvancedthis cour...            4.1
# 3  finance for managersintermediatewhen it comes ...            4.8
# 4  retrieve data using single-table sql queriesbe...            4.6
#
#   Difficulty_Level
# 0         Beginner
# 1         Beginner
# 2         Advanced
# 3     Intermediate
# 4         Beginner

# %%
new_df.shape #3522 courses with tags and 2 columns (course_name and tags)
# Out:
# (3522, 4)

# %% [markdown]
# # Text Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %% [markdown]
# # Stemming Process

# %%
import nltk #for stemming process

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
#defining the stemming function
def stem(text):
    y=[]
    
    for i in text.split():
        y.append(ps.stem(i))
    
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem) #applying stemming on the tags column
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Similarity Measure

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %% [markdown]
# # Recommendation Function

# %%
l1 = list()

# %%
new_df
# Out:
#                                             course_name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy Business Model Canvas Analys...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 3517  Capstone Retrieving Processing and Visualizing...
# 3518                    Patrick Henry Forgotten Founder
# 3519  Business intelligence and data analytics Gener...
# 3520                                Rigid Body Dynamics
# 3521  Architecting with Google Kubernetes Engine Pro...
#
#                                                    tags  Course Rating  \
# 0     write a featur length screenplay for film or t...            4.8
# 1     busi strategi busi model canva analysi with mi...            4.8
# 2     silicon thin film solar cellsadvancedthi cours...            4.1
# 3     financ for managersintermediatewhen it come to...            4.8
# 4     retriev data use single-t sql queriesbeginneri...            4.6
# ...                                                 ...            ...
# 3517  capston retriev process and visual data with p...            4.6
# 3518  patrick henri forgotten founderintermediate�g ...            4.9
# 3519  busi intellig and data analyt gener insightsad...            4.6
# 3520  rigid bodi dynamicsbeginnerthi cours teach dyn...            4.6
# 3521  architect with googl kubernet engin production...            4.7
#
#      Difficulty_Level
# 0            Beginner
# 1            Beginner
# 2            Advanced
# 3        Intermediate
# 4            Beginner
# ...               ...
# 3517         Beginner
# 3518     Intermediate
# 3519         Advanced
# 3520         Beginner
# 3521     Intermediate
#
# [3522 rows x 4 columns]

# %%
def recommend(course, row_number):
#     print(new_df.columns.values[0])
    course_index = new_df[new_df['course_name'] == course].index[0]
    distances = similarity[course_index]
    course_list = sorted(list(enumerate(distances)),reverse=True, key=lambda x:x[1])[1:7]
    l3 = []
    for i in course_list:
        l3.append(new_df.iloc[i[0]].course_name)
    new_df['Recommendation'][row_number] = ",".join(l3)
#             new_df.iloc[i[0]].course_name
#         l1.append(new_df.iloc[i[0]].course_name)
        
       
#     return l1

# %%
recommend('Business Strategy Business Model Canvas Analysis with Miro')
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
for i in range(new_df.shape[0]):
    recommend(new_df['course_name'][i], i)
# Out:
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Deepika\anaconda3\envs\cows\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df = new_df.sort_values('Course Rating', ascending = False)

# %%
new_df.to_csv('recomm1.csv')

# %%
import pickle

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
pickle.dump(new_df.to_dict(),open('course_list.pkl','wb')) #contains the dataframe in dict 
pickle.dump(new_df,open('courses.pkl','wb'))

# %%
new_df.drop(columns = 'tags', inplace = True)

# %%
new_df.head()
# Out:
#                                             course_name  Course Rating  \
# 1154                      Build CRUD REST API in Django            5.0
# 593              Acing the Product Management Interview            5.0
# 2160   Conduct a Cost-Benefit Analysis in Google Sheets            5.0
# 3190  Computational Thinking for K-12 Educators Sequ...            5.0
# 2498  Edit Your Photos for Social Media Marketing us...            5.0
#
#      Difficulty_Level                                     Recommendation
# 1154     Intermediate  Encryption And Decryption Using C++,Create a S...
# 593          Advanced  The Art & Science of Product Management,The Bu...
# 2160         Beginner  Managerial Accounting Fundamentals,Introductio...
# 3190         Advanced  Computational Thinking for K-12 Educators Vari...
# 2498         Beginner  Introduction to PicsArt for Social Media Marke...

# %%
#pycaret setup
from pycaret.nlp import *
# clf = setup(data, target = 'Course_Name', session_id=562, silent = True)

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
# %time su_1 = setup(data = data, target = 'tags', session_id=21, custom_stopwords = stop_words)
# Out:
# <style  type="text/css" >
# </style><table id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5c" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow0_col1" class="data row0 col1" >21</td>
#             </tr>
#             <tr>
#                                 <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow1_col0" class="data row1 col0" >Documents</td>
#                         <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow1_col1" class="data row1 col1" >3522</td>
#             </tr>
#             <tr>
#                                 <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow2_col0" class="data row2 col0" >Vocab Size</td>
#                         <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow2_col1" class="data row2 col1" >13451</td>
#             </tr>
#             <tr>
#                                 <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow3_col0" class="data row3 col0" >Custom Stopwords</td>
#                         <td id="T_1d33d16c_9b0c_11ec_b9a4_5c3a45ab6a5crow3_col1" class="data row3 col1" >True</td>
#             </tr>
#     </tbody></table>
# Wall time: 36.8 s

# %%
# %time m1 = create_model(model='lda', multi_core=True)
# Out:
# Wall time: 8.98 s

# %%
# %time lda_data = assign_model(m1)
# Out:
# IntProgress(value=0, description='Processing: ', max=3527)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      21:38:31
# Status     . . . . . . . . . . . . . . . . . .  Extracting Topics from Model
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
lda_data.head()
# Out:
#                                          Course_Name Difficulty_Level  \
# 0  Write,A,Feature,Length,Screenplay,For,Film,Or,...         Beginner
# 1  Business,Strategy,Business,Model,Canvas,Analys...         Beginner
# 2                      Silicon,Thin,Film,Solar,Cells         Advanced
# 3                               Finance,for,Managers     Intermediate
# 4       Retrieve,Data,using,Single-Table,SQL,Queries         Beginner
#
#                                   Course_Description  \
# 0  Write,a,Full,Length,Feature,Film,Script,In,thi...
# 1  By,the,end,of,this,guided,project,you,will,be,...
# 2  This,course,consists,of,a,general,presentation...
# 3  When,it,comes,to,numbers,there,is,always,more,...
# 4  In,this,course,you�ll,learn,how,to,effectively...
#
#                                               Skills  Course Rating  \
# 0  Drama  Comedy  peering  screenwriting  film  D...            4.8
# 1  Finance  business plan  persona user experienc...            4.8
# 2  chemistry  physics  Solar Energy  film  lambda...            4.1
# 3  accounts receivable  dupont analysis  analysis...            4.8
# 4  Data Analysis  select sql  database management...            4.6
#
#                                                 tags   Topic_0   Topic_1  \
# 0  write feature length screenplay film full leng...  0.123542  0.001361
# 1  business strategy analysis mirobeginnerby end ...  0.964198  0.003688
# 2  film solar course consist general base silicon...  0.002129  0.851829
# 3  finance come number always meet eye operationa...  0.652524  0.338489
# 4  retrieve datum use single table sql course lea...  0.022090  0.001827
#
#     Topic_2   Topic_3 Dominant_Topic  Perc_Dominant_Topic
# 0  0.746328  0.128770        Topic 2                 0.75
# 1  0.003598  0.028516        Topic 0                 0.96
# 2  0.143968  0.002074        Topic 1                 0.85
# 3  0.004509  0.004478        Topic 0                 0.65
# 4  0.058117  0.917966        Topic 3                 0.92

# %%
plot_model()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="94c4dff9-65d9-4f0a-8d60-2b785a08d772" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("94c4dff9-65d9-4f0a-8d60-2b785a08d772")) {                    Plotly.newPlot(                        "94c4dff9-65d9-4f0a-8d60-2b785a08d772",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","x":["course","learn","use","project","business","datum","design","science","management","analysis","model","create","development","also","system","computer","basic","learning","work","process","understand","strategy","skill","machine","programming","include","student","able","provide","application","language","software","develop","make","concept","base","health","help","tool","take","leadership","need","apply","experience","knowledge","build","information","data","new","well","explore","technology","web","end","different","learner","complete","program","part","specialization","practice","problem","marketing","security","method","research","introduce","world","technique","teach","write","key","product","way","first","focus","introduction","cover","communication","change","give","time","network","plan","human","people","finance","level","material","set","many","value","market","week","service","important","global","study","social","topic"],"y":[10136,4730,4234,2909,2901,2840,2379,2194,2153,1923,1656,1603,1579,1557,1522,1443,1326,1325,1310,1284,1283,1274,1263,1236,1228,1196,1189,1150,1149,1140,1124,1121,1119,1103,1091,1084,1063,1031,1031,1016,1002,996,994,982,969,969,955,922,902,897,871,870,855,855,837,831,830,814,804,798,783,741,739,726,722,716,711,702,689,684,683,676,674,673,660,655,648,641,641,623,621,619,617,604,595,593,591,585,583,573,570,564,558,551,546,545,539,538,536,530],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111 ...

# %%
lda2 = create_model('lda', num_topics = 6, multi_core = True)

# %%
print(lda2)
# Out:
# LdaModel(num_terms=13451, num_topics=6, decay=0.5, chunksize=100)

# %%
lda_results = assign_model(lda2)
lda_results.head()
# Out:
# IntProgress(value=0, description='Processing: ', max=3527)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      21:38:31
# Status     . . . . . . . . . . . . . . . . . .  Extracting Topics from Model
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
plot_model()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4ada1624-7e84-4629-b355-3fe5b2abab7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("4ada1624-7e84-4629-b355-3fe5b2abab7d")) {                    Plotly.newPlot(                        "4ada1624-7e84-4629-b355-3fe5b2abab7d",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","x":["course","learn","use","project","business","datum","design","science","management","analysis","model","create","development","also","system","computer","basic","learning","work","process","understand","strategy","skill","machine","programming","include","student","able","provide","application","language","software","develop","make","concept","base","health","help","tool","take","leadership","need","apply","experience","knowledge","build","information","data","new","well","explore","technology","web","end","different","learner","complete","program","part","specialization","practice","problem","marketing","security","method","research","introduce","world","technique","teach","write","key","product","way","first","focus","introduction","cover","communication","change","give","time","network","plan","human","people","finance","level","material","set","many","value","market","week","service","important","global","study","social","topic"],"y":[10136,4730,4234,2909,2901,2840,2379,2194,2153,1923,1656,1603,1579,1557,1522,1443,1326,1325,1310,1284,1283,1274,1263,1236,1228,1196,1189,1150,1149,1140,1124,1121,1119,1103,1091,1084,1063,1031,1031,1016,1002,996,994,982,969,969,955,922,902,897,871,870,855,855,837,831,830,814,804,798,783,741,739,726,722,716,711,702,689,684,683,676,674,673,660,655,648,641,641,623,621,619,617,604,595,593,591,585,583,573,570,564,558,551,546,545,539,538,536,530],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111 ...

# %%
# <==== Code starts here ====>

courses_list = load_model('course_list')
similarity = load_model('similarity')
courses = load_model('courses')
def recommend(course):
    index = courses_list[courses_list['course_name'] == course].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_course_names = []
    for i in distances[1:7]:
        course_name = courses_list.iloc[i[0]].course_name
        recommended_course_names.append(course_name)

    return recommended_course_names
# Out:
# Model Sucessfully Loaded
# Model Sucessfully Loaded
# Model Sucessfully Loaded

# %%
# course_list = courses_list['course_name'].values

# %%
courses_list
# Out:
# {'course_name': {1154: 'Build CRUD REST API in Django',
#   593: 'Acing the Product Management Interview',
#   2160: 'Conduct a Cost-Benefit Analysis in Google Sheets',
#   3190: 'Computational Thinking for K-12 Educators Sequences and Loops',
#   2498: 'Edit Your Photos for Social Media Marketing using PicsArt',
#   3004: 'Becoming a Social Entrepreneur Getting Started',
#   3210: 'Capstone Creating A Sustainability Proposal',
#   577: 'JavaScript Strings Properties and Methods',
#   142: 'Tracking Student Growth using Google Slides',
#   1068: 'Fundamentals of Modern Russian-designed NPPs with VVER-1200',
#   75: 'Animals and Institutions',
#   690: 'Current-Mode Control',
#   579: 'Java Inheritance Composition and Aggregation',
#   2512: 'Foundations for Interviewing with Confidence',
#   69: 'Create an FPS Weapon in Unity (Part 1 - Revolver)',
#   2521: 'TensorFlow for AI Neural Network Representation',
#   2964: 'Qualitative Data Analysis with MAXQDA Software',
#   906: 'Revolutionary Ideas Borders Elections Constitutions Prisons',
#   1306: 'Artificial Intelligence Ethics in Action',
#   377: 'Calculating Descriptive Statistics in R',
#   60: 'Change Leadership Developing Force Field Analysis in Miro',
#   2400: 'Supervised Learning Regression',
#   2554: 'Population Health Syndemics',
#   2559: 'Change Leadership Strategic Route Analysis with Miro',
#   2568: 'Tinkering Fundamentals Motion and Mechanisms',
#   938: 'Qualitative Research Design',
#   1471: 'Design Computing 3D Modeling in Rhinoceros with Python/Rhinoscript',
#   3012: 'Introduction to Integrative Nursing',
#   2435: 'Collaborate on Files in Slack Local & Google Drive Integrations',
#   1008: 'Terraform Basics Automate Provisioning of AWS EC2 Instances',
#   2394: 'Chemical Biology',
#   560: 'Compare time series predictions of COVID-19 deaths',
#   1366: 'Finding bibliography metrics using the Crossref API',
#   298: 'Encryption And Decryption Using C++',
#   1347: 'Getting Started with ProfitBooks',
#   109: 'Big data and Language 2',
#   1032: 'Getting Started with Linux Terminal',
#   1340: 'The Art & Science of Product Management',
#   2434: 'Reclaiming the Street',
#   2460: 'The Power of Machine Learning Boost Business Accumulate Clicks Fight Fraud and Deny Deadbeats',
#   1463: 'Generative Design for Part Consolidation',
#   1053: 'Run a Sparkline Trend Analysis in Google Sheets',
#   2297: 'Create a Google Video Ads Sequence Campaign',
#   549: 'My Favorite Lectures @ HKUST',
#   964: 'Palliative Care Capstone Projects',
#   2268: 'Modern Robotics Course 6 Capstone Project Mobile Manipulation',
#   2789: 'Containerization Using Docker',
#   2233: "Exploring Beethoven's Piano Sonatas Part 6",
#   3149: 'Simple Nearest Neighbors Regression and Classification',
#   3013: 'Magnetics for Power Electronic Converters',
#   3160: 'Web and Mobile Testing with Selenium',
#   1273: 'Create Fault Tolerant MongoDB Cluster',
#   2401: 'Supervised Learning Regression',
#   1893: 'Intermediate Intel� Distribution of OpenVINO� toolkit for Deep Learning Applications',
#   805: 'Create a Google Ads Video Campaign',
#   33: 'Advanced Speaking and Listening Project',
#   1881: 'Artificial Intelligence Privacy and Convenience',
#   799: 'Creating a Customer Service Survey Using Google Forms',
#   3397: 'Population Health Predictive Analytics',
#   1155: 'Digitalisation in Aeronautics',
#   2689: 'Machine Learning Rapid Prototyping with IBM Watson Studio',
#   27: 'AWS Elastic Beanstalk Build & Deploy a Node.js RESTful API',
#   1129: 'Science of Training Young Athletes Part 2',
#   2617: 'Impute Data to Forecast Demand in Google Sheets',
#   1785: 'JavaScript Numbers Properties and Methods',
#   1661: 'A Geometrical Approach to Genome Analysis Skew & Z-Curve',
#   2722: 'Cleaning Reshaping and Expanding Datasets in Python',
#   1847: 'Exploring Beethoven�s Piano Sonatas Part 2',
#   2725: 'Source control management for test automation with Git',
#   2773: 'SAS Macro Language',
#   196: 'AWS Elastic BeanstalkDeploy a Python(Flask) Web Application',
#   1666: 'Computational Thinking for K-12 Educators Conditional Loops and If Statements',
#   2684: 'Structured Query Language (SQL) using SAS',
#   437: 'Digital Signal Processing 4 Applications',
#   1237: 'Computational Thinking for K-12 Educators Nested If Statements and Compound Conditionals',
#   2891: 'Introduction to Unit Testing in Jest - The Fundamentals',
#   2644: 'Cognitive Solutions and RPA Analytics',
#   3505: 'Programming Languages Part C',
#   1753: 'Applied Public History Places People Stories',
#   455: 'Learn to Teach Java ArrayLists and 2D Arrays',
#   1613: 'Fundamentals of Social Media Advertising',
#   1734: 'TensorFlow for AI Applying Image Convolution',
#   2619: 'Computational Thinking for K-12 Educators Abstraction Methods and Lists',
#   3311: 'Agile Projects Defining Epics and Mapping Value with Taiga',
#   1704: 'Machine Translation',
#   1764: 'Promote the Ethical Use of Data-Driven Technologies',
#   1908: 'Stock Valuation with Dividend Discount Model',
#   1777: 'Cloud Systems Software',
#   3477: 'Cluster Analysis using RCmdr',
#   1611: 'Population Health Panel Management Next Level',
#   2756: 'Constructivism and Mathematics Science and Technology Education',
#   2421: 'Addiction Treatment Clinical Skills for Healthcare Providers',
#   1158: 'Psychosocial and Spiritual Aspects of Palliative Care',
#   2731: 'Anatomy Human Neuroanatomy',
#   2404: 'Multi-Axis CNC Toolpaths',
#   2408: 'Build a Modern Computer from First Principles Nand to Tetris Part II (project-centered course)',
#   1345: 'Lactation Biology',
#   2611: 'Analyzing Big Data with SQL',
#   609: 'Single Page Web Applications with AngularJS',
#   572: 'Accounting Analysis I The Role of Accounting as an Information System',
#   1328: 'Teach English Now! Second Language Listening Speaking and Pronunciation',
#   2633: 'Teach English Now! Lesson Design and Assessment',
#   601: 'Conduct Sales Projections with Seasonality in Google Sheets',
#   2651: 'Learn to Speak Korean 1',
#   1304: 'Contemporary Russian Literature',
#   2665: 'Action-Driven Business Plan From the �Classroom� to the World',
#   2517: 'Customising your models with TensorFlow 2',
#   2513: 'Getting Started with Google Classroom',
#   2666: 'Procurement Negotiation',
#   1230: 'Tweet Emotion Recognition with TensorFlow',
#   2509: 'Science Literacy',
#   2670: '3D CAD Application',
#   2507: 'Anatomy Gastrointestinal Reproductive and Endocrine Systems',
#   1215: 'Learn to Teach Java Sequences Primitive Types and Using Objects',
#   2697: 'Excel Skills for Business Essentials',
#   266: 'Getting started in cryo-EM',
#   1327: 'Teach English Now! Second Language Listening Speaking and Pronunciation',
#   1193: 'Improving Deep Neural Networks Hyperparameter tuning Regularization and Optimization',
#   248: 'Collaborative Foresight How to Game the Future',
#   1761: 'Algorithms Part II',
#   290: 'iOS Project Transreality Game',
#   1609: 'Encouraging Student Growth with Teach Your Monster to Read',
#   488: 'Teaching Impacts of Technology Fundamentals',
#   1912: 'Teach English Now! Second Language Reading Writing and Grammar',
#   1913: 'Teach English Now! Second Language Reading Writing and Grammar',
#   1930: 'Programming Languages Part B',
#   1945: 'Astrobiology Exploring Other Worlds',
#   1947: 'Check Point Jump Start Network Security',
#   493: 'History of Medical Cannabis',
#   504: 'Brand Management Aligning Business Brand and Behaviour',
#   1598: 'Data Analytics Foundations for Accountancy II',
#   1969: 'American Contract Law I',
#   1973: 'Quantum Optics 1  Single Photons',
#   1589: 'Understanding and Managing the Stresses of Police Work',
#   389: 'Introduction to Social Media Marketing',
#   1565: 'Developing the SIR Model',
#   410: 'IBM Data Topology',
#   1899: 'Medical Neuroscience',
#   1636: 'Product and Service Development Empathy Mapping with Miro',
#   1878: 'Herbal Medicine',
#   422: 'Agile Projects Creating User Stories with Value in Taiga',
#   1639: 'Global Strategy II Doing Business in The Global Economy',
#   426: 'Hearing Loss in Children',
#   1659: 'Coding for Designers Managers & Entrepreneurs III',
#   475: 'The Newborn Assessment',
#   473: 'Understanding Medical Research Your Facebook Friend is Wrong',
#   1822: 'Implant Dentistry',
#   1816: 'Foundations of Healthcare Systems Engineering',
#   1693: 'Create a Simple Gantt Chart using Google Sheets',
#   1694: 'Mindfulness in Integrative Healthcare',
#   1695: 'Mindfulness in Integrative Healthcare',
#   1792: 'Quantum Optics 2 - Two photons and more',
#   1783: 'More on Change and Sustainability',
#   2016: 'Create a Record of Students using Arrays in Java',
#   380: 'Creating Models using Smartpls',
#   2397: 'Explorations in Confucian Philosophy',
#   1378: 'Java Decision Programming',
#   2258: 'American Contract Law II',
#   319: 'Advanced Modeling for Discrete Optimization',
#   2275: 'Mountains 101',
#   2303: 'Predictive Analytics for Business with H2O in R',
#   2315: 'Building Classroom Community Using Flipgrid',
#   2318: '3-Axis Machining with Autodesk Fusion 360',
#   1375: 'Guitar Chord Voicings Playing Up The Neck',
#   510: 'Chemerinsky on Constitutional Law � Individual Rights and Liberties',
#   555: 'Improving Your Statistical Questions',
#   1374: 'Foundations of Public Health Practice Health Protection',
#   2363: 'Dino 101 Dinosaur Paleobiology',
#   2374: 'Teach English Now! Lesson Design and Assessment',
#   2380: 'Roman Architecture',
#   2384: 'Application of Health Equity Research Methods for Practice and Policy',
#   2231: 'Teach English Now! Theories of Second Language Acquisition',
#   2230: 'Teach English Now! Theories of Second Language Acquisition',
#   2182: 'Excel Skills for Business Intermediate I',
#   1483: 'Unraveling the Cycling City',
#   2154: 'GIS Mapping and Spatial Analysis Capstone',
#   2153: 'Statistical Forecasting Techniques in Google Sheets',
#   2148: 'Research for Impact',
#   2135: 'Chimpanzee Behavior and Conservation',
#   2134: 'Guidance to Keep Newborn Babies Safe and Healthy',
#   2129: 'Build a Modern Computer from First Principles From Nand to Tetris (Project-Centered Course)',
#   359: 'Global Arctic',
#   2122: 'Write Like Mozart An Introduction to Classical Music Composition',
#   2114: 'Testing for Web Accessibility With Accessibility Insights',
#   2108: 'Everyday Excel Part 2',
#   2086: 'Visualization for Data Journalism',
#   516: 'Understanding the Brain The Neurobiology of Everyday Life',
#   2045: 'Predict Sales and Forecast Trends in Google Sheets',
#   2261: 'Trauma Emergencies and Care',
#   229: 'Researcher Management and Leadership Training',
#   1153: 'The Fundamentals of Computing Capstone Exam',
#   3082: 'Plant Bioinformatics Capstone',
#   3174: 'Ash-Related Operational Challenges in Energy Utilization of Sustainable Fuels',
#   3167: 'Equine Welfare and Management',
#   953: 'Impacting the Opioid Crisis Prevention Education and Practice for Non-Prescribing Providers',
#   954: 'Product Development Customer Journey Mapping with Miro',
#   681: 'Thoracic Oncology',
#   3135: 'TensorFlow Serving with Docker for Model Deployment',
#   963: 'Manipulate Object Properties with C# in Unity',
#   3106: 'Computational Social Science Capstone Project',
#   101: 'Voice Disorders What Patients and Professionals Need to Know',
#   969: 'Change Leadership Developing Strategic Gap Analysis in Miro',
#   3092: 'Planet Earth...and You!',
#   3089: 'Creating Cutscenes in Unity',
#   671: 'First Step Korean',
#   991: 'Neural Networks and Deep Learning',
#   648: 'Social Marketing Capstone Project',
#   995: 'The Horse Course Introduction to Basic Care and Management',
#   3069: 'Building a Hiring Plan by Analyzing Past Data in Sheets',
#   117: 'Information & Digital Literacy for University Success',
#   118: 'Improving Classroom Management with Class Dojo',
#   3054: 'Kinematics Describing the Motions of Spacecraft',
#   3049: 'COVID-19 Contact Tracing',
#   3040: 'Forecasting Skills See the Future Before it Happens',
#   1047: "Exploring Beethoven's Piano Sonatas Part 4",
#   130: 'Disinformation Misinformation and Fake News Teach-Out',
#   1054: 'Motivating Gen Z Learners What Parents and Teachers Need to Know',
#   3019: 'Mandarin Chinese 3 Chinese for Beginners',
#   3006: 'Curanderismo Traditional Healing of the Mind Energy & Spirit',
#   2991: 'Advanced TestNG Framework and Integration with Selenium',
#   3204: 'Health Behavior Change From Evidence to Action',
#   933: 'Implementing Parent Feedback with Google Forms',
#   3224: 'Battery Pack Balancing and Power Estimation',
#   3232: 'Product Development Customer Persona Development with Miro',
#   3518: 'Patrick Henry Forgotten Founder',
#   3506: 'Visionary leadership identity & motivation Become a meaning maker',
#   745: 'Teach English Now! Foundational Principles',
#   7: 'Programming Languages Part A',
#   746: 'Teach English Now! Foundational Principles',
#   3468: 'Getting started with TensorFlow 2',
#   3460: 'Statistical Molecular Thermodynamics',
#   3455: 'Brand New Brand',
#   3439: 'US Social Services Where did they come from?',
#   3436: 'Protecting Cloud Architecture with Alibaba Cloud',
#   793: 'International Labour Law',
#   3410: 'International Law In Action Investigating and Prosecuting International Crimes',
#   3404: 'Federal Taxation I Individuals Employees and Sole Proprietors',
#   26: 'Population Health Alternative Payment Models',
#   29: 'Poverty & Population How Demographics Shape Policy',
#   3385: 'Mastering Programming with MATLAB',
#   3354: 'Public Health in Humanitarian Crises 2',
#   3353: 'Paleontology Theropod Dinosaurs and the Origin of Birds',
#   864: 'Validity and Bias in Epidemiology',
#   3299: 'Technology Leadership and Entrepreneurship',
#   55: 'Teaching Children with Visual Impairment Creating Empowering Classrooms',
#   3288: 'Modern Robotics Course 2 Robot Kinematics',
#   899: 'Using Seesaw for Student Learning',
#   901: 'Enhancing Communication with Remind',
#   3256: 'Negotiation Mediation and Conflict Resolution - Capstone Project',
#   3245: 'Everyday Parenting The ABCs of Child Rearing',
#   3242: 'An Introduction to Interactive Programming in Python (Part 2)',
#   147: 'Bugs 101 Insect-Human Interactions',
#   3141: 'Health Housing and Educational Services',
#   2939: 'GIS Data Acquisition and Map Design',
#   2899: "Exploring Beethoven's Piano Sonatas Part 5",
#   2833: 'How to Make Image Editing Selections in GIMP',
#   2910: 'Just Reading and Writing English 2',
#   633: 'Queering the Schoolhouse LGBTQ+ Inclusion for Educators',
#   2865: 'Educating Deaf Children Becoming an Empowered Teacher',
#   2831: 'Spatial Analysis and Satellite Imagery in a GIS',
#   1095: 'Challenging Forensic Science How Science Should Speak to Court',
#   2900: 'China�s Economic Transformation Part 1 Economic Reform and Growth in China',
#   643: 'Modern Robotics Course 4 Robot Motion Planning and Control',
#   183: 'Russian company law. Formation of legal entities.',
#   2906: 'Introduction to Breast Cancer',
#   2816: 'Industrial Organization Strategy and Competition in Business',
#   1121: 'Leveraging Mentions and Threads in Slack',
#   2885: 'Introduction to Self-Determination Theory An approach to motivation development and wellness',
#   2875: 'Character Setup and Animation',
#   2878: 'BMC and Start-up Funding for Early-Stage Start-ups',
#   1124: 'Conflict Transformation',
#   859: 'Foundations of Public Health Practice Behaviour & Behaviour Change',
#   1562: 'The Holocaust - An Introduction (II) The Final Solution',
#   862: 'The Modern World Part One Global History from 1760 to 1910',
#   879: 'Docker Essentials & Building a Containerized Web Application',
#   1570: 'Web Design Strategy and Information Architecture',
#   1572: 'Accessible Landing Page Solutions in XD',
#   1603: 'Applications in Engineering Mechanics',
#   865: 'Imagery Automation and Applications',
#   1573: 'Moral Foundations of Politics',
#   1578: 'Geospatial Analysis Project',
#   871: 'HPV-Associated Oral and Throat Cancer What You Need to Know',
#   1594: 'Simulation Analysis for Mechanical Engineers with Autodesk Fusion 360',
#   881: 'Qualitative Data Collection Methods',
#   1595: 'Camera Control',
#   1130: 'Hybrid Cloud Multi-Cluster with Anthos',
#   869: 'Unethical Decision Making in Organizations',
#   1090: 'Financial Accounting Fundamentals',
#   1561: 'An Introduction to Global Health',
#   1558: 'Basics of Extracellular Vesicles',
#   917: 'Software Design Threats and Mitigations',
#   1516: 'Electrodynamics Electric and Magnetic Fields',
#   1522: 'Feminism and Social Justice',
#   1525: 'Cyber Threat Intelligence',
#   1526: 'Cyber Threat Intelligence',
#   907: 'Multimodal Literacies Communication and Learning in the Era of Digital Media',
#   1528: 'Marketing Management I',
#   1538: 'Police Brutality in America Teach-Out',
#   1540: 'Anatomy Musculoskeletal and Integumentary Systems',
#   1541: 'Monetary Policy in the Asia Pacific',
#   1544: 'Foundations for Big Data Analysis with SQL',
#   1222: 'Strategic Innovation Building and Sustaining Innovative Organizations',
#   1221: 'Refugees in the 21st Century',
#   1547: 'Conjunctions Connectives and Adverb Clauses',
#   894: 'Getting Started with Blazor WASM',
#   1552: 'Mechanics of Materials III Beam Bending',
#   841: 'Safety in the Utility Industry',
#   1555: 'Sustainable Food Production Through Livestock Health Management',
#   889: 'Business English for Cross-cultural Communication',
#   850: 'Songwriting Writing the Lyrics',
#   809: 'CAM and Design Manufacturing for Mechanical Engineers with Autodesk Fusion 360',
#   831: 'Building a Business Presence With Facebook Marketing',
#   792: 'Giving Helpful Feedback',
#   776: 'Protecting Business Innovations via Trademark',
#   770: 'Organisational design Know your organisation',
#   1673: 'Infection Prevention in Nursing Homes',
#   1140: 'Using probability distributions for real world problems in R',
#   1678: 'Entrepreneurship I Laying the Foundation',
#   1683: 'Accounting Business and Society The Multi-faceted Role of Accounting',
#   1687: 'Introduction to battery-management systems',
#   1689: 'Professional development Improve yourself always',
#   769: 'Sports and Building Aerodynamics',
#   756: 'Predict Ideal Diamonds over Good Diamonds using a Random Forest using R',
#   1188: 'Managerial Accounting Fundamentals',
#   1185: 'Technical Support Fundamentals',
#   747: 'Python Functions Files and Dictionaries',
#   1149: 'Core Concepts of Accounting � Numbers and People',
#   1696: 'The Foundations of Cybersecurity',
#   1180: 'Avoid Overfitting Using Regularization in TensorFlow',
#   1702: 'The Global Financial Crisis',
#   744: 'Advanced Engineering Systems in Motion Dynamics of Three Dimensional (3D) Motion',
#   1714: 'The Age of Sustainable Development',
#   1164: 'Corporate Finance Essentials',
#   1150: 'International Humanitarian Law in Theory and Practice',
#   778: 'International Leadership and Organizational Behavior',
#   1663: 'Bridging the Gap between Strategy Design and Delivery',
#   817: 'Supply Chain Operations',
#   794: 'Effectively delivering the news to your audience',
#   812: 'Internet Giants The Law and Economics of Media Platforms',
#   810: 'Speaking to inform Discussing complex ideas with clear explanations and dynamic slides',
#   1134: 'Identifying Monitoring and Analyzing Risk and Incident Response and Recovery',
#   1211: 'Concepts in Python Loops Functions and Returns',
#   1615: 'Practical SAS Programming and Certification Review',
#   1616: 'G Suite Mail Management',
#   808: 'What is Palliative Care?',
#   1618: 'Exploring and Producing Data for Business Decision Making',
#   806: 'Photography Techniques Light Content and Sharing',
#   1630: 'Act on Climate Steps to Individual Community and Political Action',
#   1633: 'Introduction to Hearing Loss',
#   1206: 'Cannabis Mental Health and Brain Disorders',
#   802: 'Extracellular Vesicles in Health and Disease',
#   1637: 'An Intuitive Introduction to Probability',
#   1201: 'Fundamentals of Management with Goldman Sachs 10 000 Women',
#   797: 'Introduction to Advanced tomography',
#   1200: 'Songwriting Writing the Lyrics',
#   1651: 'Introduction to Formal Concept Analysis',
#   1658: 'Career planning resume/CV cover letter interview',
#   1136: 'Water in the Western United States',
#   1194: 'Essentials of Global Health',
#   919: 'Introduction to Complex Analysis',
#   927: 'Innovation Career Lessons from a Master',
#   1232: 'Everyday Chinese Medicine 2',
#   1111: 'Business English Planning & Negotiating',
#   1014: 'Information Visualization Advanced Techniques',
#   1351: 'Graphic Elements of Design Color Theory and Image Formats',
#   1362: 'Grow Your Business with Goldman Sachs 10 000 Women',
#   1012: 'Django Features and Libraries',
#   1277: 'Connecting with Sales Prospects',
#   1363: 'Advanced Financial Reporting Accounting for Business Combinations and Preparation of Consolidated Financial Statements',
#   1099: 'Enterprise Systems',
#   1005: 'Ready Set Future! Introduction to Futures Thinking',
#   1100: 'The Merkle Tree and Cryptocurrencies',
#   1270: 'Logging Monitoring and Observability in Google Cloud',
#   1364: 'Build Your First React Website (Part II)',
#   1265: 'Introduction to Cloud Computing',
#   997: 'Understanding Cancer Metastasis',
#   1103: 'The Business of Product Management I',
#   1264: 'Approximation Algorithms Part II',
#   985: 'De-Mystifying Mindfulness',
#   983: 'Preparing to Manage Human Resources',
#   1104: 'Introduction to Systematic Review and Meta-Analysis',
#   1369: 'Data Analysis and Reporting in SAS Visual Analytics',
#   1370: 'Fundamentals of Customers and Competition with Goldman Sachs 10 000 Women',
#   1262: 'Create Your First NoSQL Database with MongoDB and Compass',
#   1344: 'Childbirth A Global Perspective',
#   1035: 'Create and Format a Basic Document with LibreOffice Writer',
#   1039: 'Business English Making Presentations',
#   1066: 'Learning How to Learn Powerful mental tools to help you master tough subjects',
#   1085: 'Logistic Regression in R for Public Health',
#   1083: 'IT Infrastructure and Emerging Trends',
#   1300: 'Science of Exercise',
#   1299: 'Introduction to Agent-based Modeling with NetLogo',
#   1308: 'Nursing Informatics Training and Education',
#   1077: 'Using Data for Geographic Mapping and Forecasting in SAS Visual Analytics',
#   1293: 'Mindshift Break Through Obstacles to Learning and Discover Your Hidden Potential',
#   1069: 'The Cycle Management of Successful Arts and Cultural Organizations',
#   1318: 'Accessibility to the Scenic Arts',
#   1290: 'System Validation (4) Modelling Software Protocols and other behaviour',
#   1280: 'Factorial and Fractional Factorial Designs',
#   1062: 'Creating a Student Profile in Google Docs',
#   1322: 'Mechanics of Materials I Fundamentals of Stress & Strain and Axial Loading',
#   1323: 'Assessment in Higher Education Professional Development for Teachers',
#   1059: 'Study Designs in Epidemiology',
#   1284: 'How to Manage a Remote Team',
#   1048: 'Moralities of Everyday Life',
#   1331: 'Foundations of Mindfulness',
#   1336: 'Skills for Nursing Informatics Leaders',
#   1337: 'Containerize a full-stack NodeJS application in Docker',
#   981: 'Firm Level Economics Markets and Allocations',
#   1112: 'Clinical Terminology for International and U.S. Students',
#   924: 'Using SAS Viya REST APIs with Python and R',
#   1376: 'Dynamical Modeling Methods for Systems Biology',
#   1435: 'Blended Learning Personalizing Education for Students',
#   1437: 'Business Strategies for Emerging Markets',
#   1439: 'Build personal resilience',
#   1442: 'Vector Calculus for Engineers',
#   1444: 'Mechanics of Materials II Thin-Walled Pressure Vessels and Torsion',
#   1445: 'Rethinking International Tax Law',
#   1456: 'Corporate & Commercial Law I Contracts & Employment Law',
#   945: 'Getting Started with Azure DevOps Boards',
#   1466: 'Buddhism and Modern Psychology',
#   1467: 'Machine Learning with H2O Flow',
#   1119: 'Arts and Heritage Management',
#   1473: 'Queering Identities LGBTQ+ Sexuality and Gender Identity',
#   1476: 'Cybersecurity in Healthcare (Hospitals & Care Centres)',
#   935: 'A tecnologia da produ��o musical',
#   1234: 'Transformation of the Global Food System',
#   930: 'Principles of Computing (Part 1)',
#   1493: 'Blended Language Learning Design and Practice for Teachers',
#   1497: 'Customer Value in Pricing Strategy',
#   1505: 'Introduction to GIS Mapping',
#   1087: 'Managing ADHD Autism Learning Disabilities and Concussion in School',
#   1507: 'Engaging and Assessing Students with Plickers',
#   1238: 'Introduction to Typography',
#   1422: 'Create a Budget with Google Sheets',
#   1411: 'Automated Reasoning satisfiability',
#   1390: 'Resilient Teaching Through Times of Crisis and Change',
#   977: 'Performing Data Aggregation using SQL Aggregate Functions',
#   1382: 'Confronting Gender Based Violence Global Lessons for Healthcare Workers',
#   970: 'Internet of Things Capstone V2 Build a Mobile Surveillance System',
#   1261: 'Modeling and Design for Mechanical Engineers with Autodesk Fusion 360',
#   1250: 'Journey Conversations Weaving Knowledge and Action',
#   1383: 'Introduction to Household Water Treatment and Safe Storage',
#   1249: 'Nanotechnology A Maker�s Course',
#   965: 'Interactive Word Embeddings using Word2Vec and Plotly',
#   1388: 'The Science of the Solar System',
#   1393: 'Leadership in Interprofessional Informatics',
#   1407: 'Myocardial Infarction',
#   1720: 'Economics of Money and Banking',
#   958: 'Google Cloud Fundamentals for Azure Professionals Core Infrastructure',
#   1395: 'Statistical Thinking for Industrial Problem Solving presented by JMP',
#   1398: 'Mandarin Chinese 2 Chinese for Beginners',
#   957: 'CSS Animated Components with ReactJS',
#   1247: 'Introduction to Data Signal and Image Analysis with MATLAB',
#   1156: 'Social Services for Families Seniors and Those with Disabilities',
#   1403: 'DNA Decoded',
#   1405: 'Microeconomics Principles',
#   1716: 'Networking in Google Cloud Hybrid Connectivity and Network Management',
#   2085: 'Semantic Segmentation with Amazon Sagemaker',
#   1726: 'Ecology Ecosystem Dynamics and Conservation',
#   2921: 'Verb Tenses and Passives',
#   2966: 'Global sustainability and corporate social responsibility Be sustainable',
#   2954: 'Music Business Foundations',
#   2952: 'Writing and Editing Drafting',
#   2950: 'Engineering Systems in Motion Dynamics of Particles and Bodies in 2D Motion',
#   2941: 'Foundations of Teaching for Learning Planning for Teaching and Learning',
#   2923: 'Machine Learning Regression',
#   2919: 'GIS Data Formats Design and Quality',
#   3068: 'Healthcare Entrepreneurship Taking Ideas to Market',
#   2917: 'Time Value of Money',
#   2916: 'IBM Customer Engagement Specialist Professional Certificate',
#   2915: 'Engineering Health Introduction to Yoga and Physiology',
#   2904: 'Understanding Prostate Cancer',
#   2895: 'Performing Network Path and Text Analyses in SAS Visual Analytics',
#   2873: 'Converter Control',
#   2968: 'AIDS Fear and Hope',
#   2977: 'Risk in Modern Society',
#   2978: 'The Modern World Part Two Global History since 1910',
#   2992: 'Data Analytics for Lean Six Sigma',
#   2995: 'Entrepreneurship',
#   3002: 'Speaking to Inspire Ceremonial and Motivational Speeches',
#   3014: 'Ferrous Technology II',
#   3027: 'Build a Database from a Relational Model',
#   3029: 'Enhance Student Learning through Kahoot',
#   3030: 'Market and Competition in Pricing Strategy',
#   3031: 'Constitutional Reforms in Russia',
#   3032: 'Managing Change when Moving to Google Cloud',
#   3035: 'Corporate Finance II Financing Investments and Managing Risk',
#   3037: 'Think Again III How to Reason Inductively',
#   3043: 'The Sustainable Development Goals � A global transdisciplinary vision for the future',
#   3044: 'Investments II Lessons and Applications for Investors',
#   3048: 'History of Rock Part One',
#   2864: 'Using Google Forms for Student Success',
#   2863: 'LGBTQ Pride From Origins to Evolution Teach-Out',
#   2860: 'Applications of Everyday Leadership',
#   2712: 'Global Disease Masterclass Communicable Diseases Epidemiology Intervention and Prevention',
#   2632: 'Introduction to Faecal Sludge Management',
#   2637: 'Entrepreneurship Strategy From Ideation to Exit',
#   2643: 'Foundations of Health Equity Research',
#   2656: 'Storytelling and influencing Communicate with impact',
#   2659: 'Public Health in Humanitarian Crises 1',
#   2667: 'Population Health Governance',
#   2669: 'Understanding Korean Politics',
#   2674: 'Getting Started with Cascading Style Sheet',
#   2677: 'Algorithms Part I',
#   2685: 'Introduction to Calculus',
#   2691: 'From the Big Bang to Dark Energy',
#   2698: 'The Beauty of Kunqu Opera',
#   2701: 'Process Mining Data science in Action',
#   2704: 'Extinctions Past Present & Future',
#   2724: 'Journalism the future and you!',
#   2856: 'Outbreaks and Epidemics',
#   2726: 'Spanish Vocabulary Careers and Social Events',
#   2759: 'An Introduction to Accessibility and Inclusive Design',
#   2762: 'Astronomy Exploring Time and Space',
#   2763: 'Introduction to Accessible Web Development',
#   2774: 'Music Production Capstone',
#   2778: 'Protecting Business Innovations via Copyright',
#   2779: 'Fundamentals of Fluid Power',
#   2786: 'Engineering Project Management Risk Quality Teams and Procurement',
#   2792: 'The Worldview of Thomas Berry The Flourishing of the Earth Community',
#   2799: 'Fibonacci Numbers and the Golden Ratio',
#   2814: 'Jazz Improvisation',
#   2821: 'Large Marine Ecosystems Assessment and Management',
#   2829: 'Accounting Principles of Financial Accounting',
#   2842: 'Introduction to Mechanical Engineering Design and Manufacturing with Fusion 360',
#   3052: 'Firm Level Economics Consumer and Producer Behavior',
#   3070: 'Perform Feature Analysis with Yellowbrick',
#   2625: 'The Blues Understanding and Performing an American Art Form',
#   3323: 'Generative Design for Additive Manufacturing',
#   3355: 'Chinese for HSK 1',
#   3344: 'Doing More with SAS Programming',
#   3341: 'Case Studies in Personalized Medicine',
#   3335: 'Music Business Foundations',
#   3333: 'Linear Regression for Business Statistics',
#   3324: 'Driving business towards the Sustainable Development Goals',
#   3320: 'Chinese Politics Part 1 � China and Political Science',
#   3073: 'Federal Taxation II Property Transactions of Business Owners and Shareholders',
#   3313: 'Web Design Wireframes to Prototypes',
#   3310: 'Constitutional Struggles in the Muslim World',
#   3307: 'From Freedom Rides to Ferguson Narratives of Nonviolence in the American Civil Rights Movement',
#   3303: 'Classical Sociological Theory',
#   3296: 'Geospatial and Environmental Analysis',
#   3294: 'Synapses Neurons and Brains',
#   3370: 'Supply Chain Excellence',
#   3378: 'Computers Waves Simulations A Practical Introduction to Numerical Methods using Python',
#   3387: 'Managing Cybersecurity Incidents and Disasters',
#   3388: 'English for Common Interactions in the Workplace Basic Level',
#   3400: 'Analyzing Macro-Environmental Factors Using Creately',
#   3411: 'Introduction to Negotiation A Strategic Playbook for Becoming a Principled and Persuasive Negotiator',
#   3419: 'Understanding Plants - Part I What a Plant Knows',
#   3421: 'Style Images with CSS',
#   3422: 'Improving your statistical inferences',
#   3425: 'Studying at Japanese Universities',
#   3430: 'Introduction to International Criminal Law',
#   3442: 'Anatomy Cardiovascular Respiratory and Urinary Systems',
#   3450: 'Networking and Security Architecture with VMware NSX',
#   3473: 'Noun Clauses and Conditionals',
#   3484: 'Population Health During A Pandemic Contact Tracing and Beyond',
#   3489: 'Grow to Greatness Smart Growth for Private Businesses Part II',
#   3501: 'Capstone Project Teaching Impacts of Technology',
#   3293: 'Create a Google Ads Display Campaign',
#   3286: 'International Law in Action A Guide to the International Courts and Tribunals in The Hague',
#   3285: 'Introduction to Psychology',
#   3148: 'Prehospital care of acute stroke and patient selection for endovascular treatment using the RACE scale',
#   3075: 'Introduction to the Biology of Cancer',
#   3076: 'Hypothesis Testing in Public Health',
#   3077: 'Creativity Toolkit II Creative Collaboration',
#   3085: 'Exploratory Data Analysis with MATLAB',
#   3087: 'Problem-Solving Skills for University Success',
#   3093: 'Style Tables with CSS',
#   3103: 'Foundational Skills for Communicating About Health',
#   3105: 'Introduction to Cataract Surgery',
#   3118: 'Vowels of American English Pronunciation',
#   3121: 'Battery State-of-Health (SOH) Estimation',
#   3125: 'The Challenges of Global Health',
#   3126: 'Understanding User Needs',
#   3130: 'Corporate Strategy',
#   3144: 'Russian for beginners 3. ??????? ???? A1',
#   3154: 'Plant Bioinformatics',
#   3284: 'European Business Law Understanding the Fundamentals',
#   3163: 'The History of Modern Israel - Part II Challenges of Israel as a sovereign state',
#   3180: 'Teach English Now! Technology Enriched Teaching',
#   3181: 'Teach English Now! Technology Enriched Teaching',
#   3209: 'Learn Java and JavaFX by creating a Graphical Calculator',
#   3218: 'Fundamentals of GIS',
#   3229: 'Oil & Gas Industry Operations and Markets',
#   3238: 'Fashion as Design',
#   3240: 'Understanding Clinical Research Behind the Statistics',
#   3247: 'Paleontology Early Vertebrate Evolution',
#   3252: 'Excel/VBA for Creative Problem Solving Part 2',
#   3268: 'Business Applications of Hypothesis Testing and Confidence Interval Estimation',
#   3279: 'Being a researcher (in Information Science and Technology)',
#   3280: 'International Organizations Management',
#   3283: 'Create a Space Shooter Game with Scratch Studio',
#   2628: 'Natural Attenuation of Groundwater Contaminants New Paradigms Technologies and Applications',
#   2621: 'Unsupervised Machine Learning for Customer Market Segmentation',
#   1751: 'Sports and Society',
#   2013: 'DevOps Culture and Mindset',
#   2033: 'Clinical Epidemiology',
#   2027: 'Create Keyboard Movement Mechanics with C# in Unity',
#   2026: 'The Brain and Space',
#   2022: 'Inclusive Online Teaching Teach-Out',
#   2021: 'The Business of Cybersecurity Capstone',
#   2018: 'Qualitative Comparative Analysis (QCA)',
#   2008: 'Evidence-based Toxicology',
#   2178: 'Data Structures and Performance',
#   1999: 'Matrix Algebra for Engineers',
#   1996: 'Experimentation for Improvement',
#   1991: 'Managing the Company of the Future',
#   1988: 'Digital Transformation',
#   1982: 'Introduction to Genetics and Evolution',
#   1971: 'Becoming a changemaker Introduction to Social Innovation',
#   2042: 'Strategic Procurement and Sourcing Conclusions',
#   2044: 'Trade Immigration and Exchange Rates in a Globalized World',
#   2050: 'Summary Statistics in Public Health',
#   2059: 'Design Online Course Printables using Canva',
#   2067: 'Financing and Investing in Infrastructure',
#   2075: 'Using Google Jamboard for Student Learning',
#   2081: 'Generative Design for Industrial Applications',
#   2082: 'Finance for Non-Finance Professionals',
#   737: 'EMT Foundations',
#   2093: 'Psychological First Aid',
#   2098: 'University Teaching',
#   2099: 'The Holocaust - An Introduction (I) Nazi Germany Ideology The Jews and the World',
#   2132: 'Excel/VBA for Creative Problem Solving Part 1',
#   2145: 'Religious Transformation in Early China the Period of Division',
#   2146: 'Setting the Stage for Success An Eye on Safety Culture and Teamwork (Patient Safety II)',
#   2151: 'Using JavaScript JQuery and JSON in Django',
#   2156: 'Population Health Responsible Data Analysis',
#   1967: 'Machine Design Part I',
#   1964: 'Municipal Solid Waste Management in Developing Countries',
#   1962: 'Inferential and Predictive Statistics for Business',
#   1852: 'Business Strategy',
#   1: 'Business Strategy Business Model Canvas Analysis with Miro',
#   1762: 'The Science of Success What Researchers Know that You Should Know',
#   1767: 'Supply chain management Be global',
#   1794: 'Introduction to Advanced Vibrations',
#   1795: 'Sales Training Inbound Business Strategy',
#   1798: 'Accounting Analysis I Measurement and Disclosure of Assets',
#   1801: 'Dairy Production and Management',
#   1808: 'Accounting for Decision Making',
#   1812: 'Essentials in Clinical Simulations Across the Health Professions',
#   1813: 'Exploring Light Hands-on Activities and Strategies for Teachers',
#   1817: 'Aspectos b�sicos de la planificaci�n y la gesti�n de proyectos',
#   1820: 'JavaScript Variables and Assignment Operators',
#   1827: 'Excel/VBA for Creative Problem Solving Part 3 (Projects)',
#   1848: 'Sustainable Development in the 21st Century with Ban Ki-moon',
#   1853: 'Culminating Project in Health Informatics',
#   1951: 'Battery State-of-Charge (SOC) Estimation',
#   1857: 'The Power of Markets III Input Markets and Promoting Efficiency',
#   1860: 'Create a Financial Statement using Google Sheets',
#   1871: 'Python Basics',
#   1873: 'Transacting on the Blockchain',
#   1879: 'Creating Toolpaths for a CNC Lathe',
#   1887: 'Exploratory Data Analysis for Machine Learning',
#   1888: 'Exploratory Data Analysis for Machine Learning',
#   1889: 'Organising an Empire The Assyrian Way',
#   1898: 'Game Development for Modern Platforms',
#   1901: 'Supplier Management',
#   1904: 'Understanding economic policymaking',
#   1909: 'Michigan Sport-Related Concussion Training Certification',
#   1915: 'Analyzing Product Opportunities with Creately',
#   1949: 'Innovation and emerging technology Be disruptive',
#   2175: 'AI For Everyone',
#   2179: 'Data Structures and Performance',
#   2616: 'Solar Energy Codes Permitting and Zoning',
#   2459: 'Protecting Public Health in a Changing Climate A Primer for City Local and Regional Action',
#   2501: 'Biosphere 2 Science for the Future of Our Planet',
#   2496: 'Transfer Learning for NLP with TensorFlow Hub',
#   2493: 'Security & Safety Challenges in a Globalized World',
#   2481: 'FinTech Disruptive Innovation Implications for Society',
#   2475: 'Model Thinking',
#   2461: 'Introduction to Contemporary Geopolitics',
#   2453: 'The GRC Approach to Managing Cybersecurity',
#   2189: 'Statistics with SAS',
#   2446: 'Planning for your G Suite Deployment',
#   2429: 'Paleontology Ancient Marine Reptiles',
#   2419: 'Linear Regression in R for Public Health',
#   2418: 'Introduction to Psychology',
#   2416: 'Convolutional Neural Networks',
#   2414: 'Writing and Editing Revising',
#   2503: 'Business English Management and Leadership',
#   2510: 'Electrodynamics In-depth Solutions for Maxwell�s Equations',
#   2511: 'Seeking Investment Alpha',
#   2523: 'Approximation Algorithms Part I',
#   2526: 'Evaluating Problems',
#   2528: 'Business Opportunities and Risks in a Globalized Economy',
#   2535: 'The Science of Training Young Athletes',
#   2544: 'Introduction to CSS3',
#   2546: 'Supply Chain Management Strategy',
#   2551: 'Fundamentals of Rehearsing Music Ensembles',
#   2555: 'Words Spun Out of Images Visual and Literary Culture in Nineteenth Century Japan',
#   2561: 'Risk governance Engage the board',
#   2584: 'Global Postharvest Loss Prevention Fundamentals Technologies and Actors',
#   2588: 'Compare Inline Internal and External CSS',
#   2590: 'Creating Interactive Learning Videos with Edpuzzle',
#   2596: 'Mind of the Universe Science in Progress',
#   2608: 'Amazon DynamoDB Building NoSQL Database-Driven Applications',
#   2413: 'Mechanics of Materials IV Deflections Buckling Combined Loading & Failure Theories',
#   2402: 'Lesson | Business English Skills How to Navigate Tone Formality and Directness in Emails',
#   2395: 'Adapt your leadership style',
#   2269: 'Marketing Management II',
#   2193: 'Systems and Application Security',
#   2194: 'The Cosmopolitan Medieval Arabic World',
#   2202: 'Introduction to Portfolio Construction and Analysis with Python',
#   2204: 'The Science of Well-Being',
#   2206: 'The Korean Economic Development',
#   2212: 'Getting Started with SAS Programming',
#   2215: 'Emergency Care Pregnancy Infants and Children',
#   2216: 'Nursing Informatics Leadership Theory and Practice',
#   2220: 'High Performance Collaboration Leadership Teamwork and Negotiation',
#   2236: 'English/French Translator Long Short Term Memory Networks',
#   2237: 'Fundamentals of Organization',
#   2238: 'Epidemics',
#   2245: 'Six Sigma Tools for Improve and Control',
#   2249: 'Career planning Your career your life',
#   2270: 'Building on the SIR Model',
#   2392: 'Doing Business in Russia',
#   2278: 'Strategic management Be competitive',
#   2289: 'Urgent Optimism How to Turn Foresight into Action',
#   2294: 'Networking in Google Cloud Defining and Implementing Networks',
#   2295: "America's Unwritten Constitution",
#   2298: 'Sustainable Fashion',
#   2321: 'Media ethics & governance',
#   2328: 'Basic System Programming on IBM Z',
#   2338: 'Leading Change in Health Informatics',
#   2348: 'Foundations of Everyday Leadership',
#   2350: 'Corporate & Commercial Law II Business Forms Financing & Governmental Regulation',
#   2359: 'Speaking to persuade Motivating audiences with solid arguments and moving language',
#   2368: 'Supporting Parents of a Newborn Baby',
#   2370: 'Sustainable Vikings Sustainability & Corporate Social Responsibility in Scandinavia',
#   2389: 'The Neuromarketing Toolbox',
#   742: 'Solar Energy Basics',
#   0: 'Write A Feature Length Screenplay For Film Or Television',
#   469: 'The Art of Music Production',
#   492: 'Building an Ecosystem model with Insight Maker',
#   137: 'History of Rock Part Two',
#   221: 'Professional Responsibility and Ethics for Accountants',
#   340: 'Fundamentals of Immunology T Cells and Signaling',
#   218: 'Excel Skills for Business Intermediate II',
#   216: 'Seeing Through Photographs',
#   73: 'Converter Circuits',
#   213: 'Introduction to Ableton Live',
#   470: 'The Art of Music Production',
#   80: 'Transgender Medicine for General Medical Providers',
#   212: 'Introduction to Ableton Live',
#   81: 'Epigenetic Control of Gene Expression',
#   581: 'Aromatherapy Clinical Use of Essential Oils',
#   169: 'Career Planning A Pathway to Employment',
#   582: 'Aromatherapy Clinical Use of Essential Oils',
#   613: 'Asian Environmental Humanities Landscapes in Transition',
#   479: 'Foundations of Public Health Practice The Public Health Approach',
#   385: 'Autodesk Certified Professional Civil 3D for Infrastructure Design Exam Prep',
#   691: 'Developing Your Musicianship Final Project',
#   365: 'Understanding Plants - Part II Fundamentals of Plant Biology',
#   714: 'Consonants of American English Pronunciation',
#   327: 'Developing a Google SRE Culture',
#   330: 'S�ren Kierkegaard - Subjectivity Irony and the Crisis of Modernity',
#   234: 'Cyber Attack Countermeasures',
#   331: 'Design Thinking and Global Startup',
#   50: 'Integrating Scripts for Scene Interactions',
#   231: 'Food & Beverage Management',
#   621: 'Print and Digital Elements of Design Branding and User Experience',
#   52: 'Managing Asthma Allergies Diabetes and Seizures in School',
#   335: 'Anatomy of the Chest Abdomen and Pelvis',
#   574: 'Solving Algorithms for Discrete Optimization',
#   227: 'Introduction to Environmental Law and Policy',
#   57: 'Prediction and Control with Function Approximation',
#   622: 'Construction Project Management',
#   467: 'Foundations of Teaching for Learning Developing Relationships',
#   583: 'Avatar Psychology for Designers',
#   209: 'Exploring Beethoven�s Piano Sonatas',
#   194: 'Genomics for Law',
#   95: 'Making Architecture',
#   120: 'Risk Return & Valuation',
#   356: 'Surveillance Systems The Building Blocks',
#   442: 'Software Design as an Abstraction',
#   696: 'Expanding SEL',
#   700: 'Copyright for Educators & Librarians',
#   453: 'Differential Equations for Engineers',
#   695: 'Preventative Healthcare for the Newborn Baby',
#   615: 'Structuring Machine Learning Projects',
#   449: 'Hyperparameter Tuning with Neural Network Intelligence',
#   192: 'Cancer Prevention Web-Based Activity',
#   111: 'Bayesian Statistics Mixture Models',
#   113: 'Improving Math Engagement with Prodigy',
#   361: 'Mindware Critical Thinking for the Information Age',
#   94: 'Guided Imagery',
#   702: 'Providing Social Emotional Behavioral and Special Education Services in School',
#   669: 'Mining Quality Prediction Using Machine & Deep Learning',
#   460: 'Programming for Everybody (Getting Started with Python)',
#   207: 'Making Successful Decisions through the Strategy Law & Ethics Model',
#   438: 'Introduction to solar cells',
#   439: 'Mind Control Managing Your Mental Health During COVID-19',
#   205: 'Data-driven Astronomy',
#   123: 'Entrepreneurship II Preparing for Launch',
#   88: 'Introduction to CAD CAM and Practical CNC Machining',
#   204: 'Software Product Management Capstone',
#   93: 'Spacecraft Dynamics Capstone Mars Mission',
#   202: 'Introduction to Programming with MATLAB',
#   704: 'Civic Engagement in American Democracy',
#   91: 'Control physics with C# in Unity',
#   352: 'Corporate Finance I Measuring and Promoting Value Creation',
#   694: 'Global Health and Humanitarianism',
#   703: 'Infonomics II Business Information Management and Measurement',
#   237: "Easing Physical Symptoms It's Not Just Hospice Anymore",
#   428: 'Introduction to Human Behavioral Genetics',
#   255: 'The Art of Music Production',
#   413: 'Global Health Security Solidarity and Sustainability through the International Health Regulations',
#   263: 'Introduction to Accounting Data Analytics and Visualization',
#   676: 'Communication Skills for University Success',
#   156: 'Internet History Technology and Security',
#   259: 'Doing Clinical Research Biostatistics with the Wolfram Language',
#   16: 'Python Programming Essentials',
#   257: 'Leading Positive Change through Appreciative Inquiry',
#   256: 'The Art of Music Production',
#   265: 'Introduction to Game Development',
#   726: 'Evaluate Machine Learning Models with Yellowbrick',
#   655: 'Faster Together Enhancing the Recruitment of Minorities in Clinical Trials',
#   520: 'Non-Communicable Diseases in Humanitarian Settings',
#   254: 'Experimental Design Basics',
#   415: 'Patient Safety and Quality Improvement Developing a Systems View (Patient Safety I)',
#   630: 'Create a Google Ads Search Campaign',
#   157: 'Securing Digital Democracy',
#   305: 'Python Data Structures',
#   154: 'Musicianship Tensions Harmonic Function and Modal Interchange',
#   637: 'Organ Donation From Death to Life',
#   286: 'The Place of Music in 21st Century Education',
#   3: 'Finance for Managers',
#   638: 'Introduction to English Common Law',
#   284: 'Statistical Mechanics Algorithms and Computations',
#   282: 'Marketing Design with Easil',
#   400: 'Basic Modeling for Discrete Optimization',
#   731: 'Learning How To Learn for Youth',
#   158: 'Guided Imagery',
#   276: 'Nutrition and Lifestyle in Pregnancy',
#   296: 'Cost and Economics in Pricing Strategy',
#   532: 'Tableau Public for Project Management and Beyond',
#   160: 'Teach English Now! Capstone Project 1',
#   159: 'Teach English Now! Capstone Project 1',
#   303: 'Methods of Surface Analysis',
#   725: 'Grow to Greatness Smart Growth for Private Businesses Part I',
#   698: 'Art & Ideas Teaching with Themes',
#   308: 'International Law in Action the Arbitration of International Disputes',
#   174: 'When Disaster Meets Conflict',
#   568: 'Biochemical Principles of Energy Metabolism',
#   718: 'Compassionate Leadership Through Service Learning with Jane Goodall and Roots & Shoots',
#   42: 'Disability Inclusion in Education Building Systems of Support',
#   41: 'Global Strategy I How The Global Economy Works',
#   322: 'Introduction to Public Health Engineering in Humanitarian Contexts',
#   39: 'Protecting Business Innovations via Patent',
#   317: 'Create Charts and Dashboard using Google Sheets',
#   393: 'Value Creation The Carlson-Polizzotto Method',
#   148: 'Analyze Website Visitors with Google Analytics Segments',
#   722: 'Local Economic Development',
#   313: 'Astro 101 Black Holes',
#   312: 'Making Sense of the News News Literacy Lessons for Digital Citizens',
#   175: 'Introduction to Git and GitHub',
#   674: 'Current Gen 3D Game Prop Production',
#   416: 'Material Processing',
#   686: 'Sequence Models',
#   509: 'Organisational behaviour Know your people',
#   244: 'Social Media Management',
#   151: 'Textual Elements of Design Fonts Typography and Spacing',
#   508: 'Create UI in Unity Part 1 - Screen Overlay Canvas',
#   30: 'Electrodynamics Analysis of Electric Fields',
#   34: 'Hybrid Cloud Service Mesh with Anthos',
#   2068: 'Principles of Sustainable Finance',
#   2001: 'Wireless Communications for Everybody',
#   2065: 'HTML CSS and Javascript for Web Developers',
#   1956: 'Tricky American English Pronunciation',
#   2023: 'Comparing Genes Proteins and Genomes (Bioinformatics III)',
#   1978: 'Budgeting and Scheduling Projects',
#   381: 'Big History Connecting Knowledge',
# ...
#   2163: 'Business English Finance and Economics,Business English Making Presentations,Business English Basics,Business English Management and Leadership,Essentials for English Speeches and Presentations ???????,English for Effective Business Speaking',
#   2165: 'Water Supply and Sanitation Policy in Developing Countries Part 2 Developing Effective Interventions,Water Resources Management and Policy,Water in the Western United States,Introduction to Household Water Treatment and Safe Storage,Climate Change and Water in Mountains A Global Concern,Introduction to Public Health Engineering in Humanitarian Contexts',
#   2167: 'Accounting Analysis II Accounting for Liabilities and Equity,Accounting Analysis I The Role of Accounting as an Information System,Accounting Analysis I Measurement and Disclosure of Assets,Advanced Financial Reporting Accounting for Business Combinations and Preparation of Consolidated Financial Statements,Financial Reporting Capstone,Financial Accounting Foundations',
#   2168: 'VR and 360 Video Production,Introduction to Augmented Reality and ARCore,Introduction to XR VR AR and MR Foundations,New Technologies for Business Leaders,Mastering Final Cut Pro,Analyzing Video with OpenCV and NumPy',
#   2176: 'TensorFlow Serving with Docker for Model Deployment,Machine Learning Predict Numbers from Handwritten Digits using a Neural Network Keras and R,Basic Image Classification with TensorFlow,Neural Network from Scratch in TensorFlow,Neural Network Visualizer Web App with Python,Classification with Transfer Learning in Keras',
#   344: 'Photography Techniques Light Content and Sharing,Seeing Through Photographs,Camera Control,Project Management Project,Cameras Exposure and Photography,Capstone Project � Analyzing a Real Transaction',
#   2186: 'Presentation skills Designing Presentation Slides,English for Effective Business Speaking,Project Management Project,Effective Communication Capstone Project,Advanced Speaking and Listening Project,Introduction to Public Speaking',
#   2187: 'Business Model Innovation for Sustainable Landscape Restoration,Business Strategy Business Model Canvas Analysis with Miro,New Models of Business in Society,Enterprise Architecture,Sustainable Fashion,Essentials of Entrepreneurship Thinking & Action',
#   2196: 'Introduction to Chemistry Reactions and Ratios,Advanced Chemistry,Chemistry,Introduction to Physical Chemistry,General Chemistry Concept Development and Application,Statistical Molecular Thermodynamics',
#   2197: 'Structuring Machine Learning Projects,Practical Reinforcement Learning,Introduction to Reinforcement Learning in Python,Fundamentals of Reinforcement Learning,Machine Learning Foundations A Case Study Approach,Practical Machine Learning on H2O',
#   2199: 'Digital Thread Components,Digital Thread Implementation,Advanced Manufacturing Enterprise,Digital Manufacturing & Design,Advanced Manufacturing Process Analysis,Intelligent Machining',
#   338: 'Startup Valuation Methods,Advanced Valuation and Strategy - M&A Private Equity and Venture Capital,Entrepreneurship II Preparing for Launch,New Venture Finance Startup Funding for Entrepreneurs,Stock Valuation with Comparable Companies Analysis,How to finance your venture ?',
#   2210: 'Copyright Law in the Music Business,Copyright Law in the Music Business,Internet Giants The Law and Economics of Media Platforms,Understanding the Music Business What is Music Worth?,Copyright for Educators & Librarians,Music for Wellness',
#   2211: 'Unordered Data Structures,Advanced Algorithms and Complexity,Introduction to Graph Theory,Algorithms Part II,Algorithms Part I,Algorithmic Thinking (Part 1)',
#   2213: 'IT Project Management,Construction Project Management,Initiating and Planning Projects,Initiating and Planning Projects,Budgeting and Scheduling Projects,Introduction to Project Management',
#   1954: 'Autodesk Certified Professional Revit for Architectural Design Exam Prep,Autodesk Certified Professional Inventor for Mechanical Design Exam Prep,Autodesk Certified Professional Civil 3D for Infrastructure Design Exam Prep,Autodesk Certified Professional Revit for Structural Design Exam Prep,Generative Design for Additive Manufacturing,3-Axis Machining with Autodesk Fusion 360',
#   1842: 'Intro to Digital Manufacturing with Autodesk Fusion 360,Manufacturing Process with Autodesk Fusion 360,Introduction to Mechanical Engineering Design and Manufacturing with Fusion 360,3D Model Creation with Autodesk Fusion 360,Engineering Design Process with Autodesk Fusion 360,Introduction to CAD CAM and Practical CNC Machining',
#   1952: 'Innovation Through Design Think Make Break Repeat,The Language of Design Form and Meaning,Design Thinking for Innovation,Design-Led Strategy Design thinking for business strategy and entrepreneurship,Prototyping and Design,Innovation & Entrepreneurship - From Design Thinking to Funding',
#   1604: 'So You Think You Know Tango?,The World of the String Quartet,The American South Its Stories Music and Art,The Music of the Beatles,History of Rock Part One,Music Business Foundations',
#   1592: 'Introduction to Economic Theories,Economic Growth and Distributive Justice Part II - Maximize Social Wellbeing,Economic Growth and Distributive Justice Part I -The Role of the State,Introduction to Neuroeconomics How the Brain Makes Decisions,Unethical Decision Making in Organizations,Local Economic Development',
#   1591: 'AI For Everyone,Introduction to Artificial Intelligence (AI),Introduction to Artificial Intelligence (AI),Introduction to Artificial Intelligence (AI),Introduction to Artificial Intelligence (AI),Enterprise Architecture',
#   1586: 'Managing G Suite,Introduction to G Suite,G Suite Mail Management,Planning for your G Suite Deployment,Enterprise and Infrastructure Security,IT Security Defense against the digital dark arts',
#   1585: 'Creating Custom Callbacks in Keras,Build Multilayer Perceptron Models with Keras,Image Classification with CNNs using Keras,Create Custom Layers in Keras,Video Basics with OpenCV and Python,Understanding Deepfakes with Keras',
#   1582: 'Initiating and Planning Projects,Engineering Project Management Initiating and Planning,Introduction to Project Management,IT Project Management,Create a Project Charter with Google Docs,Project Management Project',
#   1576: 'Introduction to Public Speaking,Business Writing,English for Effective Business Speaking,English for Effective Business Writing,High-Impact Business Writing,High-Impact Business Writing',
#   499: 'Positive Psychology,Social Psychology,Foundations of Teaching for Learning Learners and Learning,The Psychology of Thrill Seekers,Foundations of Teaching for Learning Introduction,Get Organized How to be a Together Teacher',
#   1567: 'Create a Debt-Reduced Worksheet in Google Sheets,Create a Home Affordability Worksheet in Google Sheets,Finance for Everyone Decisions,Finance for Non-Financial Professionals,Introduction to Finance The Basics,Principles of Corporate Finance � A Tale of Value',
#   502: 'TensorFlow for AI Computer Vision Basics,TensorFlow for AI Neural Network Representation,TensorFlow for CNNs Learn and Practice CNNs,TensorFlow for AI Applying Image Convolution,TensorFlow for CNNs Transfer Learning,TensorFlow Serving with Docker for Model Deployment',
#   503: 'Software Development Processes and Methodologies,Agile Software Development,Lean Software Development,Requirements Gathering for Secure Software Development,Software Design as an Element of the Software Development Lifecycle,Agile Planning for Software Products',
#   505: "API Design and Fundamentals of Google Cloud's Apigee API Platform,API Development on Google Cloud's Apigee API Platform,API Security on Google Cloud's Apigee API Platform,On Premises Capacity Upgrade and Monitoring with Google Cloud's Apigee API Platform,Industrial IoT on Google Cloud Platform,Google Cloud Platform Big Data and Machine Learning Fundamentals",
#   1556: 'Materials Science 10 Things Every Engineer Should Know,Materials Data Sciences and Informatics,Material Processing,Advanced Functional Ceramics,Material Behavior,Dentistry 101',
#   1554: 'Leadership Through Social Influence,Relationship Management,Negotiation skills Negotiate and resolve conflict,Essentials of Entrepreneurship Thinking & Action,Communication Strategies for a Virtual Age,Self Awareness and the Effective Leader',
#   1553: 'Personal Leadership Development Planning and Leading High Performing Teams,Giving Sense to Your Leadership Experience,Building Your Leadership Skills,Adapt your leadership style,Nursing Informatics Leadership Theory and Practice,High Performance Collaboration Leadership Teamwork and Negotiation',
#   1549: 'Managing Project Risks and Changes,Initiating and Planning Projects,Initiating and Planning Projects,Introduction to Project Management,IT Project Management,Engineering Project Management Scope Time and Cost Management',
#   1593: 'Major Engineering Project Performance,Major Engineering Projects Governance Risk and Scope,Engineering Project Management Scope Time and Cost Management,Engineering Project Management Initiating and Planning,Introduction to Systems Engineering,Introduction to Project Management',
#   1606: 'Global Health Policy,The Science of Health Care Delivery,Understanding and Strengthening Health Systems,HI-FIVE Health Informatics For Innovation Value & Enrichment (Administrative/IT Perspective),Health and healthcare in transition dilemmas of governance,Health Systems Development Health systems Policy and Research',
#   477: 'Tables and Forms in HTML,Style Images with CSS,Programming Foundations with JavaScript HTML and CSS,HTML and CSS Building a Single-Page Website,Position Elements on a Page with CSS,Introduction to HTML5',
#   491: 'Palo Alto Networks Cybersecurity Essentials II,Palo Alto Networks Cybersecurity Essentials I,Cybersecurity Roles Processes & Operating System Security,Cybersecurity Roles Processes & Operating System Security,Networks and Communications Security,Cybersecurity and Its Ten Domains',
#   1655: 'Memoir and Personal Essay Managing Your Relationship with the Reader,Creative Writing The Craft of Setting and Description,English Composition I,Writing a Personal Essay,Getting Started with Essay Writing,Writing in First Person Point of View',
#   1652: 'Introduction to Valuation with WACC,Discounted Cash Flow Modeling,Valuation for Startups Using Discounted Cash Flows Approach,Profit Analysis using Economic Value Added,Stock Valuation with Dividend Discount Model,Seeking Investment Alpha',
#   1650: 'Health Systems Development A Focus on Health Service Delivery and Human Resources for Health,Health Systems Development Introduction to Health Systems,Understanding and Strengthening Health Systems,Global Health Policy,Using clinical health data for better healthcare,An Introduction to Global Health',
#   1647: 'Techniques for Teaching Adjectives and Adjective Clauses,Noun Clauses and Conditionals,Teaching Tips for Tricky English Grammar,Tricky English Grammar,Consonants of American English Pronunciation,Tricky American English Pronunciation',
#   1645: 'HI-FIVE Health Informatics For Innovation Value & Enrichment (Social/Peer Perspective),HI-FIVE Health Informatics For Innovation Value & Enrichment (Clinical Perspective),Health Care IT Challenges and Opportunities,The Science of Health Care Delivery,Health for All Through Primary Health Care,Using clinical health data for better healthcare',
#   1642: 'Autodesk Certified Professional Revit for Structural Design Exam Prep,Autodesk Certified Professional AutoCAD for Design and Drafting Exam Prep,Autodesk Certified Professional Inventor for Mechanical Design Exam Prep,Autodesk Certified Professional Civil 3D for Infrastructure Design Exam Prep,Generative Design for Additive Manufacturing,Generative Design for Industrial Applications',
#   1638: 'Digital Product Management Modern Fundamentals,A Start Guide Product Marketing Using G Suite,The Product Lifecycle A Guide from start to finish,New Product Development For Small Businesses and Start-Ups,New Product Development - develop your own new product,Analyzing Product Opportunities with Creately',
#   1632: 'Build a Database from a Relational Model,Database Design and Diagramming in Dia,Create a Database with the Modeling Tool in MySQL Workbench,Relational database systems,Creating Database Tables with SQL,Create Relational Database Tables Using SQLiteStudio',
#   1627: 'Analyze Box Office Data with Seaborn and Python,Image Compression with K-Means Clustering,Classification Trees in Python From Start To Finish,Exploratory Data Analysis with Seaborn,Image Classification with CNNs using Keras,Simple Recurrent Neural Network with Keras',
#   1626: 'AI For Medical Treatment,Structuring Machine Learning Projects,Practical Machine Learning on H2O,AI for Medical Diagnosis,Introduction to TensorFlow for Artificial Intelligence Machine Learning and Deep Learning,Machine Learning for Data Analysis',
#   1624: 'Health Care IT Challenges and Opportunities,Health Care Delivery in Healthcare Organizations,HI-FIVE Health Informatics For Innovation Value & Enrichment (Social/Peer Perspective),HI-FIVE Health Informatics For Innovation Value & Enrichment (Administrative/IT Perspective),Health for All Through Primary Health Care,HI-FIVE Health Informatics For Innovation Value & Enrichment (Clinical Perspective)',
#   1622: 'Ebola Essential Knowledge for Health Professionals,Global Health An Interdisciplinary Overview,Global Health Policy,An Introduction to Global Health,Foundations of Public Health Practice Health Protection,Global Disease Masterclass Communicable Diseases Epidemiology Intervention and Prevention',
#   1619: 'The Modern and the Postmodern (Part 2),Russian History from Lenin to Putin,Modern Art & Ideas,The Modern World Part Two Global History since 1910,The Modern World Part One Global History from 1760 to 1910,S�ren Kierkegaard - Subjectivity Irony and the Crisis of Modernity',
#   1617: 'Aromatherapy Clinical Use of Essential Oils,Aromatherapy Clinical Use of Essential Oils,Mindfulness in Integrative Healthcare,Mindfulness in Integrative Healthcare,Introduction to Integrative Nursing,Guided Imagery',
#   1614: 'Managing Security in Google Cloud Platform,Security Best Practices in Google Cloud,Essential Google Cloud Infrastructure Core Services,Essential Google Cloud Infrastructure Core Services,Essential Google Cloud Infrastructure Core Services,Essential Google Cloud Infrastructure Foundation',
#   1548: 'Managing Project Risks and Changes,Initiating and Planning Projects,Initiating and Planning Projects,Introduction to Project Management,IT Project Management,Engineering Project Management Scope Time and Cost Management',
#   512: 'Supply Chain Principles,Supply Chain Management Strategy,Managing Supply Chain Disruption During COVID-19,Supply Chain Excellence,Value Chain Management Capstone,Supply Chain Analytics',
#   1536: 'Generative Design for Part Consolidation,Generative Design for Industrial Applications,Generative Design for Additive Manufacturing,3-Axis Machining with Autodesk Fusion 360,Multi-Axis CNC Toolpaths,Creating Toolpaths for a CNC Lathe',
#   1527: 'Palo Alto Networks Cybersecurity Essentials II,Palo Alto Networks Academy Cybersecurity Foundation,Palo Alto Networks Cybersecurity Gateway II,The Foundations of Cybersecurity,Cybersecurity Compliance Framework & System Administration,Cybersecurity Compliance Framework & System Administration',
#   1474: 'Data Structures,Introduction to Data Analytics,Applied Data Science Capstone,Applied Data Science Capstone,Data Management and Visualization,Applying Data Structures to Manipulate Cleansed UN Data',
#   1468: 'Mitigating Security Vulnerabilities on Google Cloud Platform,Managing Security in Google Cloud Platform,Enterprise and Infrastructure Security,Security Best Practices in Google Cloud,Introduction to Cloud Computing,Protecting Cloud Architecture with Alibaba Cloud',
#   ...}}

# %%
similarity
# Out:
# array([[1.        , 0.03800057, 0.07908162, ..., 0.0947216 , 0.06892128,
#         0.10275975],
#        [0.03800057, 1.        , 0.01238729, ..., 0.30130767, 0.00518197,
#         0.03962144],
#        [0.07908162, 0.01238729, 1.        , ..., 0.01995129, 0.07234278,
#         0.03126409],
#        ...,
#        [0.0947216 , 0.30130767, 0.01995129, ..., 1.        , 0.00695519,
#         0.03722562],
#        [0.06892128, 0.00518197, 0.07234278, ..., 0.00695519, 1.        ,
#         0.02012109],
#        [0.10275975, 0.03962144, 0.03126409, ..., 0.03722562, 0.02012109,
#         1.        ]])

# %%
saved_lda = load_model('courses')
# Out:
# Model Sucessfully Loaded

# %%
print(saved_lda)
# Out:
#                                             course_name  \
# 1154                      Build CRUD REST API in Django
# 593              Acing the Product Management Interview
# 2160   Conduct a Cost-Benefit Analysis in Google Sheets
# 3190  Computational Thinking for K-12 Educators Sequ...
# 2498  Edit Your Photos for Social Media Marketing us...
# ...                                                 ...
# 278                      Microservices with Spring Boot
# 2467  Predict Performance Using MA Forecasting in Go...
# 2469    How To Land the Job You Want (Capstone Project)
# 2470                            C++ Classes and Objects
# 544   Create an FPS Weapon in Unity (Part 2 - Firing...
#
#                                                    tags  Course Rating  \
# 1154  build crud rest api in djangointermediatein th...            5.0
# 593   ace the product manag interviewadvancedsponsor...            5.0
# 2160  conduct a cost-benefit analysi in googl sheets...            5.0
# 3190  comput think for k-12 educ sequenc and loopsad...            5.0
# 2498  edit your photo for social media market use pi...            5.0
# ...                                                 ...            ...
# 278   microservic with spring bootadvancedbi the end...            0.0
# 2467  predict perform use ma forecast in googl sheet...            0.0
# 2469  how to land the job you want (capston project)...            0.0
# 2470  c++ class and objectsconversantin thi project ...            0.0
# 544   creat an fp weapon in uniti (part 2 - fire eff...            0.0
#
#      Difficulty_Level                                     Recommendation
# 1154     Intermediate  Encryption And Decryption Using C++,Create a S...
# 593          Advanced  The Art & Science of Product Management,The Bu...
# 2160         Beginner  Managerial Accounting Fundamentals,Introductio...
# 3190         Advanced  Computational Thinking for K-12 Educators Vari...
# 2498         Beginner  Introduction to PicsArt for Social Media Marke...
# ...               ...                                                ...
# 278          Advanced  Web Application Development Basic Concepts,Con...
# 2467         Beginner  Predict Sales and Forecast Trends in Google Sh...
# 2469         Advanced  Project Writing a Research Paper,Project Manag...
# 2470       Conversant  Java Classes and Objects,Class Creation in Obj...
# 544          Advanced  Create an FPS Weapon in Unity (Part 3 -Damage ...
#
# [3522 rows x 5 columns]

# %%
courses
# Out:
#                                             course_name  \
# 1154                      Build CRUD REST API in Django
# 593              Acing the Product Management Interview
# 2160   Conduct a Cost-Benefit Analysis in Google Sheets
# 3190  Computational Thinking for K-12 Educators Sequ...
# 2498  Edit Your Photos for Social Media Marketing us...
# ...                                                 ...
# 278                      Microservices with Spring Boot
# 2467  Predict Performance Using MA Forecasting in Go...
# 2469    How To Land the Job You Want (Capstone Project)
# 2470                            C++ Classes and Objects
# 544   Create an FPS Weapon in Unity (Part 2 - Firing...
#
#                                                    tags  Course Rating  \
# 1154  build crud rest api in djangointermediatein th...            5.0
# 593   ace the product manag interviewadvancedsponsor...            5.0
# 2160  conduct a cost-benefit analysi in googl sheets...            5.0
# 3190  comput think for k-12 educ sequenc and loopsad...            5.0
# 2498  edit your photo for social media market use pi...            5.0
# ...                                                 ...            ...
# 278   microservic with spring bootadvancedbi the end...            0.0
# 2467  predict perform use ma forecast in googl sheet...            0.0
# 2469  how to land the job you want (capston project)...            0.0
# 2470  c++ class and objectsconversantin thi project ...            0.0
# 544   creat an fp weapon in uniti (part 2 - fire eff...            0.0
#
#      Difficulty_Level                                     Recommendation
# 1154     Intermediate  Encryption And Decryption Using C++,Create a S...
# 593          Advanced  The Art & Science of Product Management,The Bu...
# 2160         Beginner  Managerial Accounting Fundamentals,Introductio...
# 3190         Advanced  Computational Thinking for K-12 Educators Vari...
# 2498         Beginner  Introduction to PicsArt for Social Media Marke...
# ...               ...                                                ...
# 278          Advanced  Web Application Development Basic Concepts,Con...
# 2467         Beginner  Predict Sales and Forecast Trends in Google Sh...
# 2469         Advanced  Project Writing a Research Paper,Project Manag...
# 2470       Conversant  Java Classes and Objects,Class Creation in Obj...
# 544          Advanced  Create an FPS Weapon in Unity (Part 3 -Damage ...
#
# [3522 rows x 5 columns]
